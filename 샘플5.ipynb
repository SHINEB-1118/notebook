# %%
# 1. ?????


import os
import copy
import numpy as np
import pandas as pd
from collections import defaultdict

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

# %%
import torch
print(torch.cuda.get_device_name(0))
# Out:
# NVIDIA GeForce RTX 4060

# %%
# 2. 4~8월 cargo CSV 로딩

file_paths = [
    r"C:\Users\HP\Desktop\prE\04cargo.csv",
    r"C:\Users\HP\Desktop\prE\05cargo.csv",
    r"C:\Users\HP\Desktop\prE\06cargo.csv",
    r"C:\Users\HP\Desktop\prE\07cargo.csv",
    r"C:\Users\HP\Desktop\prE\08cargo.csv",
]

df_list = []

for path in file_paths:
    temp = pd.read_csv(path)
    temp["source_file"] = os.path.basename(path)
    df_list.append(temp)

df_raw = pd.concat(df_list, ignore_index=True)

print(df_raw.shape)
print(df_raw.columns)
df_raw.head()
# Out:
# (4500839, 20)
# Index(['MMSI', 'Date', 'Lat', 'Long', 'SOG', 'COG', 'Heading', 'Name', 'Type',
#        'IMO', 'Call', 'DimA', 'DimB', 'DimC', 'DimD', 'Draft', 'Tons',
#        'Length', 'Breadth', 'source_file'],
#       dtype='str')
#         MMSI                 Date        Lat        Long  SOG    COG  Heading  \
# 0  215331000  2024-04-01 00:02:56  35.067482  128.808068  0.0  285.7       78
# 1  215331000  2024-04-01 00:05:56  35.067487  128.808107  0.0  233.2       78
# 2  215331000  2024-04-01 00:08:56  35.067478  128.808130  0.0  236.5       78
# 3  215331000  2024-04-01 00:11:56  35.067490  128.808120  0.0  242.4       78
# 4  215331000  2024-04-01 00:14:56  35.067518  128.808348  0.0  238.9       78
#
#                 Name  Type        IMO     Call   DimA   DimB  DimC  DimD  \
# 0  CMA CGM ARGENTINA  70.0  9839909.0  9HA5066  110.0  256.0  29.0  22.0
# 1  CMA CGM ARGENTINA  70.0  9839909.0  9HA5066  110.0  256.0  29.0  22.0
# 2  CMA CGM ARGENTINA  70.0  9839909.0  9HA5066  110.0  256.0  29.0  22.0
# 3  CMA CGM ARGENTINA  70.0  9839909.0  9HA5066  110.0  256.0  29.0  22.0
# 4  CMA CGM ARGENTINA  70.0  9839909.0  9HA5066  110.0  256.0  29.0  22.0
#
#    Draft      Tons  Length  Breadth  source_file
# 0   14.4  169408.0   366.0     51.0  04cargo.csv
# 1   14.4  169408.0   366.0     51.0  04cargo.csv
# 2   14.4  169408.0   366.0     51.0  04cargo.csv
# 3   14.4  169408.0   366.0     51.0  04cargo.csv
# 4   14.4  169408.0   366.0     51.0  04cargo.csv

# %%
# 3. 컬럼 정리 및 기본 전처리

df = df_raw[["MMSI", "Date", "Lat", "Long", "SOG", "COG", "Heading", "source_file"]].copy()

df = df.rename(columns={
    "Date": "timestamp",
    "Lat": "lat",
    "Long": "lon",
    "SOG": "sog",
    "COG": "cog",
    "Heading": "heading"
})

df["timestamp"] = pd.to_datetime(df["timestamp"], errors="coerce")

for col in ["lat", "lon", "sog", "cog", "heading"]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

df = df.dropna(subset=["MMSI", "timestamp", "lat", "lon", "sog", "cog", "heading"])

df = df[
    (df["lat"].between(-90, 90)) &
    (df["lon"].between(-180, 180)) &
    (df["sog"] >= 0) &
    (df["cog"].between(0, 360)) &
    (df["heading"].between(0, 360))
].copy()

df = df.sort_values(["MMSI", "timestamp"]).reset_index(drop=True)

df["month"] = df["timestamp"].dt.month

print(df.shape)
print(df["month"].value_counts().sort_index())
df.head()
# Out:
# (4417967, 9)
# month
# 4    826933
# 5    900471
# 6    907346
# 7    912136
# 8    871081
# Name: count, dtype: int64
#         MMSI           timestamp        lat         lon  sog    cog  heading  \
# 0  209079000 2024-08-05 03:42:22  34.960100  128.823167  9.9  339.7      338
# 1  209079000 2024-08-05 03:42:32  34.960518  128.822972  9.8  339.7      338
# 2  209079000 2024-08-05 03:42:42  34.960935  128.822775  9.6  339.1      338
# 3  209079000 2024-08-05 03:42:52  34.961335  128.822592  9.4  338.6      338
# 4  209079000 2024-08-05 03:43:02  34.961732  128.822387  9.3  338.0      338
#
#    source_file  month
# 0  08cargo.csv      8
# 1  08cargo.csv      8
# 2  08cargo.csv      8
# 3  08cargo.csv      8
# 4  08cargo.csv      8

# %%
# 4. 이동 선박 / 정지 선박 기준

MOVING_THRESHOLD = 0.5

moving_df = df[df["sog"] > MOVING_THRESHOLD].copy()
stationary_df = df[df["sog"] <= MOVING_THRESHOLD].copy()

print("전체 데이터:", len(df))
print("이동 선박 데이터:", len(moving_df))
print("정지/저속 선박 데이터:", len(stationary_df))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 # 4. 이동 선박 / 정지 선박 기준
#       2
#       3 MOVING_THRESHOLD = 0.5
#       4
# ----> 5 moving_df = df[df["sog"] > MOVING_THRESHOLD].copy()
#       6 stationary_df = df[df["sog"] <= MOVING_THRESHOLD].copy()
#       7
#       8 print("전체 데이터:", len(df))
#
# NameError: name 'df' is not defined

# %%
# 5. Grid 설정
# Interaction Graph 학습용: 0.5 NM
# 최종 혼잡도 시각화용: 1.0 NM

TRAIN_GRID_NM = 0.1
VIS_GRID_NM = 0.1

BASE_LAT_FOR_LON_SCALE = 35.0

TRAIN_LAT_GRID_SIZE = (TRAIN_GRID_NM * 1.852) / 111
TRAIN_LON_GRID_SIZE = (TRAIN_GRID_NM * 1.852) / (
    111 * np.cos(np.radians(BASE_LAT_FOR_LON_SCALE))
)

VIS_LAT_GRID_SIZE = (VIS_GRID_NM * 1.852) / 111
VIS_LON_GRID_SIZE = (VIS_GRID_NM * 1.852) / (
    111 * np.cos(np.radians(BASE_LAT_FOR_LON_SCALE))
)

print("TRAIN_LAT_GRID_SIZE:", TRAIN_LAT_GRID_SIZE)
print("TRAIN_LON_GRID_SIZE:", TRAIN_LON_GRID_SIZE)
print("VIS_LAT_GRID_SIZE:", VIS_LAT_GRID_SIZE)
print("VIS_LON_GRID_SIZE:", VIS_LON_GRID_SIZE)
# Out:
# TRAIN_LAT_GRID_SIZE: 0.0016684684684684687
# TRAIN_LON_GRID_SIZE: 0.0020368239084560514
# VIS_LAT_GRID_SIZE: 0.0016684684684684687
# VIS_LON_GRID_SIZE: 0.0020368239084560514

# %%
# 6. AIS ??? 5? ?? resampling ??
# ????? ???? ???. ?? ??? ?? 5? bin? ???.
# COG/Heading? ?? ??? ????.

RESAMPLE_INTERVAL = "5min"
MAX_REASONABLE_SPEED_KNOTS = 40
MAX_REASONABLE_STEP_KM = 6


def circular_mean_deg(series):
    values = series.dropna().values

    if len(values) == 0:
        return np.nan

    radians = np.radians(values)
    sin_mean = np.mean(np.sin(radians))
    cos_mean = np.mean(np.cos(radians))

    angle = np.degrees(np.arctan2(sin_mean, cos_mean))
    return angle + 360 if angle < 0 else angle


def haversine_km_np(lat1, lon1, lat2, lon2):
    R = 6371.0

    lat1 = np.radians(lat1)
    lon1 = np.radians(lon1)
    lat2 = np.radians(lat2)
    lon2 = np.radians(lon2)

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = (
        np.sin(dlat / 2) ** 2
        + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    )
    c = 2 * np.arcsin(np.sqrt(a))

    return R * c


def resample_ais_5min(df, progress_step=10):
    result = []
    grouped = list(df.groupby("MMSI"))
    total = len(grouped)
    next_progress = progress_step

    print(f"Resampling start: {total} vessels")

    for idx, (mmsi, group) in enumerate(grouped, start=1):
        group = group.sort_values("timestamp").set_index("timestamp")

        resampled = group[["lat", "lon", "sog"]].resample(RESAMPLE_INTERVAL).mean()
        resampled["cog"] = group["cog"].resample(RESAMPLE_INTERVAL).apply(circular_mean_deg)
        resampled["heading"] = group["heading"].resample(RESAMPLE_INTERVAL).apply(circular_mean_deg)

        resampled = resampled.dropna()
        resampled["MMSI"] = mmsi
        result.append(resampled.reset_index())

        progress = idx / total * 100 if total else 100
        if progress >= next_progress or idx == total:
            print(f"Resampling progress: {progress:.1f}% ({idx}/{total} vessels)")
            next_progress += progress_step

    if len(result) == 0:
        return pd.DataFrame(columns=["timestamp", "lat", "lon", "sog", "cog", "heading", "MMSI"])

    return pd.concat(result, ignore_index=True)


def remove_unrealistic_jumps(df, max_speed_knots=MAX_REASONABLE_SPEED_KNOTS, max_step_km=MAX_REASONABLE_STEP_KM):
    cleaned = []
    removed_count = 0

    for mmsi, group in df.groupby("MMSI"):
        group = group.sort_values("timestamp").copy()

        prev_lat = group["lat"].shift(1)
        prev_lon = group["lon"].shift(1)
        prev_time = group["timestamp"].shift(1)

        dt_hours = (group["timestamp"] - prev_time).dt.total_seconds() / 3600
        dist_km = haversine_km_np(prev_lat, prev_lon, group["lat"], group["lon"])
        speed_knots = (dist_km / 1.852) / dt_hours

        valid = (
            prev_time.isna()
            | (
                (dt_hours > 0)
                & (speed_knots <= max_speed_knots)
                & (dist_km <= max_step_km)
            )
        )

        removed_count += int((~valid).sum())
        cleaned.append(group.loc[valid])

    result = pd.concat(cleaned, ignore_index=True) if cleaned else df.iloc[0:0].copy()
    print(f"Removed unrealistic jump rows: {removed_count}")
    return result


def add_direction_features(df):
    result = df.copy()

    result["cog_sin"] = np.sin(np.radians(result["cog"]))
    result["cog_cos"] = np.cos(np.radians(result["cog"]))
    result["heading_sin"] = np.sin(np.radians(result["heading"]))
    result["heading_cos"] = np.cos(np.radians(result["heading"]))

    return result

# %%
# 7. ? ?? Train / Validation / Test ?? ? resampling
# ?? ??? ?? ???? ? ???? ?? ??? ?? ? ???? split ? resampling??.
# ????? ???? ??, ??? AIS jump? ??? ? ?? sin/cos feature? ????.

train_month_raw = moving_df[moving_df["month"].isin([4, 5, 6])].copy()
val_month_raw = moving_df[moving_df["month"].isin([7])].copy()
test_month_raw = moving_df[moving_df["month"].isin([8])].copy()

train_raw = resample_ais_5min(train_month_raw, progress_step=5)
val_raw = resample_ais_5min(val_month_raw, progress_step=5)
test_raw = resample_ais_5min(test_month_raw, progress_step=5)

train_raw = add_direction_features(remove_unrealistic_jumps(train_raw))
val_raw = add_direction_features(remove_unrealistic_jumps(val_raw))
test_raw = add_direction_features(remove_unrealistic_jumps(test_raw))

for split_df in [train_raw, val_raw, test_raw]:
    split_df["month"] = split_df["timestamp"].dt.month

moving_resampled = pd.concat([train_raw, val_raw, test_raw], ignore_index=True)
moving_resampled = moving_resampled.sort_values(["MMSI", "timestamp"]).reset_index(drop=True)

print("train_raw:", train_raw.shape)
print("val_raw:", val_raw.shape)
print("test_raw:", test_raw.shape)
print("all moving_resampled:", moving_resampled.shape)
# Out:
# Resampling start: 1083 vessels
# Resampling progress: 5.1% (55/1083 vessels)
# Resampling progress: 10.1% (109/1083 vessels)
# Resampling progress: 15.1% (163/1083 vessels)
# Resampling progress: 20.0% (217/1083 vessels)
# Resampling progress: 25.0% (271/1083 vessels)
# Resampling progress: 30.0% (325/1083 vessels)
# Resampling progress: 35.1% (380/1083 vessels)
# Resampling progress: 40.1% (434/1083 vessels)
# Resampling progress: 45.1% (488/1083 vessels)
# Resampling progress: 50.0% (542/1083 vessels)
# Resampling progress: 55.0% (596/1083 vessels)
# Resampling progress: 60.0% (650/1083 vessels)
# Resampling progress: 65.0% (704/1083 vessels)
# Resampling progress: 70.1% (759/1083 vessels)
# Resampling progress: 75.1% (813/1083 vessels)
# Resampling progress: 80.1% (867/1083 vessels)
# Resampling progress: 85.0% (921/1083 vessels)
# Resampling progress: 90.0% (975/1083 vessels)
# Resampling progress: 95.0% (1029/1083 vessels)
# Resampling progress: 100.0% (1083/1083 vessels)
# Resampling start: 547 vessels
# Resampling progress: 5.1% (28/547 vessels)
# Resampling progress: 10.1% (55/547 vessels)
# Resampling progress: 15.2% (83/547 vessels)
# Resampling progress: 20.1% (110/547 vessels)
# Resampling progress: 25.0% (137/547 vessels)
# Resampling progress: 30.2% (165/547 vessels)
# Resampling progress: 35.1% (192/547 vessels)
# Resampling progress: 40.0% (219/547 vessels)
# Resampling progress: 45.2% (247/547 vessels)
# Resampling progress: 50.1% (274/547 vessels)
# Resampling progress: 55.0% (301/547 vessels)
# Resampling progress: 60.1% (329/547 vessels)
# Resampling progress: 65.1% (356/547 vessels)
# Resampling progress: 70.0% (383/547 vessels)
# Resampling progress: 75.1% (411/547 vessels)
# Resampling progress: 80.1% (438/547 vessels)
# Resampling progress: 85.0% (465/547 vessels)
# Resampling progress: 90.1% (493/547 vessels)
# Resampling progress: 95.1% (520/547 vessels)
# Resampling progress: 100.0% (547/547 vessels)
# Resampling start: 521 vessels
# Resampling progress: 5.2% (27/521 vessels)
# Resampling progress: 10.2% (53/521 vessels)
# Resampling progress: 15.2% (79/521 vessels)
# Resampling progress: 20.2% (105/521 vessels)
# Resampling progress: 25.1% (131/521 vessels)
# Resampling progress: 30.1% (157/521 vessels)
# Resampling progress: 35.1% (183/521 vessels)
# Resampling progress: 40.1% (209/521 vessels)
# Resampling progress: 45.1% (235/521 vessels)
# Resampling progress: 50.1% (261/521 vessels)
# Resampling progress: 55.1% (287/521 vessels)
# Resampling progress: 60.1% (313/521 vessels)
# Resampling progress: 65.1% (339/521 vessels)
# Resampling progress: 70.1% (365/521 vessels)
# Resampling progress: 75.0% (391/521 vessels)
# Resampling progress: 80.0% (417/521 vessels)
# Resampling progress: 85.0% (443/521 vessels)
# Resampling progress: 90.0% (469/521 vessels)
# Resampling progress: 95.0% (495/521 vessels)
# Resampling progress: 100.0% (521/521 vessels)
# Removed unrealistic jump rows: 8
# Removed unrealistic jump rows: 1
# Removed unrealistic jump rows: 1
# train_raw: (51894, 12)
# val_raw: (18187, 12)
# test_raw: (16790, 12)
# all moving_resampled: (86871, 12)

# %%
# 8. ???
# ?? feature? lat/lon/sog? ?? sin/cos? ????.
# target? ?? ?? ??? ??? ?? ?? ?? ?? 5? delta_lat/delta_lon??.

feature_cols = [
    "lat", "lon", "sog",
    "cog_sin", "cog_cos",
    "heading_sin", "heading_cos"
]
target_cols = ["delta_lat", "delta_lon"]

x_scaler = MinMaxScaler()
y_scaler = MinMaxScaler()


def build_delta_target_frame(raw_df, interval_minutes=5):
    rows = []
    expected_delta = pd.Timedelta(minutes=interval_minutes)

    for _, group in raw_df.groupby("MMSI"):
        group = group.sort_values("timestamp").reset_index(drop=True)

        next_lat = group["lat"].shift(-1)
        next_lon = group["lon"].shift(-1)
        next_time = group["timestamp"].shift(-1)

        is_continuous = (next_time - group["timestamp"]) == expected_delta
        delta_df = pd.DataFrame({
            "delta_lat": next_lat - group["lat"],
            "delta_lon": next_lon - group["lon"]
        })

        rows.append(delta_df.loc[is_continuous].dropna())

    if len(rows) == 0:
        return pd.DataFrame(columns=target_cols)

    return pd.concat(rows, ignore_index=True)


train_delta_targets = build_delta_target_frame(train_raw)

x_scaler.fit(train_raw[feature_cols])
y_scaler.fit(train_delta_targets[target_cols])


def apply_scaling(raw_df):
    norm_df = raw_df.copy()
    norm_df[feature_cols] = x_scaler.transform(raw_df[feature_cols])
    return norm_df


train_norm = apply_scaling(train_raw)
val_norm = apply_scaling(val_raw)
test_norm = apply_scaling(test_raw)
all_norm = apply_scaling(moving_resampled)

print("delta target rows for scaler:", len(train_delta_targets))
train_norm.head()
# Out:
# delta target rows for scaler: 46964
#             timestamp       lat       lon       sog         cog  heading  \
# 0 2024-04-15 10:35:00  0.002318  0.898242  0.095379  338.500000    340.0
# 1 2024-04-15 10:40:00  0.058490  0.844810  0.093379  339.103334    340.0
# 2 2024-04-15 10:45:00  0.160297  0.750063  0.081613  339.240000    340.0
# 3 2024-04-15 10:50:00  0.252004  0.664034  0.076696  339.216667    340.0
# 4 2024-04-15 10:55:00  0.346525  0.578389  0.086988  339.506666    340.0
#
#         MMSI   cog_sin   cog_cos  heading_sin  heading_cos  month
# 0  209423000  0.316749  0.965209      0.32899     0.969846      4
# 1  209423000  0.321658  0.967113      0.32899     0.969846      4
# 2  209423000  0.322773  0.967537      0.32899     0.969846      4
# 3  209423000  0.322582  0.967464      0.32899     0.969846      4
# 4  209423000  0.324951  0.968356      0.32899     0.969846      4

# %%
# 9. Interaction transition statistics ??
# train_raw?? grid ? ?? ??? ????.
# ?? sequence? interaction adjacency matrix? 10??? ? ??? ??? ???.


def latlon_to_grid(lat, lon, lat_min, lon_min, lat_grid_size, lon_grid_size):
    row = int((lat - lat_min) / lat_grid_size)
    col = int((lon - lon_min) / lon_grid_size)
    return row, col


def build_interaction_counts(df):
    transition_counts = defaultdict(int)

    lat_min = df["lat"].min()
    lon_min = df["lon"].min()

    for mmsi, group in df.groupby("MMSI"):
        group = group.sort_values("timestamp")
        coords = group[["lat", "lon"]].values

        for i in range(len(coords) - 1):
            g1 = latlon_to_grid(
                coords[i][0], coords[i][1],
                lat_min, lon_min,
                TRAIN_LAT_GRID_SIZE, TRAIN_LON_GRID_SIZE
            )
            g2 = latlon_to_grid(
                coords[i + 1][0], coords[i + 1][1],
                lat_min, lon_min,
                TRAIN_LAT_GRID_SIZE, TRAIN_LON_GRID_SIZE
            )
            transition_counts[(g1, g2)] += 1

    return transition_counts, lat_min, lon_min


transition_counts, train_lat_min, train_lon_min = build_interaction_counts(train_raw)

print("interaction transition count:", len(transition_counts))
print("train_lat_min:", train_lat_min)
print("train_lon_min:", train_lon_min)
# Out:
# interaction transition count: 13134
# train_lat_min: 34.96
# train_lon_min: 128.770005

# %%
# 10. Sequence? Multi-Graph ?? ??
# Distance graph? sequence? ??? ?? ????,
# Interaction graph? 9??? ?? train ?? transition statistics? ????.

DISTANCE_GRAPH_SIGMA_KM = 0.5


def create_distance_graph(raw_seq, sigma_km=DISTANCE_GRAPH_SIGMA_KM):
    coords = raw_seq[:, :2]

    lat_km = coords[:, 0] * 111.0
    lon_km = coords[:, 1] * 111.0 * np.cos(np.radians(BASE_LAT_FOR_LON_SCALE))
    xy = np.stack([lat_km, lon_km], axis=1)

    diff = xy[:, None, :] - xy[None, :, :]
    dist_km = np.sqrt(np.sum(diff ** 2, axis=-1))

    A = np.exp(-dist_km / sigma_km)
    return A.astype(np.float32)


def create_interaction_graph(raw_seq):
    N = len(raw_seq)
    A = np.zeros((N, N), dtype=np.float32)

    nodes = [
        latlon_to_grid(
            row[0], row[1],
            train_lat_min, train_lon_min,
            TRAIN_LAT_GRID_SIZE, TRAIN_LON_GRID_SIZE
        )
        for row in raw_seq
    ]

    for i in range(N):
        for j in range(N):
            A[i, j] = transition_counts.get((nodes[i], nodes[j]), 0)

    if A.max() > 0:
        A = A / (A.max() + 1e-6)

    return A.astype(np.float32)


def create_multi_graph(raw_seq):
    A_distance = create_distance_graph(raw_seq)
    A_interaction = create_interaction_graph(raw_seq)
    return np.stack([A_distance, A_interaction], axis=0).astype(np.float32)

# %%
# 11. 과거 10개 시점으로 다음 5분 이동량 예측 sequence 생성
# history 내부 간격은 최대 10분까지 허용하되,
# 마지막 입력 시점 -> target 시점은 정확히 5분인 경우만 사용한다.

def create_next_step_sequences_with_graph(raw_df, norm_df, seq_len=10, stride=1, max_sequences=None):
    sequences = []
    max_gap = np.timedelta64(10, "m")
    target_gap = np.timedelta64(5, "m")

    for mmsi in raw_df["MMSI"].unique():
        raw_group = raw_df[raw_df["MMSI"] == mmsi].sort_values("timestamp").reset_index(drop=True)
        norm_group = norm_df[norm_df["MMSI"] == mmsi].sort_values("timestamp").reset_index(drop=True)

        if len(raw_group) <= seq_len:
            continue

        raw_data = raw_group[feature_cols].values.astype(np.float32)
        norm_data = norm_group[feature_cols].values.astype(np.float32)
        timestamps = raw_group["timestamp"].values.astype("datetime64[ns]")

        for i in range(0, len(raw_group) - seq_len, stride):
            time_window = timestamps[i:i + seq_len + 1]
            time_diffs = np.diff(time_window).astype("timedelta64[m]")

            history_diffs = time_diffs[:-1]
            target_diff = time_diffs[-1]

            if not np.all((history_diffs > np.timedelta64(0, "m")) & (history_diffs <= max_gap)):
                continue

            if target_diff != target_gap:
                continue

            raw_seq = raw_data[i:i + seq_len]
            norm_seq = norm_data[i:i + seq_len]

            current_pos = raw_data[i + seq_len - 1][:2]
            next_pos = raw_data[i + seq_len][:2]
            raw_delta = next_pos - current_pos

            target = y_scaler.transform(
                pd.DataFrame([raw_delta], columns=target_cols)
            )[0].astype(np.float32)

            graph = create_multi_graph(raw_seq)
            sequences.append((norm_seq, graph, target))

            if max_sequences is not None and len(sequences) >= max_sequences:
                return sequences

    return sequences


SEQ_LEN = 10
TRAIN_STRIDE = 1
VAL_STRIDE = 1
TEST_STRIDE = 1

MAX_TRAIN_SEQUENCES = None
MAX_VAL_SEQUENCES = None
MAX_TEST_SEQUENCES = None

train_sequences = create_next_step_sequences_with_graph(
    train_raw,
    train_norm,
    seq_len=SEQ_LEN,
    stride=TRAIN_STRIDE,
    max_sequences=MAX_TRAIN_SEQUENCES
)

val_sequences = create_next_step_sequences_with_graph(
    val_raw,
    val_norm,
    seq_len=SEQ_LEN,
    stride=VAL_STRIDE,
    max_sequences=MAX_VAL_SEQUENCES
)

test_sequences = create_next_step_sequences_with_graph(
    test_raw,
    test_norm,
    seq_len=SEQ_LEN,
    stride=TEST_STRIDE,
    max_sequences=MAX_TEST_SEQUENCES
)

print("train_sequences:", len(train_sequences))
print("val_sequences:", len(val_sequences))
print("test_sequences:", len(test_sequences))

if len(train_sequences) > 0:
    print("sample norm_seq:", train_sequences[0][0].shape)
    print("sample graph:", train_sequences[0][1].shape)
    print("sample target:", train_sequences[0][2].shape)
else:
    print("train_sequences가 비어 있습니다.")
# Out:
# train_sequences: 10792
# val_sequences: 4080
# test_sequences: 3628
# sample norm_seq: (10, 7)
# sample graph: (2, 10, 10)
# sample target: (2,)

# %%
# 12. Dataset / DataLoader
# graph는 이미 pre-compute 되어 있음

class AISDataset(Dataset):
    def __init__(self, sequences):
        self.sequences = sequences

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        norm_seq, graph, target = self.sequences[idx]

        return (
            torch.tensor(norm_seq, dtype=torch.float32),
            torch.tensor(graph, dtype=torch.float32),
            torch.tensor(target, dtype=torch.float32)
        )


BATCH_SIZE = 32

train_dataset = AISDataset(train_sequences)
val_dataset = AISDataset(val_sequences)
test_dataset = AISDataset(test_sequences)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False, drop_last=False)

for X, graphs, y in train_loader:
    print("X:", X.shape)
    print("graphs:", graphs.shape)
    print("y:", y.shape)
    break
# Out:
# X: torch.Size([32, 10, 7])
# graphs: torch.Size([32, 2, 10, 10])
# y: torch.Size([32, 2])

# %%
# 13. STMGCN ?? ??
# Spatial-Temporal Multi-Graph Convolutional Network

class GCNLayer(nn.Module):
    def __init__(self, in_dim, out_dim, dropout=0.1):
        super().__init__()
        self.linear = nn.Linear(in_dim, out_dim)
        self.dropout = nn.Dropout(dropout)
        self.norm = nn.LayerNorm(out_dim)

    def forward(self, X, A):
        B, T, _ = X.shape

        I = torch.eye(T, device=X.device, dtype=X.dtype).unsqueeze(0).expand(B, T, T)
        A_hat = A.to(dtype=X.dtype) + I

        degree = torch.sum(A_hat, dim=-1).clamp_min(1e-6)
        degree_inv_sqrt = torch.pow(degree, -0.5)
        A_norm = degree_inv_sqrt.unsqueeze(-1) * A_hat * degree_inv_sqrt.unsqueeze(-2)

        H = A_norm @ self.linear(X)
        H = F.relu(H)
        H = self.dropout(H)

        return self.norm(H)


class MultiGraphAttentionFusion(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.score_layer = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.Tanh(),
            nn.Linear(hidden_dim // 2, 1)
        )

    def forward(self, H_list):
        scores = []

        for H in H_list:
            graph_score = self.score_layer(H).mean(dim=1)
            scores.append(graph_score)

        scores = torch.cat(scores, dim=1)
        weights = F.softmax(scores, dim=1)

        fused = torch.zeros_like(H_list[0])
        for i, H in enumerate(H_list):
            w = weights[:, i].view(-1, 1, 1)
            fused = fused + w * H

        return fused, weights


class TemporalConvBlock(nn.Module):
    def __init__(self, hidden_dim, kernel_size=3, dropout=0.1):
        super().__init__()
        padding = kernel_size // 2

        self.filter_conv = nn.Conv1d(hidden_dim, hidden_dim, kernel_size, padding=padding)
        self.gate_conv = nn.Conv1d(hidden_dim, hidden_dim, kernel_size, padding=padding)
        self.proj = nn.Conv1d(hidden_dim, hidden_dim, kernel_size=1)
        self.dropout = nn.Dropout(dropout)
        self.norm = nn.LayerNorm(hidden_dim)

    def forward(self, x):
        residual = x

        x = x.transpose(1, 2)
        z = torch.tanh(self.filter_conv(x))
        g = torch.sigmoid(self.gate_conv(x))
        x = self.proj(z * g)
        x = self.dropout(x)
        x = x.transpose(1, 2)

        return self.norm(x + residual)


class STMGCN(nn.Module):
    def __init__(
        self,
        input_dim=5,
        hidden_dim=64,
        num_graphs=2,
        output_dim=2,
        num_temporal_blocks=2,
        dropout=0.1
    ):
        super().__init__()

        self.num_graphs = num_graphs

        self.input_projection = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.ReLU(),
            nn.LayerNorm(hidden_dim)
        )

        self.gcn_layers = nn.ModuleList([
            GCNLayer(hidden_dim, hidden_dim, dropout=dropout)
            for _ in range(num_graphs)
        ])

        self.graph_fusion = MultiGraphAttentionFusion(hidden_dim)

        self.temporal_blocks = nn.ModuleList([
            TemporalConvBlock(hidden_dim, dropout=dropout)
            for _ in range(num_temporal_blocks)
        ])

        self.output_layer = nn.Sequential(
            nn.Linear(hidden_dim, hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim // 2, output_dim)
        )

        self.last_graph_weights = None

    def forward(self, X, graphs):
        H0 = self.input_projection(X)

        H_list = []
        for i in range(self.num_graphs):
            A = graphs[:, i, :, :]
            H = self.gcn_layers[i](H0, A)
            H_list.append(H)

        H, graph_weights = self.graph_fusion(H_list)
        self.last_graph_weights = graph_weights.detach()

        for block in self.temporal_blocks:
            H = block(H)

        last_hidden = H[:, -1, :]
        return self.output_layer(last_hidden)

# %%
# 14. ?? ??

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("device:", device)

model = STMGCN(
    input_dim=len(feature_cols),
    hidden_dim=64,
    num_graphs=2,
    output_dim=2,
    num_temporal_blocks=2,
    dropout=0.1
).to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
criterion = nn.MSELoss()
# Out:
# device: cuda

# %%
# 15. ?? ?? + Validation ?? + Early Stopping


def train_one_epoch(model, loader, optimizer, criterion):
    model.train()
    total_loss = 0

    for X, graphs, y in loader:
        X = X.to(device)
        graphs = graphs.to(device)
        y = y.to(device)

        optimizer.zero_grad()
        pred = model(X, graphs)
        loss = criterion(pred, y)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(loader)


def evaluate_loss(model, loader, criterion):
    model.eval()
    total_loss = 0

    with torch.no_grad():
        for X, graphs, y in loader:
            X = X.to(device)
            graphs = graphs.to(device)
            y = y.to(device)

            pred = model(X, graphs)
            loss = criterion(pred, y)
            total_loss += loss.item()

    return total_loss / len(loader)


EPOCHS = 2000
PATIENCE = 150

best_val_loss = float("inf")
patience_counter = 0
best_model_state = None

train_losses = []
val_losses = []

for epoch in range(EPOCHS):
    train_loss = train_one_epoch(model, train_loader, optimizer, criterion)
    val_loss = evaluate_loss(model, val_loader, criterion)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    print(f"Epoch [{epoch + 1}/{EPOCHS}] Train Loss: {train_loss:.6f} | Val Loss: {val_loss:.6f}")

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model_state = copy.deepcopy(model.state_dict())
        patience_counter = 0
    else:
        patience_counter += 1

    if patience_counter >= PATIENCE:
        print("Early stopping")
        break

if best_model_state is not None:
    model.load_state_dict(best_model_state)

print("Best Val Loss:", best_val_loss)
# Out:
# Epoch [1/2000] Train Loss: 0.015133 | Val Loss: 0.001896
# Epoch [2/2000] Train Loss: 0.007552 | Val Loss: 0.001532
# Epoch [3/2000] Train Loss: 0.005915 | Val Loss: 0.001303
# Epoch [4/2000] Train Loss: 0.004964 | Val Loss: 0.001168
# Epoch [5/2000] Train Loss: 0.003979 | Val Loss: 0.000967
# Epoch [6/2000] Train Loss: 0.003330 | Val Loss: 0.001336
# Epoch [7/2000] Train Loss: 0.002731 | Val Loss: 0.001245
# Epoch [8/2000] Train Loss: 0.002218 | Val Loss: 0.001119
# Epoch [9/2000] Train Loss: 0.001795 | Val Loss: 0.000870
# Epoch [10/2000] Train Loss: 0.001400 | Val Loss: 0.001089
# Epoch [11/2000] Train Loss: 0.001146 | Val Loss: 0.000904
# Epoch [12/2000] Train Loss: 0.000969 | Val Loss: 0.000580
# Epoch [13/2000] Train Loss: 0.000851 | Val Loss: 0.000583
# Epoch [14/2000] Train Loss: 0.000771 | Val Loss: 0.000516
# Epoch [15/2000] Train Loss: 0.000704 | Val Loss: 0.000560
# Epoch [16/2000] Train Loss: 0.000651 | Val Loss: 0.000518
# Epoch [17/2000] Train Loss: 0.000656 | Val Loss: 0.000443
# Epoch [18/2000] Train Loss: 0.000605 | Val Loss: 0.000483
# Epoch [19/2000] Train Loss: 0.000591 | Val Loss: 0.000502
# Epoch [20/2000] Train Loss: 0.000588 | Val Loss: 0.000453
# Epoch [21/2000] Train Loss: 0.000582 | Val Loss: 0.000488
# Epoch [22/2000] Train Loss: 0.000561 | Val Loss: 0.000449
# Epoch [23/2000] Train Loss: 0.000571 | Val Loss: 0.000477
# Epoch [24/2000] Train Loss: 0.000536 | Val Loss: 0.000479
# Epoch [25/2000] Train Loss: 0.000553 | Val Loss: 0.000441
# Epoch [26/2000] Train Loss: 0.000541 | Val Loss: 0.000527
# Epoch [27/2000] Train Loss: 0.000522 | Val Loss: 0.000453
# Epoch [28/2000] Train Loss: 0.000529 | Val Loss: 0.000498
# Epoch [29/2000] Train Loss: 0.000513 | Val Loss: 0.000460
# Epoch [30/2000] Train Loss: 0.000491 | Val Loss: 0.000477
# Epoch [31/2000] Train Loss: 0.000490 | Val Loss: 0.000458
# Epoch [32/2000] Train Loss: 0.000503 | Val Loss: 0.000479
# Epoch [33/2000] Train Loss: 0.000502 | Val Loss: 0.000501
# Epoch [34/2000] Train Loss: 0.000499 | Val Loss: 0.000508
# Epoch [35/2000] Train Loss: 0.000500 | Val Loss: 0.000560
# Epoch [36/2000] Train Loss: 0.000491 | Val Loss: 0.000451
# Epoch [37/2000] Train Loss: 0.000479 | Val Loss: 0.000428
# Epoch [38/2000] Train Loss: 0.000477 | Val Loss: 0.000552
# Epoch [39/2000] Train Loss: 0.000469 | Val Loss: 0.000487
# Epoch [40/2000] Train Loss: 0.000474 | Val Loss: 0.000422
# Epoch [41/2000] Train Loss: 0.000485 | Val Loss: 0.000486
# Epoch [42/2000] Train Loss: 0.000486 | Val Loss: 0.000455
# Epoch [43/2000] Train Loss: 0.000483 | Val Loss: 0.000416
# Epoch [44/2000] Train Loss: 0.000472 | Val Loss: 0.000437
# Epoch [45/2000] Train Loss: 0.000478 | Val Loss: 0.000659
# Epoch [46/2000] Train Loss: 0.000475 | Val Loss: 0.000442
# Epoch [47/2000] Train Loss: 0.000462 | Val Loss: 0.000429
# Epoch [48/2000] Train Loss: 0.000457 | Val Loss: 0.000468
# Epoch [49/2000] Train Loss: 0.000466 | Val Loss: 0.000560
# Epoch [50/2000] Train Loss: 0.000470 | Val Loss: 0.000400
# Epoch [51/2000] Train Loss: 0.000456 | Val Loss: 0.000478
# Epoch [52/2000] Train Loss: 0.000462 | Val Loss: 0.000407
# Epoch [53/2000] Train Loss: 0.000449 | Val Loss: 0.000403
# Epoch [54/2000] Train Loss: 0.000452 | Val Loss: 0.000411
# Epoch [55/2000] Train Loss: 0.000453 | Val Loss: 0.000392
# Epoch [56/2000] Train Loss: 0.000454 | Val Loss: 0.000404
# Epoch [57/2000] Train Loss: 0.000457 | Val Loss: 0.000449
# Epoch [58/2000] Train Loss: 0.000450 | Val Loss: 0.000490
# Epoch [59/2000] Train Loss: 0.000465 | Val Loss: 0.000411
# Epoch [60/2000] Train Loss: 0.000474 | Val Loss: 0.000390
# Epoch [61/2000] Train Loss: 0.000434 | Val Loss: 0.000410
# Epoch [62/2000] Train Loss: 0.000451 | Val Loss: 0.000380
# Epoch [63/2000] Train Loss: 0.000447 | Val Loss: 0.000423
# Epoch [64/2000] Train Loss: 0.000453 | Val Loss: 0.000440
# Epoch [65/2000] Train Loss: 0.000445 | Val Loss: 0.000432
# Epoch [66/2000] Train Loss: 0.000459 | Val Loss: 0.000385
# Epoch [67/2000] Train Loss: 0.000447 | Val Loss: 0.000461
# Epoch [68/2000] Train Loss: 0.000442 | Val Loss: 0.000424
# Epoch [69/2000] Train Loss: 0.000452 | Val Loss: 0.000440
# Epoch [70/2000] Train Loss: 0.000458 | Val Loss: 0.000428
# Epoch [71/2000] Train Loss: 0.000451 | Val Loss: 0.000357
# Epoch [72/2000] Train Loss: 0.000449 | Val Loss: 0.000421
# Epoch [73/2000] Train Loss: 0.000442 | Val Loss: 0.000409
# Epoch [74/2000] Train Loss: 0.000456 | Val Loss: 0.000359
# Epoch [75/2000] Train Loss: 0.000449 | Val Loss: 0.000379
# Epoch [76/2000] Train Loss: 0.000432 | Val Loss: 0.000409
# Epoch [77/2000] Train Loss: 0.000451 | Val Loss: 0.000330
# Epoch [78/2000] Train Loss: 0.000462 | Val Loss: 0.000366
# Epoch [79/2000] Train Loss: 0.000448 | Val Loss: 0.000384
# Epoch [80/2000] Train Loss: 0.000436 | Val Loss: 0.000378
# Epoch [81/2000] Train Loss: 0.000444 | Val Loss: 0.000418
# Epoch [82/2000] Train Loss: 0.000434 | Val Loss: 0.000395
# Epoch [83/2000] Train Loss: 0.000451 | Val Loss: 0.000379
# Epoch [84/2000] Train Loss: 0.000446 | Val Loss: 0.000396
# Epoch [85/2000] Train Loss: 0.000435 | Val Loss: 0.000340
# Epoch [86/2000] Train Loss: 0.000434 | Val Loss: 0.000355
# Epoch [87/2000] Train Loss: 0.000453 | Val Loss: 0.000347
# Epoch [88/2000] Train Loss: 0.000448 | Val Loss: 0.000420
# Epoch [89/2000] Train Loss: 0.000446 | Val Loss: 0.000385
# Epoch [90/2000] Train Loss: 0.000456 | Val Loss: 0.000482
# Epoch [91/2000] Train Loss: 0.000442 | Val Loss: 0.000360
# Epoch [92/2000] Train Loss: 0.000436 | Val Loss: 0.000338
# Epoch [93/2000] Train Loss: 0.000462 | Val Loss: 0.000355
# Epoch [94/2000] Train Loss: 0.000456 | Val Loss: 0.000364
# Epoch [95/2000] Train Loss: 0.000436 | Val Loss: 0.000354
# Epoch [96/2000] Train Loss: 0.000444 | Val Loss: 0.000398
# Epoch [97/2000] Train Loss: 0.000452 | Val Loss: 0.000386
# Epoch [98/2000] Train Loss: 0.000446 | Val Loss: 0.000414
# Epoch [99/2000] Train Loss: 0.000444 | Val Loss: 0.000428
# Epoch [100/2000] Train Loss: 0.000451 | Val Loss: 0.000374
# Epoch [101/2000] Train Loss: 0.000443 | Val Loss: 0.000375
# Epoch [102/2000] Train Loss: 0.000447 | Val Loss: 0.000334
# Epoch [103/2000] Train Loss: 0.000441 | Val Loss: 0.000354
# Epoch [104/2000] Train Loss: 0.000438 | Val Loss: 0.000377
# Epoch [105/2000] Train Loss: 0.000434 | Val Loss: 0.000385
# Epoch [106/2000] Train Loss: 0.000442 | Val Loss: 0.000376
# Epoch [107/2000] Train Loss: 0.000435 | Val Loss: 0.000374
# Epoch [108/2000] Train Loss: 0.000444 | Val Loss: 0.000371
# Epoch [109/2000] Train Loss: 0.000441 | Val Loss: 0.000479
# Epoch [110/2000] Train Loss: 0.000435 | Val Loss: 0.000374
# Epoch [111/2000] Train Loss: 0.000438 | Val Loss: 0.000420
# Epoch [112/2000] Train Loss: 0.000451 | Val Loss: 0.000371
# Epoch [113/2000] Train Loss: 0.000446 | Val Loss: 0.000351
# Epoch [114/2000] Train Loss: 0.000445 | Val Loss: 0.000401
# Epoch [115/2000] Train Loss: 0.000437 | Val Loss: 0.000402
# Epoch [116/2000] Train Loss: 0.000429 | Val Loss: 0.000416
# Epoch [117/2000] Train Loss: 0.000437 | Val Loss: 0.000350
# Epoch [118/2000] Train Loss: 0.000435 | Val Loss: 0.000418
# Epoch [119/2000] Train Loss: 0.000435 | Val Loss: 0.000363
# Epoch [120/2000] Train Loss: 0.000441 | Val Loss: 0.000354
# Epoch [121/2000] Train Loss: 0.000447 | Val Loss: 0.000438
# Epoch [122/2000] Train Loss: 0.000437 | Val Loss: 0.000326
# Epoch [123/2000] Train Loss: 0.000450 | Val Loss: 0.000351
# Epoch [124/2000] Train Loss: 0.000431 | Val Loss: 0.000402
# Epoch [125/2000] Train Loss: 0.000432 | Val Loss: 0.000433
# Epoch [126/2000] Train Loss: 0.000444 | Val Loss: 0.000392
# Epoch [127/2000] Train Loss: 0.000436 | Val Loss: 0.000457
# Epoch [128/2000] Train Loss: 0.000439 | Val Loss: 0.000478
# Epoch [129/2000] Train Loss: 0.000440 | Val Loss: 0.000383
# Epoch [130/2000] Train Loss: 0.000429 | Val Loss: 0.000391
# Epoch [131/2000] Train Loss: 0.000432 | Val Loss: 0.000419
# Epoch [132/2000] Train Loss: 0.000438 | Val Loss: 0.000447
# Epoch [133/2000] Train Loss: 0.000445 | Val Loss: 0.000440
# Epoch [134/2000] Train Loss: 0.000429 | Val Loss: 0.000391
# Epoch [135/2000] Train Loss: 0.000427 | Val Loss: 0.000381
# Epoch [136/2000] Train Loss: 0.000435 | Val Loss: 0.000361
# Epoch [137/2000] Train Loss: 0.000441 | Val Loss: 0.000382
# Epoch [138/2000] Train Loss: 0.000444 | Val Loss: 0.000442
# Epoch [139/2000] Train Loss: 0.000438 | Val Loss: 0.000366
# Epoch [140/2000] Train Loss: 0.000434 | Val Loss: 0.000406
# Epoch [141/2000] Train Loss: 0.000446 | Val Loss: 0.000468
# Epoch [142/2000] Train Loss: 0.000438 | Val Loss: 0.000388
# Epoch [143/2000] Train Loss: 0.000448 | Val Loss: 0.000418
# Epoch [144/2000] Train Loss: 0.000449 | Val Loss: 0.000451
# Epoch [145/2000] Train Loss: 0.000433 | Val Loss: 0.000413
# Epoch [146/2000] Train Loss: 0.000439 | Val Loss: 0.000388
# Epoch [147/2000] Train Loss: 0.000438 | Val Loss: 0.000449
# Epoch [148/2000] Train Loss: 0.000439 | Val Loss: 0.000417
# Epoch [149/2000] Train Loss: 0.000427 | Val Loss: 0.000419
# Epoch [150/2000] Train Loss: 0.000438 | Val Loss: 0.000442
# Epoch [151/2000] Train Loss: 0.000433 | Val Loss: 0.000428
# Epoch [152/2000] Train Loss: 0.000444 | Val Loss: 0.000430
# Epoch [153/2000] Train Loss: 0.000431 | Val Loss: 0.000397
# Epoch [154/2000] Train Loss: 0.000442 | Val Loss: 0.000389
# Epoch [155/2000] Train Loss: 0.000429 | Val Loss: 0.000390
# Epoch [156/2000] Train Loss: 0.000440 | Val Loss: 0.000402
# Epoch [157/2000] Train Loss: 0.000431 | Val Loss: 0.000370
# Epoch [158/2000] Train Loss: 0.000437 | Val Loss: 0.000448
# Epoch [159/2000] Train Loss: 0.000439 | Val Loss: 0.000401
# Epoch [160/2000] Train Loss: 0.000440 | Val Loss: 0.000440
# Epoch [161/2000] Train Loss: 0.000427 | Val Loss: 0.000422
# Epoch [162/2000] Train Loss: 0.000433 | Val Loss: 0.000427
# Epoch [163/2000] Train Loss: 0.000439 | Val Loss: 0.000376
# Epoch [164/2000] Train Loss: 0.000423 | Val Loss: 0.000457
# Epoch [165/2000] Train Loss: 0.000443 | Val Loss: 0.000374
# Epoch [166/2000] Train Loss: 0.000442 | Val Loss: 0.000371
# Epoch [167/2000] Train Loss: 0.000422 | Val Loss: 0.000399
# Epoch [168/2000] Train Loss: 0.000428 | Val Loss: 0.000426
# Epoch [169/2000] Train Loss: 0.000432 | Val Loss: 0.000410
# Epoch [170/2000] Train Loss: 0.000425 | Val Loss: 0.000353
# Epoch [171/2000] Train Loss: 0.000437 | Val Loss: 0.000397
# Epoch [172/2000] Train Loss: 0.000432 | Val Loss: 0.000410
# Epoch [173/2000] Train Loss: 0.000434 | Val Loss: 0.000373
# Epoch [174/2000] Train Loss: 0.000437 | Val Loss: 0.000390
# Epoch [175/2000] Train Loss: 0.000429 | Val Loss: 0.000418
# Epoch [176/2000] Train Loss: 0.000437 | Val Loss: 0.000440
# Epoch [177/2000] Train Loss: 0.000446 | Val Loss: 0.000386
# Epoch [178/2000] Train Loss: 0.000421 | Val Loss: 0.000397
# Epoch [179/2000] Train Loss: 0.000440 | Val Loss: 0.000402
# Epoch [180/2000] Train Loss: 0.000422 | Val Loss: 0.000399
# Epoch [181/2000] Train Loss: 0.000433 | Val Loss: 0.000472
# Epoch [182/2000] Train Loss: 0.000428 | Val Loss: 0.000356
# Epoch [183/2000] Train Loss: 0.000425 | Val Loss: 0.000406
# Epoch [184/2000] Train Loss: 0.000436 | Val Loss: 0.000374
# Epoch [185/2000] Train Loss: 0.000433 | Val Loss: 0.000426
# Epoch [186/2000] Train Loss: 0.000429 | Val Loss: 0.000410
# Epoch [187/2000] Train Loss: 0.000433 | Val Loss: 0.000355
# Epoch [188/2000] Train Loss: 0.000429 | Val Loss: 0.000374
# Epoch [189/2000] Train Loss: 0.000440 | Val Loss: 0.000373
# Epoch [190/2000] Train Loss: 0.000445 | Val Loss: 0.000368
# Epoch [191/2000] Train Loss: 0.000432 | Val Loss: 0.000356
# Epoch [192/2000] Train Loss: 0.000427 | Val Loss: 0.000385
# Epoch [193/2000] Train Loss: 0.000437 | Val Loss: 0.000338
# Epoch [194/2000] Train Loss: 0.000430 | Val Loss: 0.000366
# Epoch [195/2000] Train Loss: 0.000426 | Val Loss: 0.000391
# Epoch [196/2000] Train Loss: 0.000441 | Val Loss: 0.000459
# Epoch [197/2000] Train Loss: 0.000425 | Val Loss: 0.000353
# Epoch [198/2000] Train Loss: 0.000421 | Val Loss: 0.000336
# Epoch [199/2000] Train Loss: 0.000428 | Val Loss: 0.000329
# Epoch [200/2000] Train Loss: 0.000435 | Val Loss: 0.000363
# Epoch [201/2000] Train Loss: 0.000431 | Val Loss: 0.000354
# Epoch [202/2000] Train Loss: 0.000430 | Val Loss: 0.000332
# Epoch [203/2000] Train Loss: 0.000424 | Val Loss: 0.000397
# Epoch [204/2000] Train Loss: 0.000441 | Val Loss: 0.000347
# Epoch [205/2000] Train Loss: 0.000435 | Val Loss: 0.000384
# Epoch [206/2000] Train Loss: 0.000426 | Val Loss: 0.000349
# Epoch [207/2000] Train Loss: 0.000428 | Val Loss: 0.000379
# Epoch [208/2000] Train Loss: 0.000435 | Val Loss: 0.000375
# Epoch [209/2000] Train Loss: 0.000429 | Val Loss: 0.000359
# Epoch [210/2000] Train Loss: 0.000409 | Val Loss: 0.000445
# Epoch [211/2000] Train Loss: 0.000448 | Val Loss: 0.000405
# Epoch [212/2000] Train Loss: 0.000420 | Val Loss: 0.000351
# Epoch [213/2000] Train Loss: 0.000422 | Val Loss: 0.000401
# Epoch [214/2000] Train Loss: 0.000426 | Val Loss: 0.000390
# Epoch [215/2000] Train Loss: 0.000438 | Val Loss: 0.000355
# Epoch [216/2000] Train Loss: 0.000434 | Val Loss: 0.000330
# Epoch [217/2000] Train Loss: 0.000427 | Val Loss: 0.000328
# Epoch [218/2000] Train Loss: 0.000431 | Val Loss: 0.000396
# Epoch [219/2000] Train Loss: 0.000422 | Val Loss: 0.000350
# Epoch [220/2000] Train Loss: 0.000445 | Val Loss: 0.000378
# Epoch [221/2000] Train Loss: 0.000428 | Val Loss: 0.000392
# Epoch [222/2000] Train Loss: 0.000429 | Val Loss: 0.000306
# Epoch [223/2000] Train Loss: 0.000429 | Val Loss: 0.000295
# Epoch [224/2000] Train Loss: 0.000440 | Val Loss: 0.000389
# Epoch [225/2000] Train Loss: 0.000426 | Val Loss: 0.000318
# Epoch [226/2000] Train Loss: 0.000432 | Val Loss: 0.000334
# Epoch [227/2000] Train Loss: 0.000431 | Val Loss: 0.000336
# Epoch [228/2000] Train Loss: 0.000436 | Val Loss: 0.000353
# Epoch [229/2000] Train Loss: 0.000434 | Val Loss: 0.000289
# Epoch [230/2000] Train Loss: 0.000425 | Val Loss: 0.000323
# Epoch [231/2000] Train Loss: 0.000422 | Val Loss: 0.000311
# Epoch [232/2000] Train Loss: 0.000423 | Val Loss: 0.000323
# Epoch [233/2000] Train Loss: 0.000441 | Val Loss: 0.000309
# Epoch [234/2000] Train Loss: 0.000422 | Val Loss: 0.000307
# Epoch [235/2000] Train Loss: 0.000430 | Val Loss: 0.000392
# Epoch [236/2000] Train Loss: 0.000435 | Val Loss: 0.000356
# Epoch [237/2000] Train Loss: 0.000424 | Val Loss: 0.000394
# Epoch [238/2000] Train Loss: 0.000433 | Val Loss: 0.000334
# Epoch [239/2000] Train Loss: 0.000427 | Val Loss: 0.000354
# Epoch [240/2000] Train Loss: 0.000425 | Val Loss: 0.000387
# Epoch [241/2000] Train Loss: 0.000420 | Val Loss: 0.000385
# Epoch [242/2000] Train Loss: 0.000436 | Val Loss: 0.000347
# Epoch [243/2000] Train Loss: 0.000431 | Val Loss: 0.000407
# Epoch [244/2000] Train Loss: 0.000417 | Val Loss: 0.000358
# Epoch [245/2000] Train Loss: 0.000429 | Val Loss: 0.000378
# Epoch [246/2000] Train Loss: 0.000439 | Val Loss: 0.000337
# Epoch [247/2000] Train Loss: 0.000432 | Val Loss: 0.000362
# Epoch [248/2000] Train Loss: 0.000434 | Val Loss: 0.000367
# Epoch [249/2000] Train Loss: 0.000437 | Val Loss: 0.000323
# Epoch [250/2000] Train Loss: 0.000436 | Val Loss: 0.000344
# Epoch [251/2000] Train Loss: 0.000429 | Val Loss: 0.000337
# Epoch [252/2000] Train Loss: 0.000416 | Val Loss: 0.000331
# Epoch [253/2000] Train Loss: 0.000434 | Val Loss: 0.000298
# Epoch [254/2000] Train Loss: 0.000422 | Val Loss: 0.000348
# Epoch [255/2000] Train Loss: 0.000429 | Val Loss: 0.000401
# Epoch [256/2000] Train Loss: 0.000429 | Val Loss: 0.000340
# Epoch [257/2000] Train Loss: 0.000415 | Val Loss: 0.000439
# Epoch [258/2000] Train Loss: 0.000411 | Val Loss: 0.000320
# Epoch [259/2000] Train Loss: 0.000433 | Val Loss: 0.000360
# Epoch [260/2000] Train Loss: 0.000424 | Val Loss: 0.000397
# Epoch [261/2000] Train Loss: 0.000427 | Val Loss: 0.000354
# Epoch [262/2000] Train Loss: 0.000430 | Val Loss: 0.000357
# Epoch [263/2000] Train Loss: 0.000425 | Val Loss: 0.000357
# Epoch [264/2000] Train Loss: 0.000423 | Val Loss: 0.000394
# Epoch [265/2000] Train Loss: 0.000439 | Val Loss: 0.000369
# Epoch [266/2000] Train Loss: 0.000429 | Val Loss: 0.000460
# Epoch [267/2000] Train Loss: 0.000419 | Val Loss: 0.000318
# Epoch [268/2000] Train Loss: 0.000428 | Val Loss: 0.000306
# Epoch [269/2000] Train Loss: 0.000430 | Val Loss: 0.000328
# Epoch [270/2000] Train Loss: 0.000431 | Val Loss: 0.000369
# Epoch [271/2000] Train Loss: 0.000439 | Val Loss: 0.000357
# Epoch [272/2000] Train Loss: 0.000434 | Val Loss: 0.000297
# Epoch [273/2000] Train Loss: 0.000435 | Val Loss: 0.000373
# Epoch [274/2000] Train Loss: 0.000419 | Val Loss: 0.000312
# Epoch [275/2000] Train Loss: 0.000428 | Val Loss: 0.000314
# Epoch [276/2000] Train Loss: 0.000434 | Val Loss: 0.000320
# Epoch [277/2000] Train Loss: 0.000420 | Val Loss: 0.000323
# Epoch [278/2000] Train Loss: 0.000428 | Val Loss: 0.000354
# Epoch [279/2000] Train Loss: 0.000426 | Val Loss: 0.000331
# Epoch [280/2000] Train Loss: 0.000434 | Val Loss: 0.000338
# Epoch [281/2000] Train Loss: 0.000414 | Val Loss: 0.000314
# Epoch [282/2000] Train Loss: 0.000429 | Val Loss: 0.000303
# Epoch [283/2000] Train Loss: 0.000429 | Val Loss: 0.000313
# Epoch [284/2000] Train Loss: 0.000435 | Val Loss: 0.000346
# Epoch [285/2000] Train Loss: 0.000435 | Val Loss: 0.000328
# Epoch [286/2000] Train Loss: 0.000427 | Val Loss: 0.000318
# Epoch [287/2000] Train Loss: 0.000423 | Val Loss: 0.000314
# Epoch [288/2000] Train Loss: 0.000431 | Val Loss: 0.000306
# Epoch [289/2000] Train Loss: 0.000426 | Val Loss: 0.000277
# Epoch [290/2000] Train Loss: 0.000418 | Val Loss: 0.000285
# Epoch [291/2000] Train Loss: 0.000421 | Val Loss: 0.000278
# Epoch [292/2000] Train Loss: 0.000430 | Val Loss: 0.000351
# Epoch [293/2000] Train Loss: 0.000436 | Val Loss: 0.000362
# Epoch [294/2000] Train Loss: 0.000437 | Val Loss: 0.000303
# Epoch [295/2000] Train Loss: 0.000419 | Val Loss: 0.000314
# Epoch [296/2000] Train Loss: 0.000421 | Val Loss: 0.000280
# Epoch [297/2000] Train Loss: 0.000428 | Val Loss: 0.000292
# Epoch [298/2000] Train Loss: 0.000430 | Val Loss: 0.000285
# Epoch [299/2000] Train Loss: 0.000420 | Val Loss: 0.000315
# Epoch [300/2000] Train Loss: 0.000427 | Val Loss: 0.000282
# Epoch [301/2000] Train Loss: 0.000444 | Val Loss: 0.000288
# Epoch [302/2000] Train Loss: 0.000424 | Val Loss: 0.000283
# Epoch [303/2000] Train Loss: 0.000428 | Val Loss: 0.000301
# Epoch [304/2000] Train Loss: 0.000433 | Val Loss: 0.000314
# Epoch [305/2000] Train Loss: 0.000445 | Val Loss: 0.000313
# Epoch [306/2000] Train Loss: 0.000413 | Val Loss: 0.000339
# Epoch [307/2000] Train Loss: 0.000431 | Val Loss: 0.000318
# Epoch [308/2000] Train Loss: 0.000434 | Val Loss: 0.000280
# Epoch [309/2000] Train Loss: 0.000421 | Val Loss: 0.000298
# Epoch [310/2000] Train Loss: 0.000421 | Val Loss: 0.000351
# Epoch [311/2000] Train Loss: 0.000433 | Val Loss: 0.000359
# Epoch [312/2000] Train Loss: 0.000430 | Val Loss: 0.000307
# Epoch [313/2000] Train Loss: 0.000423 | Val Loss: 0.000372
# Epoch [314/2000] Train Loss: 0.000433 | Val Loss: 0.000307
# Epoch [315/2000] Train Loss: 0.000425 | Val Loss: 0.000355
# Epoch [316/2000] Train Loss: 0.000421 | Val Loss: 0.000312
# Epoch [317/2000] Train Loss: 0.000431 | Val Loss: 0.000359
# Epoch [318/2000] Train Loss: 0.000425 | Val Loss: 0.000312
# Epoch [319/2000] Train Loss: 0.000423 | Val Loss: 0.000332
# Epoch [320/2000] Train Loss: 0.000423 | Val Loss: 0.000397
# Epoch [321/2000] Train Loss: 0.000423 | Val Loss: 0.000301
# Epoch [322/2000] Train Loss: 0.000431 | Val Loss: 0.000336
# Epoch [323/2000] Train Loss: 0.000424 | Val Loss: 0.000330
# Epoch [324/2000] Train Loss: 0.000421 | Val Loss: 0.000314
# Epoch [325/2000] Train Loss: 0.000431 | Val Loss: 0.000281
# Epoch [326/2000] Train Loss: 0.000423 | Val Loss: 0.000327
# Epoch [327/2000] Train Loss: 0.000439 | Val Loss: 0.000289
# Epoch [328/2000] Train Loss: 0.000434 | Val Loss: 0.000342
# Epoch [329/2000] Train Loss: 0.000423 | Val Loss: 0.000347
# Epoch [330/2000] Train Loss: 0.000429 | Val Loss: 0.000315
# Epoch [331/2000] Train Loss: 0.000433 | Val Loss: 0.000347
# Epoch [332/2000] Train Loss: 0.000436 | Val Loss: 0.000304
# Epoch [333/2000] Train Loss: 0.000424 | Val Loss: 0.000329
# Epoch [334/2000] Train Loss: 0.000423 | Val Loss: 0.000400
# Epoch [335/2000] Train Loss: 0.000425 | Val Loss: 0.000315
# Epoch [336/2000] Train Loss: 0.000416 | Val Loss: 0.000348
# Epoch [337/2000] Train Loss: 0.000432 | Val Loss: 0.000343
# Epoch [338/2000] Train Loss: 0.000436 | Val Loss: 0.000262
# Epoch [339/2000] Train Loss: 0.000418 | Val Loss: 0.000313
# Epoch [340/2000] Train Loss: 0.000429 | Val Loss: 0.000309
# Epoch [341/2000] Train Loss: 0.000435 | Val Loss: 0.000310
# Epoch [342/2000] Train Loss: 0.000415 | Val Loss: 0.000300
# Epoch [343/2000] Train Loss: 0.000421 | Val Loss: 0.000290
# Epoch [344/2000] Train Loss: 0.000435 | Val Loss: 0.000344
# Epoch [345/2000] Train Loss: 0.000428 | Val Loss: 0.000288
# Epoch [346/2000] Train Loss: 0.000429 | Val Loss: 0.000305
# Epoch [347/2000] Train Loss: 0.000430 | Val Loss: 0.000298
# Epoch [348/2000] Train Loss: 0.000425 | Val Loss: 0.000447
# Epoch [349/2000] Train Loss: 0.000437 | Val Loss: 0.000293
# Epoch [350/2000] Train Loss: 0.000428 | Val Loss: 0.000373
# Epoch [351/2000] Train Loss: 0.000434 | Val Loss: 0.000319
# Epoch [352/2000] Train Loss: 0.000422 | Val Loss: 0.000365
# Epoch [353/2000] Train Loss: 0.000423 | Val Loss: 0.000302
# Epoch [354/2000] Train Loss: 0.000422 | Val Loss: 0.000300
# Epoch [355/2000] Train Loss: 0.000428 | Val Loss: 0.000316
# Epoch [356/2000] Train Loss: 0.000419 | Val Loss: 0.000278
# Epoch [357/2000] Train Loss: 0.000413 | Val Loss: 0.000365
# Epoch [358/2000] Train Loss: 0.000428 | Val Loss: 0.000315
# Epoch [359/2000] Train Loss: 0.000420 | Val Loss: 0.000345
# Epoch [360/2000] Train Loss: 0.000418 | Val Loss: 0.000274
# Epoch [361/2000] Train Loss: 0.000421 | Val Loss: 0.000277
# Epoch [362/2000] Train Loss: 0.000418 | Val Loss: 0.000295
# Epoch [363/2000] Train Loss: 0.000425 | Val Loss: 0.000308
# Epoch [364/2000] Train Loss: 0.000412 | Val Loss: 0.000323
# Epoch [365/2000] Train Loss: 0.000427 | Val Loss: 0.000333
# Epoch [366/2000] Train Loss: 0.000427 | Val Loss: 0.000294
# Epoch [367/2000] Train Loss: 0.000431 | Val Loss: 0.000313
# Epoch [368/2000] Train Loss: 0.000424 | Val Loss: 0.000331
# Epoch [369/2000] Train Loss: 0.000422 | Val Loss: 0.000314
# Epoch [370/2000] Train Loss: 0.000419 | Val Loss: 0.000300
# Epoch [371/2000] Train Loss: 0.000418 | Val Loss: 0.000294
# Epoch [372/2000] Train Loss: 0.000424 | Val Loss: 0.000353
# Epoch [373/2000] Train Loss: 0.000432 | Val Loss: 0.000315
# Epoch [374/2000] Train Loss: 0.000423 | Val Loss: 0.000287
# Epoch [375/2000] Train Loss: 0.000425 | Val Loss: 0.000268
# Epoch [376/2000] Train Loss: 0.000417 | Val Loss: 0.000290
# Epoch [377/2000] Train Loss: 0.000428 | Val Loss: 0.000311
# Epoch [378/2000] Train Loss: 0.000432 | Val Loss: 0.000320
# Epoch [379/2000] Train Loss: 0.000430 | Val Loss: 0.000297
# Epoch [380/2000] Train Loss: 0.000423 | Val Loss: 0.000287
# Epoch [381/2000] Train Loss: 0.000431 | Val Loss: 0.000312
# Epoch [382/2000] Train Loss: 0.000415 | Val Loss: 0.000308
# Epoch [383/2000] Train Loss: 0.000430 | Val Loss: 0.000311
# Epoch [384/2000] Train Loss: 0.000424 | Val Loss: 0.000303
# Epoch [385/2000] Train Loss: 0.000421 | Val Loss: 0.000291
# Epoch [386/2000] Train Loss: 0.000434 | Val Loss: 0.000318
# Epoch [387/2000] Train Loss: 0.000415 | Val Loss: 0.000259
# Epoch [388/2000] Train Loss: 0.000423 | Val Loss: 0.000293
# Epoch [389/2000] Train Loss: 0.000439 | Val Loss: 0.000289
# Epoch [390/2000] Train Loss: 0.000426 | Val Loss: 0.000317
# Epoch [391/2000] Train Loss: 0.000420 | Val Loss: 0.000292
# Epoch [392/2000] Train Loss: 0.000436 | Val Loss: 0.000313
# Epoch [393/2000] Train Loss: 0.000431 | Val Loss: 0.000279
# Epoch [394/2000] Train Loss: 0.000416 | Val Loss: 0.000279
# Epoch [395/2000] Train Loss: 0.000415 | Val Loss: 0.000305
# Epoch [396/2000] Train Loss: 0.000422 | Val Loss: 0.000330
# Epoch [397/2000] Train Loss: 0.000431 | Val Loss: 0.000342
# Epoch [398/2000] Train Loss: 0.000417 | Val Loss: 0.000350
# Epoch [399/2000] Train Loss: 0.000421 | Val Loss: 0.000260
# Epoch [400/2000] Train Loss: 0.000417 | Val Loss: 0.000346
# Epoch [401/2000] Train Loss: 0.000414 | Val Loss: 0.000306
# Epoch [402/2000] Train Loss: 0.000420 | Val Loss: 0.000355
# Epoch [403/2000] Train Loss: 0.000419 | Val Loss: 0.000317
# Epoch [404/2000] Train Loss: 0.000431 | Val Loss: 0.000300
# Epoch [405/2000] Train Loss: 0.000419 | Val Loss: 0.000380
# Epoch [406/2000] Train Loss: 0.000419 | Val Loss: 0.000317
# Epoch [407/2000] Train Loss: 0.000424 | Val Loss: 0.000382
# Epoch [408/2000] Train Loss: 0.000433 | Val Loss: 0.000308
# Epoch [409/2000] Train Loss: 0.000425 | Val Loss: 0.000303
# Epoch [410/2000] Train Loss: 0.000431 | Val Loss: 0.000313
# Epoch [411/2000] Train Loss: 0.000426 | Val Loss: 0.000292
# Epoch [412/2000] Train Loss: 0.000426 | Val Loss: 0.000308
# Epoch [413/2000] Train Loss: 0.000428 | Val Loss: 0.000308
# Epoch [414/2000] Train Loss: 0.000413 | Val Loss: 0.000269
# Epoch [415/2000] Train Loss: 0.000435 | Val Loss: 0.000342
# Epoch [416/2000] Train Loss: 0.000420 | Val Loss: 0.000351
# Epoch [417/2000] Train Loss: 0.000418 | Val Loss: 0.000308
# Epoch [418/2000] Train Loss: 0.000427 | Val Loss: 0.000310
# Epoch [419/2000] Train Loss: 0.000427 | Val Loss: 0.000279
# Epoch [420/2000] Train Loss: 0.000418 | Val Loss: 0.000283
# Epoch [421/2000] Train Loss: 0.000417 | Val Loss: 0.000273
# Epoch [422/2000] Train Loss: 0.000420 | Val Loss: 0.000278
# Epoch [423/2000] Train Loss: 0.000416 | Val Loss: 0.000317
# Epoch [424/2000] Train Loss: 0.000427 | Val Loss: 0.000288
# Epoch [425/2000] Train Loss: 0.000440 | Val Loss: 0.000277
# Epoch [426/2000] Train Loss: 0.000426 | Val Loss: 0.000295
# Epoch [427/2000] Train Loss: 0.000421 | Val Loss: 0.000397
# Epoch [428/2000] Train Loss: 0.000431 | Val Loss: 0.000306
# Epoch [429/2000] Train Loss: 0.000428 | Val Loss: 0.000268
# Epoch [430/2000] Train Loss: 0.000411 | Val Loss: 0.000255
# Epoch [431/2000] Train Loss: 0.000431 | Val Loss: 0.000259
# Epoch [432/2000] Train Loss: 0.000431 | Val Loss: 0.000368
# Epoch [433/2000] Train Loss: 0.000423 | Val Loss: 0.000348
# Epoch [434/2000] Train Loss: 0.000416 | Val Loss: 0.000330
# Epoch [435/2000] Train Loss: 0.000420 | Val Loss: 0.000269
# Epoch [436/2000] Train Loss: 0.000433 | Val Loss: 0.000287
# Epoch [437/2000] Train Loss: 0.000423 | Val Loss: 0.000321
# Epoch [438/2000] Train Loss: 0.000424 | Val Loss: 0.000313
# Epoch [439/2000] Train Loss: 0.000428 | Val Loss: 0.000300
# Epoch [440/2000] Train Loss: 0.000422 | Val Loss: 0.000266
# Epoch [441/2000] Train Loss: 0.000419 | Val Loss: 0.000289
# Epoch [442/2000] Train Loss: 0.000430 | Val Loss: 0.000337
# Epoch [443/2000] Train Loss: 0.000418 | Val Loss: 0.000288
# Epoch [444/2000] Train Loss: 0.000416 | Val Loss: 0.000392
# Epoch [445/2000] Train Loss: 0.000420 | Val Loss: 0.000288
# Epoch [446/2000] Train Loss: 0.000422 | Val Loss: 0.000380
# Epoch [447/2000] Train Loss: 0.000426 | Val Loss: 0.000296
# Epoch [448/2000] Train Loss: 0.000426 | Val Loss: 0.000284
# Epoch [449/2000] Train Loss: 0.000418 | Val Loss: 0.000352
# Epoch [450/2000] Train Loss: 0.000423 | Val Loss: 0.000354
# Epoch [451/2000] Train Loss: 0.000424 | Val Loss: 0.000309
# Epoch [452/2000] Train Loss: 0.000423 | Val Loss: 0.000355
# Epoch [453/2000] Train Loss: 0.000418 | Val Loss: 0.000339
# Epoch [454/2000] Train Loss: 0.000418 | Val Loss: 0.000312
# Epoch [455/2000] Train Loss: 0.000434 | Val Loss: 0.000347
# Epoch [456/2000] Train Loss: 0.000418 | Val Loss: 0.000278
# Epoch [457/2000] Train Loss: 0.000431 | Val Loss: 0.000360
# Epoch [458/2000] Train Loss: 0.000430 | Val Loss: 0.000335
# Epoch [459/2000] Train Loss: 0.000431 | Val Loss: 0.000288
# Epoch [460/2000] Train Loss: 0.000413 | Val Loss: 0.000344
# Epoch [461/2000] Train Loss: 0.000429 | Val Loss: 0.000309
# Epoch [462/2000] Train Loss: 0.000417 | Val Loss: 0.000299
# Epoch [463/2000] Train Loss: 0.000417 | Val Loss: 0.000281
# Epoch [464/2000] Train Loss: 0.000416 | Val Loss: 0.000323
# Epoch [465/2000] Train Loss: 0.000420 | Val Loss: 0.000314
# Epoch [466/2000] Train Loss: 0.000423 | Val Loss: 0.000257
# Epoch [467/2000] Train Loss: 0.000427 | Val Loss: 0.000337
# Epoch [468/2000] Train Loss: 0.000431 | Val Loss: 0.000340
# Epoch [469/2000] Train Loss: 0.000408 | Val Loss: 0.000286
# Epoch [470/2000] Train Loss: 0.000427 | Val Loss: 0.000366
# Epoch [471/2000] Train Loss: 0.000425 | Val Loss: 0.000277
# Epoch [472/2000] Train Loss: 0.000421 | Val Loss: 0.000471
# Epoch [473/2000] Train Loss: 0.000429 | Val Loss: 0.000371
# Epoch [474/2000] Train Loss: 0.000431 | Val Loss: 0.000326
# Epoch [475/2000] Train Loss: 0.000424 | Val Loss: 0.000386
# Epoch [476/2000] Train Loss: 0.000425 | Val Loss: 0.000313
# Epoch [477/2000] Train Loss: 0.000437 | Val Loss: 0.000279
# Epoch [478/2000] Train Loss: 0.000427 | Val Loss: 0.000320
# Epoch [479/2000] Train Loss: 0.000424 | Val Loss: 0.000320
# Epoch [480/2000] Train Loss: 0.000417 | Val Loss: 0.000294
# Epoch [481/2000] Train Loss: 0.000426 | Val Loss: 0.000284
# Epoch [482/2000] Train Loss: 0.000420 | Val Loss: 0.000325
# Epoch [483/2000] Train Loss: 0.000429 | Val Loss: 0.000296
# Epoch [484/2000] Train Loss: 0.000423 | Val Loss: 0.000310
# Epoch [485/2000] Train Loss: 0.000429 | Val Loss: 0.000275
# Epoch [486/2000] Train Loss: 0.000424 | Val Loss: 0.000297
# Epoch [487/2000] Train Loss: 0.000419 | Val Loss: 0.000288
# Epoch [488/2000] Train Loss: 0.000428 | Val Loss: 0.000280
# Epoch [489/2000] Train Loss: 0.000433 | Val Loss: 0.000276
# Epoch [490/2000] Train Loss: 0.000427 | Val Loss: 0.000313
# Epoch [491/2000] Train Loss: 0.000425 | Val Loss: 0.000271
# Epoch [492/2000] Train Loss: 0.000427 | Val Loss: 0.000328
# Epoch [493/2000] Train Loss: 0.000433 | Val Loss: 0.000318
# Epoch [494/2000] Train Loss: 0.000416 | Val Loss: 0.000296
# Epoch [495/2000] Train Loss: 0.000407 | Val Loss: 0.000286
# Epoch [496/2000] Train Loss: 0.000413 | Val Loss: 0.000333
# Epoch [497/2000] Train Loss: 0.000433 | Val Loss: 0.000277
# Epoch [498/2000] Train Loss: 0.000424 | Val Loss: 0.000294
# Epoch [499/2000] Train Loss: 0.000427 | Val Loss: 0.000356
# Epoch [500/2000] Train Loss: 0.000426 | Val Loss: 0.000287
# Epoch [501/2000] Train Loss: 0.000391 | Val Loss: 0.000332
# Epoch [502/2000] Train Loss: 0.000412 | Val Loss: 0.000382
# Epoch [503/2000] Train Loss: 0.000418 | Val Loss: 0.000277
# Epoch [504/2000] Train Loss: 0.000425 | Val Loss: 0.000262
# Epoch [505/2000] Train Loss: 0.000418 | Val Loss: 0.000301
# Epoch [506/2000] Train Loss: 0.000412 | Val Loss: 0.000390
# Epoch [507/2000] Train Loss: 0.000426 | Val Loss: 0.000333
# Epoch [508/2000] Train Loss: 0.000418 | Val Loss: 0.000280
# Epoch [509/2000] Train Loss: 0.000434 | Val Loss: 0.000282
# Epoch [510/2000] Train Loss: 0.000418 | Val Loss: 0.000308
# Epoch [511/2000] Train Loss: 0.000413 | Val Loss: 0.000361
# Epoch [512/2000] Train Loss: 0.000421 | Val Loss: 0.000325
# Epoch [513/2000] Train Loss: 0.000424 | Val Loss: 0.000286
# Epoch [514/2000] Train Loss: 0.000416 | Val Loss: 0.000297
# Epoch [515/2000] Train Loss: 0.000418 | Val Loss: 0.000305
# Epoch [516/2000] Train Loss: 0.000421 | Val Loss: 0.000312
# Epoch [517/2000] Train Loss: 0.000414 | Val Loss: 0.000298
# Epoch [518/2000] Train Loss: 0.000428 | Val Loss: 0.000363
# Epoch [519/2000] Train Loss: 0.000427 | Val Loss: 0.000334
# Epoch [520/2000] Train Loss: 0.000427 | Val Loss: 0.000293
# Epoch [521/2000] Train Loss: 0.000417 | Val Loss: 0.000265
# Epoch [522/2000] Train Loss: 0.000418 | Val Loss: 0.000273
# Epoch [523/2000] Train Loss: 0.000429 | Val Loss: 0.000304
# Epoch [524/2000] Train Loss: 0.000412 | Val Loss: 0.000347
# Epoch [525/2000] Train Loss: 0.000422 | Val Loss: 0.000314
# Epoch [526/2000] Train Loss: 0.000424 | Val Loss: 0.000312
# Epoch [527/2000] Train Loss: 0.000432 | Val Loss: 0.000320
# Epoch [528/2000] Train Loss: 0.000417 | Val Loss: 0.000402
# Epoch [529/2000] Train Loss: 0.000427 | Val Loss: 0.000310
# Epoch [530/2000] Train Loss: 0.000427 | Val Loss: 0.000287
# Epoch [531/2000] Train Loss: 0.000422 | Val Loss: 0.000328
# Epoch [532/2000] Train Loss: 0.000424 | Val Loss: 0.000296
# Epoch [533/2000] Train Loss: 0.000423 | Val Loss: 0.000365
# Epoch [534/2000] Train Loss: 0.000427 | Val Loss: 0.000453
# Epoch [535/2000] Train Loss: 0.000429 | Val Loss: 0.000310
# Epoch [536/2000] Train Loss: 0.000431 | Val Loss: 0.000347
# Epoch [537/2000] Train Loss: 0.000443 | Val Loss: 0.000319
# Epoch [538/2000] Train Loss: 0.000406 | Val Loss: 0.000391
# Epoch [539/2000] Train Loss: 0.000434 | Val Loss: 0.000316
# Epoch [540/2000] Train Loss: 0.000429 | Val Loss: 0.000339
# Epoch [541/2000] Train Loss: 0.000428 | Val Loss: 0.000327
# Epoch [542/2000] Train Loss: 0.000415 | Val Loss: 0.000336
# Epoch [543/2000] Train Loss: 0.000410 | Val Loss: 0.000417
# Epoch [544/2000] Train Loss: 0.000421 | Val Loss: 0.000338
# Epoch [545/2000] Train Loss: 0.000421 | Val Loss: 0.000313
# Epoch [546/2000] Train Loss: 0.000433 | Val Loss: 0.000297
# Epoch [547/2000] Train Loss: 0.000433 | Val Loss: 0.000352
# Epoch [548/2000] Train Loss: 0.000428 | Val Loss: 0.000334
# Epoch [549/2000] Train Loss: 0.000424 | Val Loss: 0.000317
# Epoch [550/2000] Train Loss: 0.000417 | Val Loss: 0.000405
# Epoch [551/2000] Train Loss: 0.000435 | Val Loss: 0.000279
# Epoch [552/2000] Train Loss: 0.000426 | Val Loss: 0.000340
# Epoch [553/2000] Train Loss: 0.000429 | Val Loss: 0.000341
# Epoch [554/2000] Train Loss: 0.000432 | Val Loss: 0.000404
# Epoch [555/2000] Train Loss: 0.000414 | Val Loss: 0.000298
# Epoch [556/2000] Train Loss: 0.000419 | Val Loss: 0.000282
# Epoch [557/2000] Train Loss: 0.000409 | Val Loss: 0.000345
# Epoch [558/2000] Train Loss: 0.000417 | Val Loss: 0.000286
# Epoch [559/2000] Train Loss: 0.000419 | Val Loss: 0.000280
# Epoch [560/2000] Train Loss: 0.000425 | Val Loss: 0.000340
# Epoch [561/2000] Train Loss: 0.000417 | Val Loss: 0.000308
# Epoch [562/2000] Train Loss: 0.000427 | Val Loss: 0.000268
# Epoch [563/2000] Train Loss: 0.000419 | Val Loss: 0.000325
# Epoch [564/2000] Train Loss: 0.000423 | Val Loss: 0.000254
# Epoch [565/2000] Train Loss: 0.000442 | Val Loss: 0.000346
# Epoch [566/2000] Train Loss: 0.000416 | Val Loss: 0.000354
# Epoch [567/2000] Train Loss: 0.000421 | Val Loss: 0.000294
# Epoch [568/2000] Train Loss: 0.000425 | Val Loss: 0.000422
# Epoch [569/2000] Train Loss: 0.000429 | Val Loss: 0.000271
# Epoch [570/2000] Train Loss: 0.000429 | Val Loss: 0.000271
# Epoch [571/2000] Train Loss: 0.000423 | Val Loss: 0.000320
# Epoch [572/2000] Train Loss: 0.000419 | Val Loss: 0.000276
# Epoch [573/2000] Train Loss: 0.000429 | Val Loss: 0.000304
# Epoch [574/2000] Train Loss: 0.000422 | Val Loss: 0.000263
# Epoch [575/2000] Train Loss: 0.000417 | Val Loss: 0.000256
# Epoch [576/2000] Train Loss: 0.000431 | Val Loss: 0.000293
# Epoch [577/2000] Train Loss: 0.000422 | Val Loss: 0.000292
# Epoch [578/2000] Train Loss: 0.000433 | Val Loss: 0.000586
# Epoch [579/2000] Train Loss: 0.000419 | Val Loss: 0.000283
# Epoch [580/2000] Train Loss: 0.000420 | Val Loss: 0.000322
# Epoch [581/2000] Train Loss: 0.000412 | Val Loss: 0.000355
# Epoch [582/2000] Train Loss: 0.000423 | Val Loss: 0.000310
# Epoch [583/2000] Train Loss: 0.000421 | Val Loss: 0.000320
# Epoch [584/2000] Train Loss: 0.000437 | Val Loss: 0.000342
# Epoch [585/2000] Train Loss: 0.000424 | Val Loss: 0.000255
# Epoch [586/2000] Train Loss: 0.000416 | Val Loss: 0.000297
# Epoch [587/2000] Train Loss: 0.000422 | Val Loss: 0.000295
# Epoch [588/2000] Train Loss: 0.000418 | Val Loss: 0.000279
# Epoch [589/2000] Train Loss: 0.000413 | Val Loss: 0.000301
# Epoch [590/2000] Train Loss: 0.000423 | Val Loss: 0.000290
# Epoch [591/2000] Train Loss: 0.000427 | Val Loss: 0.000272
# Epoch [592/2000] Train Loss: 0.000421 | Val Loss: 0.000312
# Epoch [593/2000] Train Loss: 0.000425 | Val Loss: 0.000285
# Epoch [594/2000] Train Loss: 0.000428 | Val Loss: 0.000404
# Epoch [595/2000] Train Loss: 0.000437 | Val Loss: 0.000324
# Epoch [596/2000] Train Loss: 0.000426 | Val Loss: 0.000269
# Epoch [597/2000] Train Loss: 0.000414 | Val Loss: 0.000281
# Epoch [598/2000] Train Loss: 0.000422 | Val Loss: 0.000317
# Epoch [599/2000] Train Loss: 0.000407 | Val Loss: 0.000307
# Epoch [600/2000] Train Loss: 0.000423 | Val Loss: 0.000314
# Epoch [601/2000] Train Loss: 0.000422 | Val Loss: 0.000316
# Epoch [602/2000] Train Loss: 0.000414 | Val Loss: 0.000277
# Epoch [603/2000] Train Loss: 0.000423 | Val Loss: 0.000300
# Epoch [604/2000] Train Loss: 0.000429 | Val Loss: 0.000426
# Epoch [605/2000] Train Loss: 0.000424 | Val Loss: 0.000300
# Epoch [606/2000] Train Loss: 0.000423 | Val Loss: 0.000331
# Epoch [607/2000] Train Loss: 0.000422 | Val Loss: 0.000268
# Epoch [608/2000] Train Loss: 0.000413 | Val Loss: 0.000333
# Epoch [609/2000] Train Loss: 0.000419 | Val Loss: 0.000358
# Epoch [610/2000] Train Loss: 0.000395 | Val Loss: 0.000324
# Epoch [611/2000] Train Loss: 0.000420 | Val Loss: 0.000292
# Epoch [612/2000] Train Loss: 0.000425 | Val Loss: 0.000341
# Epoch [613/2000] Train Loss: 0.000423 | Val Loss: 0.000395
# Epoch [614/2000] Train Loss: 0.000422 | Val Loss: 0.000327
# Epoch [615/2000] Train Loss: 0.000422 | Val Loss: 0.000371
# Epoch [616/2000] Train Loss: 0.000425 | Val Loss: 0.000350
# Epoch [617/2000] Train Loss: 0.000428 | Val Loss: 0.000290
# Epoch [618/2000] Train Loss: 0.000415 | Val Loss: 0.000316
# Epoch [619/2000] Train Loss: 0.000429 | Val Loss: 0.000391
# Epoch [620/2000] Train Loss: 0.000410 | Val Loss: 0.000307
# Epoch [621/2000] Train Loss: 0.000436 | Val Loss: 0.000358
# Epoch [622/2000] Train Loss: 0.000434 | Val Loss: 0.000315
# Epoch [623/2000] Train Loss: 0.000418 | Val Loss: 0.000298
# Epoch [624/2000] Train Loss: 0.000430 | Val Loss: 0.000336
# Epoch [625/2000] Train Loss: 0.000422 | Val Loss: 0.000366
# Epoch [626/2000] Train Loss: 0.000415 | Val Loss: 0.000326
# Epoch [627/2000] Train Loss: 0.000429 | Val Loss: 0.000294
# Epoch [628/2000] Train Loss: 0.000410 | Val Loss: 0.000300
# Epoch [629/2000] Train Loss: 0.000427 | Val Loss: 0.000307
# Epoch [630/2000] Train Loss: 0.000417 | Val Loss: 0.000324
# Epoch [631/2000] Train Loss: 0.000418 | Val Loss: 0.000280
# Epoch [632/2000] Train Loss: 0.000423 | Val Loss: 0.000302
# Epoch [633/2000] Train Loss: 0.000415 | Val Loss: 0.000323
# Epoch [634/2000] Train Loss: 0.000418 | Val Loss: 0.000332
# Epoch [635/2000] Train Loss: 0.000413 | Val Loss: 0.000293
# Epoch [636/2000] Train Loss: 0.000418 | Val Loss: 0.000306
# Epoch [637/2000] Train Loss: 0.000424 | Val Loss: 0.000313
# Epoch [638/2000] Train Loss: 0.000424 | Val Loss: 0.000270
# Epoch [639/2000] Train Loss: 0.000419 | Val Loss: 0.000259
# Epoch [640/2000] Train Loss: 0.000425 | Val Loss: 0.000260
# Epoch [641/2000] Train Loss: 0.000419 | Val Loss: 0.000263
# Epoch [642/2000] Train Loss: 0.000430 | Val Loss: 0.000346
# Epoch [643/2000] Train Loss: 0.000419 | Val Loss: 0.000411
# Epoch [644/2000] Train Loss: 0.000412 | Val Loss: 0.000334
# Epoch [645/2000] Train Loss: 0.000422 | Val Loss: 0.000304
# Epoch [646/2000] Train Loss: 0.000422 | Val Loss: 0.000265
# Epoch [647/2000] Train Loss: 0.000430 | Val Loss: 0.000279
# Epoch [648/2000] Train Loss: 0.000436 | Val Loss: 0.000277
# Epoch [649/2000] Train Loss: 0.000416 | Val Loss: 0.000286
# Epoch [650/2000] Train Loss: 0.000420 | Val Loss: 0.000321
# Epoch [651/2000] Train Loss: 0.000419 | Val Loss: 0.000299
# Epoch [652/2000] Train Loss: 0.000416 | Val Loss: 0.000348
# Epoch [653/2000] Train Loss: 0.000418 | Val Loss: 0.000288
# Epoch [654/2000] Train Loss: 0.000423 | Val Loss: 0.000290
# Epoch [655/2000] Train Loss: 0.000402 | Val Loss: 0.000357
# Epoch [656/2000] Train Loss: 0.000433 | Val Loss: 0.000303
# Epoch [657/2000] Train Loss: 0.000428 | Val Loss: 0.000299
# Epoch [658/2000] Train Loss: 0.000416 | Val Loss: 0.000273
# Epoch [659/2000] Train Loss: 0.000417 | Val Loss: 0.000284
# Epoch [660/2000] Train Loss: 0.000408 | Val Loss: 0.000319
# Epoch [661/2000] Train Loss: 0.000419 | Val Loss: 0.000385
# Epoch [662/2000] Train Loss: 0.000423 | Val Loss: 0.000305
# Epoch [663/2000] Train Loss: 0.000426 | Val Loss: 0.000316
# Epoch [664/2000] Train Loss: 0.000421 | Val Loss: 0.000282
# Epoch [665/2000] Train Loss: 0.000421 | Val Loss: 0.000292
# Epoch [666/2000] Train Loss: 0.000424 | Val Loss: 0.000285
# Epoch [667/2000] Train Loss: 0.000419 | Val Loss: 0.000500
# Epoch [668/2000] Train Loss: 0.000418 | Val Loss: 0.000305
# Epoch [669/2000] Train Loss: 0.000429 | Val Loss: 0.000336
# Epoch [670/2000] Train Loss: 0.000416 | Val Loss: 0.000332
# Epoch [671/2000] Train Loss: 0.000421 | Val Loss: 0.000350
# Epoch [672/2000] Train Loss: 0.000405 | Val Loss: 0.000306
# Epoch [673/2000] Train Loss: 0.000423 | Val Loss: 0.000325
# Epoch [674/2000] Train Loss: 0.000417 | Val Loss: 0.000287
# Epoch [675/2000] Train Loss: 0.000418 | Val Loss: 0.000272
# Epoch [676/2000] Train Loss: 0.000433 | Val Loss: 0.000306
# Epoch [677/2000] Train Loss: 0.000416 | Val Loss: 0.000309
# Epoch [678/2000] Train Loss: 0.000424 | Val Loss: 0.000333
# Epoch [679/2000] Train Loss: 0.000424 | Val Loss: 0.000321
# Epoch [680/2000] Train Loss: 0.000414 | Val Loss: 0.000328
# Epoch [681/2000] Train Loss: 0.000420 | Val Loss: 0.000281
# Epoch [682/2000] Train Loss: 0.000422 | Val Loss: 0.000261
# Epoch [683/2000] Train Loss: 0.000425 | Val Loss: 0.000361
# Epoch [684/2000] Train Loss: 0.000422 | Val Loss: 0.000308
# Epoch [685/2000] Train Loss: 0.000415 | Val Loss: 0.000275
# Epoch [686/2000] Train Loss: 0.000415 | Val Loss: 0.000283
# Epoch [687/2000] Train Loss: 0.000417 | Val Loss: 0.000292
# Epoch [688/2000] Train Loss: 0.000429 | Val Loss: 0.000300
# Epoch [689/2000] Train Loss: 0.000408 | Val Loss: 0.000285
# Epoch [690/2000] Train Loss: 0.000422 | Val Loss: 0.000297
# Epoch [691/2000] Train Loss: 0.000427 | Val Loss: 0.000282
# Epoch [692/2000] Train Loss: 0.000424 | Val Loss: 0.000277
# Epoch [693/2000] Train Loss: 0.000413 | Val Loss: 0.000281
# Epoch [694/2000] Train Loss: 0.000411 | Val Loss: 0.000313
# Epoch [695/2000] Train Loss: 0.000420 | Val Loss: 0.000313
# Epoch [696/2000] Train Loss: 0.000421 | Val Loss: 0.000273
# Epoch [697/2000] Train Loss: 0.000425 | Val Loss: 0.000280
# Epoch [698/2000] Train Loss: 0.000421 | Val Loss: 0.000318
# Epoch [699/2000] Train Loss: 0.000416 | Val Loss: 0.000296
# Epoch [700/2000] Train Loss: 0.000421 | Val Loss: 0.000307
# Epoch [701/2000] Train Loss: 0.000419 | Val Loss: 0.000263
# Epoch [702/2000] Train Loss: 0.000418 | Val Loss: 0.000287
# Epoch [703/2000] Train Loss: 0.000418 | Val Loss: 0.000296
# Epoch [704/2000] Train Loss: 0.000413 | Val Loss: 0.000283
# Epoch [705/2000] Train Loss: 0.000418 | Val Loss: 0.000361
# Epoch [706/2000] Train Loss: 0.000417 | Val Loss: 0.000284
# Epoch [707/2000] Train Loss: 0.000413 | Val Loss: 0.000273
# Epoch [708/2000] Train Loss: 0.000418 | Val Loss: 0.000299
# Epoch [709/2000] Train Loss: 0.000430 | Val Loss: 0.000258
# Epoch [710/2000] Train Loss: 0.000422 | Val Loss: 0.000276
# Epoch [711/2000] Train Loss: 0.000408 | Val Loss: 0.000317
# Epoch [712/2000] Train Loss: 0.000421 | Val Loss: 0.000279
# Epoch [713/2000] Train Loss: 0.000424 | Val Loss: 0.000307
# Epoch [714/2000] Train Loss: 0.000423 | Val Loss: 0.000303
# Early stopping
# Best Val Loss: 0.000254309580611789

# %%
# 16. 학습 곡선 확인

plt.figure(figsize=(8, 5))

plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")

plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Training / Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
# 17. Test set ?? 5? ??? ?? ??

model.eval()

with torch.no_grad():
    for X, graphs, y in test_loader:
        X = X.to(device)
        graphs = graphs.to(device)
        y = y.to(device)

        pred = model(X, graphs)

        pred_delta = y_scaler.inverse_transform(pred.cpu().numpy())
        true_delta = y_scaler.inverse_transform(y.cpu().numpy())

        print("?? delta_lat/delta_lon:")
        print(pred_delta[:5])

        print("?? delta_lat/delta_lon:")
        print(true_delta[:5])

        break
# Out:
# ?? delta_lat/delta_lon:
# [[ 0.00336994  0.00924774]
#  [ 0.00223344  0.00729087]
#  [ 0.00181052  0.00453314]
#  [ 0.00087922  0.00101056]
#  [-0.01211136  0.00453187]]
# ?? delta_lat/delta_lon:
# [[ 0.00411606  0.0090332 ]
#  [ 0.00266266  0.00724793]
#  [ 0.00177002  0.00404358]
#  [ 0.0009079   0.00086975]
#  [-0.0104332   0.0039978 ]]

# %%
# 18. 선박 궤적 예측 함수
# 5분 one-step STMGCN을 반복 적용해 multi-horizon trajectory를 생성한다.
# start_sog를 저장해 속도 구간별 오차 분석에 활용한다.

FORECAST_MINUTES_LIST = [5, 10, 15, 30, 60]
MAX_FORECAST_MINUTES = max(FORECAST_MINUTES_LIST)

TOLERANCE_MINUTES = 2.5
MAX_HISTORY_GAP_MINUTES = 15
BASE_TIME_LOOKBACK_MINUTES = 60


def haversine_km(lat1, lon1, lat2, lon2):
    R = 6371.0

    lat1 = np.radians(lat1)
    lon1 = np.radians(lon1)
    lat2 = np.radians(lat2)
    lon2 = np.radians(lon2)

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = (
        np.sin(dlat / 2) ** 2
        + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    )
    c = 2 * np.arcsin(np.sqrt(a))

    return R * c


def estimate_sog_cog_from_points(prev_lat, prev_lon, new_lat, new_lon, minutes=5):
    dist_km = haversine_km(prev_lat, prev_lon, new_lat, new_lon)
    sog_knots = (dist_km / 1.852) / (minutes / 60)

    dlon = np.radians(new_lon - prev_lon)
    lat1 = np.radians(prev_lat)
    lat2 = np.radians(new_lat)

    y = np.sin(dlon) * np.cos(lat2)
    x = np.cos(lat1) * np.sin(lat2) - np.sin(lat1) * np.cos(lat2) * np.cos(dlon)
    cog = (np.degrees(np.arctan2(y, x)) + 360) % 360

    return sog_knots, cog


def predict_next_position(model, raw_seq, norm_seq):
    graph = create_multi_graph(raw_seq)

    X = torch.tensor(norm_seq, dtype=torch.float32).unsqueeze(0).to(device)
    graphs = torch.tensor(graph, dtype=torch.float32).unsqueeze(0).to(device)

    with torch.no_grad():
        pred_delta_norm = model(X, graphs).cpu().numpy()

    pred_delta = y_scaler.inverse_transform(pred_delta_norm)[0]
    last_latlon = raw_seq[-1, :2]
    pred_latlon = last_latlon + pred_delta

    return pred_delta_norm[0], pred_delta, pred_latlon


def recursive_forecast_path(model, raw_seq, norm_seq, forecast_minutes=240):
    steps = int(forecast_minutes / 5)

    raw_seq = raw_seq.copy()
    norm_seq = norm_seq.copy()
    predicted_path = []

    for step in range(1, steps + 1):
        pred_delta_norm, pred_delta, pred_latlon = predict_next_position(model, raw_seq, norm_seq)

        prev_raw = raw_seq[-1].copy()
        new_raw = prev_raw.copy()

        new_raw[0] = pred_latlon[0]
        new_raw[1] = pred_latlon[1]

        est_sog, est_cog = estimate_sog_cog_from_points(
            prev_raw[0], prev_raw[1],
            pred_latlon[0], pred_latlon[1],
            minutes=5
        )

        new_raw[2] = est_sog
        new_raw[3] = np.sin(np.radians(est_cog))
        new_raw[4] = np.cos(np.radians(est_cog))
        new_raw[5] = np.sin(np.radians(est_cog))
        new_raw[6] = np.cos(np.radians(est_cog))

        new_norm = x_scaler.transform(pd.DataFrame([new_raw], columns=feature_cols))[0]

        raw_seq = np.vstack([raw_seq[1:], new_raw])
        norm_seq = np.vstack([norm_seq[1:], new_norm])

        predicted_path.append({
            "step": step,
            "forecast_minutes": step * 5,
            "lat": pred_latlon[0],
            "lon": pred_latlon[1]
        })

    return pd.DataFrame(predicted_path)


def generate_base_times(df, forecast_minutes, num_base_times=100):
    all_times = sorted(df["timestamp"].unique())
    max_allowed_time = df["timestamp"].max() - pd.Timedelta(minutes=forecast_minutes)
    candidate_times = [t for t in all_times if t <= max_allowed_time]

    if len(candidate_times) == 0:
        raise ValueError("미래 실제 위치를 확인할 수 있는 base_time이 없습니다.")

    if len(candidate_times) <= num_base_times:
        return candidate_times

    selected_idx = np.linspace(0, len(candidate_times) - 1, num_base_times).astype(int)
    return [candidate_times[i] for i in selected_idx]


def make_prediction_inputs_at_base_time(df_raw, df_norm, base_time, seq_len=10):
    pred_inputs = []

    lookback_start = base_time - pd.Timedelta(minutes=BASE_TIME_LOOKBACK_MINUTES)

    current_df = df_raw[
        (df_raw["timestamp"] >= lookback_start) &
        (df_raw["timestamp"] <= base_time)
    ].copy()

    if len(current_df) == 0:
        return pred_inputs

    latest_idx = current_df.groupby("MMSI")["timestamp"].idxmax()
    current_snapshot = current_df.loc[latest_idx].copy()
    moving_snapshot = current_snapshot[current_snapshot["sog"] > MOVING_THRESHOLD].copy()

    for _, row in moving_snapshot.iterrows():
        mmsi = row["MMSI"]
        current_time = row["timestamp"]

        hist_raw = df_raw[
            (df_raw["MMSI"] == mmsi) &
            (df_raw["timestamp"] <= current_time)
        ].sort_values("timestamp").tail(seq_len)

        hist_norm = df_norm[
            (df_norm["MMSI"] == mmsi) &
            (df_norm["timestamp"] <= current_time)
        ].sort_values("timestamp").tail(seq_len)

        if len(hist_raw) < seq_len or len(hist_norm) < seq_len:
            continue

        time_diffs = hist_raw["timestamp"].diff().dropna()

        if not (time_diffs <= pd.Timedelta(minutes=MAX_HISTORY_GAP_MINUTES)).all():
            continue

        pred_inputs.append({
            "MMSI": mmsi,
            "base_time": current_time,
            "start_lat": hist_raw.iloc[-1]["lat"],
            "start_lon": hist_raw.iloc[-1]["lon"],
            "start_sog": hist_raw.iloc[-1]["sog"],
            "raw_seq": hist_raw[feature_cols].values.astype(np.float32),
            "norm_seq": hist_norm[feature_cols].values.astype(np.float32)
        })

    return pred_inputs


def get_actual_position_near_time(df, mmsi, target_time, tolerance_minutes=2.5):
    tolerance = pd.Timedelta(minutes=tolerance_minutes)

    vessel_df = df[
        (df["MMSI"] == mmsi) &
        (df["timestamp"] >= target_time - tolerance) &
        (df["timestamp"] <= target_time + tolerance)
    ].copy()

    if len(vessel_df) == 0:
        return None

    vessel_df["time_diff"] = (vessel_df["timestamp"] - target_time).abs()
    row = vessel_df.sort_values("time_diff").iloc[0]

    return {
        "timestamp": row["timestamp"],
        "lat": row["lat"],
        "lon": row["lon"]
    }


def get_actual_path_for_horizons(df, mmsi, base_time, forecast_minutes_list):
    rows = []

    for minutes in forecast_minutes_list:
        actual = get_actual_position_near_time(
            df,
            mmsi,
            base_time + pd.Timedelta(minutes=minutes),
            tolerance_minutes=TOLERANCE_MINUTES
        )

        if actual is None:
            continue

        rows.append({
            "forecast_minutes": minutes,
            "timestamp": actual["timestamp"],
            "lat": actual["lat"],
            "lon": actual["lon"]
        })

    return pd.DataFrame(rows)

# %%
# 19. Multi-horizon 선박 궤적 예측 실행
# start_sog를 trajectory_results_df에 저장한다.

NUM_BASE_TIMES = 300

base_times = generate_base_times(
    test_raw,
    forecast_minutes=MAX_FORECAST_MINUTES,
    num_base_times=NUM_BASE_TIMES
)

trajectory_records = []
trajectory_paths = []

model.eval()

for base_idx, base_time in enumerate(base_times):
    print(f"[{base_idx + 1}/{len(base_times)}] base_time: {base_time}")

    pred_inputs = make_prediction_inputs_at_base_time(
        test_raw,
        test_norm,
        base_time,
        seq_len=SEQ_LEN
    )

    if len(pred_inputs) == 0:
        print("예측 가능한 이동 선박 없음. skip")
        continue

    print("prediction input vessels:", len(pred_inputs))

    for item in pred_inputs:
        mmsi = item["MMSI"]
        vessel_base_time = item["base_time"]

        pred_path = recursive_forecast_path(
            model,
            item["raw_seq"],
            item["norm_seq"],
            forecast_minutes=MAX_FORECAST_MINUTES
        )

        actual_path = get_actual_path_for_horizons(
            test_raw,
            mmsi,
            vessel_base_time,
            FORECAST_MINUTES_LIST
        )

        if len(actual_path) == 0:
            continue

        pred_horizon = pred_path[
            pred_path["forecast_minutes"].isin(FORECAST_MINUTES_LIST)
        ].copy()

        merged = pred_horizon.merge(
            actual_path,
            on="forecast_minutes",
            suffixes=("_pred", "_actual")
        )

        if len(merged) == 0:
            continue

        for _, row in merged.iterrows():
            error_km = haversine_km(
                row["lat_actual"], row["lon_actual"],
                row["lat_pred"], row["lon_pred"]
            )

            trajectory_records.append({
                "base_time": vessel_base_time,
                "MMSI": mmsi,
                "start_sog": item["start_sog"],
                "forecast_minutes": row["forecast_minutes"],
                "pred_lat": row["lat_pred"],
                "pred_lon": row["lon_pred"],
                "actual_lat": row["lat_actual"],
                "actual_lon": row["lon_actual"],
                "error_km": error_km,
                "error_nm": error_km / 1.852
            })

        trajectory_paths.append({
            "base_time": vessel_base_time,
            "MMSI": mmsi,
            "start_lat": item["start_lat"],
            "start_lon": item["start_lon"],
            "start_sog": item["start_sog"],
            "raw_seq": item["raw_seq"],
            "pred_path": pred_horizon.reset_index(drop=True),
            "actual_path": actual_path.reset_index(drop=True)
        })

trajectory_results_df = pd.DataFrame(trajectory_records)

print("trajectory result rows:", len(trajectory_results_df))
print("trajectory paths:", len(trajectory_paths))

if len(trajectory_results_df) > 0:
    display(trajectory_results_df.head())
else:
    print("평가 가능한 trajectory 결과가 없습니다.")
# Out:
# [1/300] base_time: 2024-08-01 00:00:00
# 예측 가능한 이동 선박 없음. skip
# [2/300] base_time: 2024-08-01 03:35:00
# 예측 가능한 이동 선박 없음. skip
# [3/300] base_time: 2024-08-01 05:55:00
# prediction input vessels: 1
# [4/300] base_time: 2024-08-01 07:55:00
# prediction input vessels: 5
# [5/300] base_time: 2024-08-01 12:45:00
# prediction input vessels: 2
# [6/300] base_time: 2024-08-01 15:00:00
# prediction input vessels: 2
# [7/300] base_time: 2024-08-01 17:00:00
# prediction input vessels: 4
# [8/300] base_time: 2024-08-01 19:10:00
# prediction input vessels: 4
# [9/300] base_time: 2024-08-01 21:10:00
# prediction input vessels: 5
# [10/300] base_time: 2024-08-02 00:00:00
# prediction input vessels: 1
# [11/300] base_time: 2024-08-02 02:05:00
# prediction input vessels: 2
# [12/300] base_time: 2024-08-02 04:15:00
# prediction input vessels: 4
# [13/300] base_time: 2024-08-02 06:20:00
# prediction input vessels: 2
# [14/300] base_time: 2024-08-02 08:20:00
# prediction input vessels: 2
# [15/300] base_time: 2024-08-02 11:55:00
# prediction input vessels: 2
# [16/300] base_time: 2024-08-02 14:00:00
# prediction input vessels: 4
# [17/300] base_time: 2024-08-02 16:00:00
# prediction input vessels: 1
# [18/300] base_time: 2024-08-02 18:20:00
# prediction input vessels: 3
# [19/300] base_time: 2024-08-02 21:25:00
# prediction input vessels: 1
# [20/300] base_time: 2024-08-02 23:45:00
# prediction input vessels: 1
# [21/300] base_time: 2024-08-03 01:50:00
# prediction input vessels: 2
# [22/300] base_time: 2024-08-03 04:40:00
# prediction input vessels: 4
# [23/300] base_time: 2024-08-03 07:40:00
# prediction input vessels: 2
# [24/300] base_time: 2024-08-03 09:40:00
# prediction input vessels: 2
# [25/300] base_time: 2024-08-03 11:45:00
# prediction input vessels: 2
# [26/300] base_time: 2024-08-03 13:50:00
# prediction input vessels: 1
# [27/300] base_time: 2024-08-03 16:15:00
# prediction input vessels: 1
# [28/300] base_time: 2024-08-03 18:20:00
# prediction input vessels: 1
# [29/300] base_time: 2024-08-03 20:20:00
# prediction input vessels: 2
# [30/300] base_time: 2024-08-03 22:45:00
# prediction input vessels: 2
# [31/300] base_time: 2024-08-04 00:50:00
# prediction input vessels: 2
# [32/300] base_time: 2024-08-04 03:00:00
# prediction input vessels: 2
# [33/300] base_time: 2024-08-04 05:05:00
# prediction input vessels: 2
# [34/300] base_time: 2024-08-04 07:25:00
# prediction input vessels: 1
# [35/300] base_time: 2024-08-04 10:35:00
# 예측 가능한 이동 선박 없음. skip
# [36/300] base_time: 2024-08-04 12:40:00
# prediction input vessels: 4
# [37/300] base_time: 2024-08-04 14:40:00
# prediction input vessels: 3
# [38/300] base_time: 2024-08-04 18:25:00
# 예측 가능한 이동 선박 없음. skip
# [39/300] base_time: 2024-08-04 20:25:00
# prediction input vessels: 3
# [40/300] base_time: 2024-08-04 22:30:00
# prediction input vessels: 3
# [41/300] base_time: 2024-08-05 00:35:00
# prediction input vessels: 2
# [42/300] base_time: 2024-08-05 04:05:00
# 예측 가능한 이동 선박 없음. skip
# [43/300] base_time: 2024-08-05 06:35:00
# prediction input vessels: 7
# [44/300] base_time: 2024-08-05 09:10:00
# 예측 가능한 이동 선박 없음. skip
# [45/300] base_time: 2024-08-05 11:15:00
# prediction input vessels: 3
# [46/300] base_time: 2024-08-05 13:20:00
# prediction input vessels: 3
# [47/300] base_time: 2024-08-05 15:30:00
# prediction input vessels: 1
# [48/300] base_time: 2024-08-05 19:25:00
# 예측 가능한 이동 선박 없음. skip
# [49/300] base_time: 2024-08-05 21:45:00
# prediction input vessels: 1
# [50/300] base_time: 2024-08-06 00:20:00
# prediction input vessels: 2
# [51/300] base_time: 2024-08-06 02:25:00
# prediction input vessels: 4
# [52/300] base_time: 2024-08-06 07:15:00
# prediction input vessels: 1
# [53/300] base_time: 2024-08-06 09:20:00
# 예측 가능한 이동 선박 없음. skip
# [54/300] base_time: 2024-08-06 11:20:00
# prediction input vessels: 2
# [55/300] base_time: 2024-08-06 13:25:00
# prediction input vessels: 2
# [56/300] base_time: 2024-08-06 15:35:00
# prediction input vessels: 2
# [57/300] base_time: 2024-08-06 17:55:00
# prediction input vessels: 1
# [58/300] base_time: 2024-08-06 20:00:00
# prediction input vessels: 2
# [59/300] base_time: 2024-08-06 22:30:00
# prediction input vessels: 1
# [60/300] base_time: 2024-08-07 00:35:00
# prediction input vessels: 3
# [61/300] base_time: 2024-08-07 03:20:00
# prediction input vessels: 2
# [62/300] base_time: 2024-08-07 05:30:00
# prediction input vessels: 4
# [63/300] base_time: 2024-08-07 08:00:00
# prediction input vessels: 1
# [64/300] base_time: 2024-08-07 10:20:00
# prediction input vessels: 1
# [65/300] base_time: 2024-08-07 13:15:00
# prediction input vessels: 1
# [66/300] base_time: 2024-08-07 16:15:00
# prediction input vessels: 2
# [67/300] base_time: 2024-08-07 18:15:00
# prediction input vessels: 2
# [68/300] base_time: 2024-08-07 20:35:00
# 예측 가능한 이동 선박 없음. skip
# [69/300] base_time: 2024-08-07 22:45:00
# prediction input vessels: 3
# [70/300] base_time: 2024-08-08 00:50:00
# prediction input vessels: 4
# [71/300] base_time: 2024-08-08 02:55:00
# prediction input vessels: 4
# [72/300] base_time: 2024-08-08 05:00:00
# prediction input vessels: 3
# [73/300] base_time: 2024-08-08 07:05:00
# prediction input vessels: 2
# [74/300] base_time: 2024-08-08 09:05:00
# prediction input vessels: 4
# [75/300] base_time: 2024-08-08 11:30:00
# prediction input vessels: 1
# [76/300] base_time: 2024-08-08 14:40:00
# prediction input vessels: 3
# [77/300] base_time: 2024-08-08 16:40:00
# prediction input vessels: 3
# [78/300] base_time: 2024-08-08 18:45:00
# prediction input vessels: 5
# [79/300] base_time: 2024-08-08 21:45:00
# 예측 가능한 이동 선박 없음. skip
# [80/300] base_time: 2024-08-08 23:50:00
# prediction input vessels: 1
# [81/300] base_time: 2024-08-09 02:00:00
# prediction input vessels: 4
# [82/300] base_time: 2024-08-09 04:00:00
# prediction input vessels: 3
# [83/300] base_time: 2024-08-09 06:05:00
# prediction input vessels: 1
# [84/300] base_time: 2024-08-09 09:20:00
# 예측 가능한 이동 선박 없음. skip
# [85/300] base_time: 2024-08-09 13:30:00
# 예측 가능한 이동 선박 없음. skip
# [86/300] base_time: 2024-08-09 16:30:00
# prediction input vessels: 1
# [87/300] base_time: 2024-08-09 18:45:00
# prediction input vessels: 3
# [88/300] base_time: 2024-08-09 20:50:00
# prediction input vessels: 4
# [89/300] base_time: 2024-08-10 00:45:00
# prediction input vessels: 1
# [90/300] base_time: 2024-08-10 02:50:00
# prediction input vessels: 4
# [91/300] base_time: 2024-08-10 05:10:00
# prediction input vessels: 2
# [92/300] base_time: 2024-08-10 09:00:00
# 예측 가능한 이동 선박 없음. skip
# [93/300] base_time: 2024-08-10 11:05:00
# prediction input vessels: 2
# [94/300] base_time: 2024-08-10 13:05:00
# prediction input vessels: 5
# [95/300] base_time: 2024-08-10 16:20:00
# 예측 가능한 이동 선박 없음. skip
# [96/300] base_time: 2024-08-10 19:00:00
# prediction input vessels: 4
# [97/300] base_time: 2024-08-10 21:00:00
# prediction input vessels: 4
# [98/300] base_time: 2024-08-10 23:05:00
# prediction input vessels: 1
# [99/300] base_time: 2024-08-11 01:05:00
# prediction input vessels: 3
# [100/300] base_time: 2024-08-11 03:45:00
# prediction input vessels: 1
# [101/300] base_time: 2024-08-11 09:00:00
# 예측 가능한 이동 선박 없음. skip
# [102/300] base_time: 2024-08-11 11:00:00
# prediction input vessels: 5
# [103/300] base_time: 2024-08-11 13:20:00
# prediction input vessels: 1
# [104/300] base_time: 2024-08-11 15:45:00
# 예측 가능한 이동 선박 없음. skip
# [105/300] base_time: 2024-08-11 18:25:00
# prediction input vessels: 7
# [106/300] base_time: 2024-08-11 22:05:00
# prediction input vessels: 1
# [107/300] base_time: 2024-08-12 00:05:00
# prediction input vessels: 5
# [108/300] base_time: 2024-08-12 02:10:00
# prediction input vessels: 3
# [109/300] base_time: 2024-08-12 04:15:00
# prediction input vessels: 1
# [110/300] base_time: 2024-08-12 07:00:00
# 예측 가능한 이동 선박 없음. skip
# [111/300] base_time: 2024-08-12 09:30:00
# prediction input vessels: 1
# [112/300] base_time: 2024-08-12 13:45:00
# prediction input vessels: 1
# [113/300] base_time: 2024-08-12 16:00:00
# prediction input vessels: 1
# [114/300] base_time: 2024-08-12 18:05:00
# prediction input vessels: 2
# [115/300] base_time: 2024-08-12 20:45:00
# prediction input vessels: 1
# [116/300] base_time: 2024-08-12 23:50:00
# 예측 가능한 이동 선박 없음. skip
# [117/300] base_time: 2024-08-13 02:50:00
# 예측 가능한 이동 선박 없음. skip
# [118/300] base_time: 2024-08-13 04:55:00
# prediction input vessels: 6
# [119/300] base_time: 2024-08-13 07:50:00
# 예측 가능한 이동 선박 없음. skip
# [120/300] base_time: 2024-08-13 09:50:00
# prediction input vessels: 5
# [121/300] base_time: 2024-08-13 12:05:00
# prediction input vessels: 1
# [122/300] base_time: 2024-08-13 14:05:00
# prediction input vessels: 3
# [123/300] base_time: 2024-08-13 17:45:00
# 예측 가능한 이동 선박 없음. skip
# [124/300] base_time: 2024-08-13 20:40:00
# prediction input vessels: 2
# [125/300] base_time: 2024-08-13 23:40:00
# prediction input vessels: 1
# [126/300] base_time: 2024-08-14 01:45:00
# prediction input vessels: 3
# [127/300] base_time: 2024-08-14 03:45:00
# prediction input vessels: 1
# [128/300] base_time: 2024-08-14 05:50:00
# 예측 가능한 이동 선박 없음. skip
# [129/300] base_time: 2024-08-14 08:05:00
# prediction input vessels: 1
# [130/300] base_time: 2024-08-14 10:40:00
# prediction input vessels: 1
# [131/300] base_time: 2024-08-14 13:20:00
# prediction input vessels: 3
# [132/300] base_time: 2024-08-14 15:20:00
# prediction input vessels: 4
# [133/300] base_time: 2024-08-14 17:25:00
# prediction input vessels: 3
# [134/300] base_time: 2024-08-14 20:55:00
# 예측 가능한 이동 선박 없음. skip
# [135/300] base_time: 2024-08-15 00:25:00
# 예측 가능한 이동 선박 없음. skip
# [136/300] base_time: 2024-08-15 03:00:00
# prediction input vessels: 1
# [137/300] base_time: 2024-08-15 05:00:00
# prediction input vessels: 3
# [138/300] base_time: 2024-08-15 07:50:00
# prediction input vessels: 3
# [139/300] base_time: 2024-08-15 10:30:00
# prediction input vessels: 1
# [140/300] base_time: 2024-08-15 12:45:00
# prediction input vessels: 3
# [141/300] base_time: 2024-08-15 14:50:00
# prediction input vessels: 3
# [142/300] base_time: 2024-08-15 18:35:00
# prediction input vessels: 1
# [143/300] base_time: 2024-08-15 20:40:00
# prediction input vessels: 1
# [144/300] base_time: 2024-08-15 22:45:00
# prediction input vessels: 2
# [145/300] base_time: 2024-08-16 00:55:00
# prediction input vessels: 4
# [146/300] base_time: 2024-08-16 03:00:00
# prediction input vessels: 2
# [147/300] base_time: 2024-08-16 05:25:00
# 예측 가능한 이동 선박 없음. skip
# [148/300] base_time: 2024-08-16 07:30:00
# prediction input vessels: 2
# [149/300] base_time: 2024-08-16 09:35:00
# prediction input vessels: 3
# [150/300] base_time: 2024-08-16 11:35:00
# prediction input vessels: 2
# [151/300] base_time: 2024-08-16 14:20:00
# 예측 가능한 이동 선박 없음. skip
# [152/300] base_time: 2024-08-16 16:35:00
# prediction input vessels: 2
# [153/300] base_time: 2024-08-16 20:10:00
# 예측 가능한 이동 선박 없음. skip
# [154/300] base_time: 2024-08-16 22:55:00
# 예측 가능한 이동 선박 없음. skip
# [155/300] base_time: 2024-08-17 00:55:00
# prediction input vessels: 3
# [156/300] base_time: 2024-08-17 03:40:00
# prediction input vessels: 1
# [157/300] base_time: 2024-08-17 07:50:00
# prediction input vessels: 1
# [158/300] base_time: 2024-08-17 09:55:00
# prediction input vessels: 3
# [159/300] base_time: 2024-08-17 12:00:00
# prediction input vessels: 3
# [160/300] base_time: 2024-08-17 14:15:00
# 예측 가능한 이동 선박 없음. skip
# [161/300] base_time: 2024-08-17 16:20:00
# prediction input vessels: 4
# [162/300] base_time: 2024-08-17 18:40:00
# 예측 가능한 이동 선박 없음. skip
# [163/300] base_time: 2024-08-17 20:45:00
# prediction input vessels: 3
# [164/300] base_time: 2024-08-17 23:55:00
# prediction input vessels: 1
# [165/300] base_time: 2024-08-18 02:25:00
# 예측 가능한 이동 선박 없음. skip
# [166/300] base_time: 2024-08-18 04:30:00
# prediction input vessels: 3
# [167/300] base_time: 2024-08-18 06:30:00
# prediction input vessels: 4
# [168/300] base_time: 2024-08-18 08:35:00
# prediction input vessels: 4
# [169/300] base_time: 2024-08-18 11:00:00
# prediction input vessels: 1
# [170/300] base_time: 2024-08-18 13:00:00
# prediction input vessels: 3
# [171/300] base_time: 2024-08-18 15:05:00
# prediction input vessels: 3
# [172/300] base_time: 2024-08-18 18:00:00
# prediction input vessels: 1
# [173/300] base_time: 2024-08-18 20:05:00
# prediction input vessels: 2
# [174/300] base_time: 2024-08-18 22:30:00
# prediction input vessels: 4
# [175/300] base_time: 2024-08-19 01:15:00
# prediction input vessels: 3
# [176/300] base_time: 2024-08-19 03:20:00
# prediction input vessels: 4
# [177/300] base_time: 2024-08-19 06:05:00
# 예측 가능한 이동 선박 없음. skip
# [178/300] base_time: 2024-08-19 09:50:00
# prediction input vessels: 1
# [179/300] base_time: 2024-08-19 14:40:00
# 예측 가능한 이동 선박 없음. skip
# [180/300] base_time: 2024-08-19 17:00:00
# 예측 가능한 이동 선박 없음. skip
# [181/300] base_time: 2024-08-19 19:05:00
# prediction input vessels: 7
# [182/300] base_time: 2024-08-19 21:10:00
# prediction input vessels: 1
# [183/300] base_time: 2024-08-20 00:20:00
# 예측 가능한 이동 선박 없음. skip
# [184/300] base_time: 2024-08-20 02:25:00
# prediction input vessels: 1
# [185/300] base_time: 2024-08-20 04:25:00
# prediction input vessels: 5
# [186/300] base_time: 2024-08-20 06:55:00
# prediction input vessels: 1
# [187/300] base_time: 2024-08-20 08:55:00
# prediction input vessels: 2
# [188/300] base_time: 2024-08-20 11:10:00
# prediction input vessels: 2
# [189/300] base_time: 2024-08-20 13:15:00
# prediction input vessels: 6
# [190/300] base_time: 2024-08-20 15:45:00
# 예측 가능한 이동 선박 없음. skip
# [191/300] base_time: 2024-08-20 18:00:00
# prediction input vessels: 3
# [192/300] base_time: 2024-08-20 20:00:00
# prediction input vessels: 3
# [193/300] base_time: 2024-08-20 22:20:00
# prediction input vessels: 2
# [194/300] base_time: 2024-08-21 02:00:00
# prediction input vessels: 1
# [195/300] base_time: 2024-08-21 05:10:00
# 예측 가능한 이동 선박 없음. skip
# [196/300] base_time: 2024-08-21 09:00:00
# prediction input vessels: 1
# [197/300] base_time: 2024-08-21 11:00:00
# prediction input vessels: 3
# [198/300] base_time: 2024-08-21 13:05:00
# prediction input vessels: 4
# [199/300] base_time: 2024-08-21 15:20:00
# prediction input vessels: 1
# [200/300] base_time: 2024-08-21 17:45:00
# prediction input vessels: 1
# [201/300] base_time: 2024-08-21 19:50:00
# prediction input vessels: 7
# [202/300] base_time: 2024-08-21 23:00:00
# prediction input vessels: 1
# [203/300] base_time: 2024-08-22 01:00:00
# prediction input vessels: 1
# [204/300] base_time: 2024-08-22 03:25:00
# prediction input vessels: 2
# [205/300] base_time: 2024-08-22 05:25:00
# prediction input vessels: 4
# [206/300] base_time: 2024-08-22 08:00:00
# prediction input vessels: 2
# [207/300] base_time: 2024-08-22 10:45:00
# prediction input vessels: 1
# [208/300] base_time: 2024-08-22 13:20:00
# 예측 가능한 이동 선박 없음. skip
# [209/300] base_time: 2024-08-22 15:25:00
# prediction input vessels: 3
# [210/300] base_time: 2024-08-22 17:25:00
# prediction input vessels: 3
# [211/300] base_time: 2024-08-22 19:30:00
# prediction input vessels: 3
# [212/300] base_time: 2024-08-22 21:35:00
# prediction input vessels: 4
# [213/300] base_time: 2024-08-22 23:45:00
# prediction input vessels: 4
# [214/300] base_time: 2024-08-23 01:50:00
# prediction input vessels: 3
# [215/300] base_time: 2024-08-23 03:50:00
# prediction input vessels: 3
# [216/300] base_time: 2024-08-23 06:10:00
# prediction input vessels: 1
# [217/300] base_time: 2024-08-23 08:45:00
# prediction input vessels: 1
# [218/300] base_time: 2024-08-23 11:25:00
# 예측 가능한 이동 선박 없음. skip
# [219/300] base_time: 2024-08-23 13:30:00
# prediction input vessels: 3
# [220/300] base_time: 2024-08-23 17:50:00
# prediction input vessels: 2
# [221/300] base_time: 2024-08-23 20:25:00
# 예측 가능한 이동 선박 없음. skip
# [222/300] base_time: 2024-08-23 23:10:00
# prediction input vessels: 2
# [223/300] base_time: 2024-08-24 03:05:00
# 예측 가능한 이동 선박 없음. skip
# [224/300] base_time: 2024-08-24 05:15:00
# prediction input vessels: 2
# [225/300] base_time: 2024-08-24 07:25:00
# prediction input vessels: 1
# [226/300] base_time: 2024-08-24 09:55:00
# prediction input vessels: 2
# [227/300] base_time: 2024-08-24 12:50:00
# 예측 가능한 이동 선박 없음. skip
# [228/300] base_time: 2024-08-24 15:25:00
# 예측 가능한 이동 선박 없음. skip
# [229/300] base_time: 2024-08-24 17:30:00
# prediction input vessels: 2
# [230/300] base_time: 2024-08-24 19:30:00
# prediction input vessels: 4
# [231/300] base_time: 2024-08-24 21:55:00
# prediction input vessels: 1
# [232/300] base_time: 2024-08-25 00:00:00
# prediction input vessels: 1
# [233/300] base_time: 2024-08-25 04:25:00
# prediction input vessels: 1
# [234/300] base_time: 2024-08-25 07:00:00
# 예측 가능한 이동 선박 없음. skip
# [235/300] base_time: 2024-08-25 09:00:00
# prediction input vessels: 5
# [236/300] base_time: 2024-08-25 12:50:00
# prediction input vessels: 7
# [237/300] base_time: 2024-08-25 14:55:00
# prediction input vessels: 4
# [238/300] base_time: 2024-08-25 16:55:00
# prediction input vessels: 3
# [239/300] base_time: 2024-08-25 19:40:00
# prediction input vessels: 2
# [240/300] base_time: 2024-08-25 21:40:00
# prediction input vessels: 2
# [241/300] base_time: 2024-08-25 23:55:00
# prediction input vessels: 2
# [242/300] base_time: 2024-08-26 02:00:00
# prediction input vessels: 5
# [243/300] base_time: 2024-08-26 04:35:00
# prediction input vessels: 1
# [244/300] base_time: 2024-08-26 07:40:00
# prediction input vessels: 2
# [245/300] base_time: 2024-08-26 09:50:00
# prediction input vessels: 3
# [246/300] base_time: 2024-08-26 11:55:00
# prediction input vessels: 4
# [247/300] base_time: 2024-08-26 14:00:00
# prediction input vessels: 3
# [248/300] base_time: 2024-08-26 17:00:00
# prediction input vessels: 4
# [249/300] base_time: 2024-08-26 21:45:00
# prediction input vessels: 1
# [250/300] base_time: 2024-08-26 23:55:00
# prediction input vessels: 2
# [251/300] base_time: 2024-08-27 02:10:00
# prediction input vessels: 1
# [252/300] base_time: 2024-08-27 04:15:00
# prediction input vessels: 2
# [253/300] base_time: 2024-08-27 06:15:00
# prediction input vessels: 4
# [254/300] base_time: 2024-08-27 08:55:00
# prediction input vessels: 1
# [255/300] base_time: 2024-08-27 11:10:00
# prediction input vessels: 1
# [256/300] base_time: 2024-08-27 13:30:00
# prediction input vessels: 1
# [257/300] base_time: 2024-08-27 15:40:00
# prediction input vessels: 1
# [258/300] base_time: 2024-08-27 17:40:00
# 예측 가능한 이동 선박 없음. skip
# [259/300] base_time: 2024-08-27 19:55:00
# 예측 가능한 이동 선박 없음. skip
# [260/300] base_time: 2024-08-27 21:55:00
# prediction input vessels: 2
# [261/300] base_time: 2024-08-28 00:40:00
# prediction input vessels: 4
# [262/300] base_time: 2024-08-28 03:15:00
# prediction input vessels: 1
# [263/300] base_time: 2024-08-28 05:15:00
# prediction input vessels: 2
# [264/300] base_time: 2024-08-28 07:55:00
# prediction input vessels: 2
# [265/300] base_time: 2024-08-28 09:55:00
# prediction input vessels: 3
# [266/300] base_time: 2024-08-28 12:00:00
# prediction input vessels: 4
# [267/300] base_time: 2024-08-28 14:10:00
# prediction input vessels: 1
# [268/300] base_time: 2024-08-28 16:55:00
# prediction input vessels: 1
# [269/300] base_time: 2024-08-28 19:00:00
# prediction input vessels: 6
# [270/300] base_time: 2024-08-28 21:35:00
# prediction input vessels: 2
# [271/300] base_time: 2024-08-28 23:50:00
# prediction input vessels: 2
# [272/300] base_time: 2024-08-29 01:55:00
# prediction input vessels: 3
# [273/300] base_time: 2024-08-29 06:10:00
# 예측 가능한 이동 선박 없음. skip
# [274/300] base_time: 2024-08-29 08:55:00
# prediction input vessels: 1
# [275/300] base_time: 2024-08-29 10:55:00
# prediction input vessels: 2
# [276/300] base_time: 2024-08-29 13:40:00
# prediction input vessels: 4
# [277/300] base_time: 2024-08-29 16:20:00
# prediction input vessels: 2
# [278/300] base_time: 2024-08-29 18:45:00
# prediction input vessels: 1
# [279/300] base_time: 2024-08-29 21:30:00
# prediction input vessels: 1
# [280/300] base_time: 2024-08-29 23:35:00
# prediction input vessels: 4
# [281/300] base_time: 2024-08-30 01:40:00
# prediction input vessels: 1
# [282/300] base_time: 2024-08-30 03:45:00
# prediction input vessels: 2
# [283/300] base_time: 2024-08-30 06:05:00
# 예측 가능한 이동 선박 없음. skip
# [284/300] base_time: 2024-08-30 08:10:00
# prediction input vessels: 3
# [285/300] base_time: 2024-08-30 11:00:00
# prediction input vessels: 1
# [286/300] base_time: 2024-08-30 13:55:00
# 예측 가능한 이동 선박 없음. skip
# [287/300] base_time: 2024-08-30 16:25:00
# prediction input vessels: 2
# [288/300] base_time: 2024-08-30 19:10:00
# prediction input vessels: 2
# [289/300] base_time: 2024-08-30 21:15:00
# prediction input vessels: 5
# [290/300] base_time: 2024-08-30 23:25:00
# prediction input vessels: 2
# [291/300] base_time: 2024-08-31 01:30:00
# prediction input vessels: 2
# [292/300] base_time: 2024-08-31 04:25:00
# prediction input vessels: 1
# [293/300] base_time: 2024-08-31 06:50:00
# prediction input vessels: 1
# [294/300] base_time: 2024-08-31 08:55:00
# prediction input vessels: 3
# [295/300] base_time: 2024-08-31 10:55:00
# prediction input vessels: 1
# [296/300] base_time: 2024-08-31 13:10:00
# prediction input vessels: 1
# [297/300] base_time: 2024-08-31 15:20:00
# prediction input vessels: 1
# [298/300] base_time: 2024-08-31 17:20:00
# prediction input vessels: 5
# [299/300] base_time: 2024-08-31 19:25:00
# prediction input vessels: 4
# [300/300] base_time: 2024-08-31 22:55:00
# prediction input vessels: 2
# trajectory result rows: 335
# trajectory paths: 140
#             base_time       MMSI  start_sog  forecast_minutes   pred_lat  \
# 0 2024-08-01 05:55:00  477845600       9.88                 5  34.996044
# 1 2024-08-01 05:55:00  477845600       9.88                10  34.980495
# 2 2024-08-01 05:55:00  477845600       9.88                15  34.965740
# 3 2024-08-01 17:00:00  440189000       2.86                 5  35.074360
# 4 2024-08-01 17:00:00  440189000       2.86                10  35.074959
#
#      pred_lon  actual_lat  actual_lon  error_km  error_nm
# 0  128.795410   34.996237  128.795140  0.032634  0.017621
# 1  128.801117   34.980562  128.800617  0.046154  0.024921
# 2  128.806870   34.966039  128.807358  0.055578  0.030010
# 3  128.778610   35.074996  128.777367  0.133370  0.072014
# 4  128.777191   35.075977  128.775863  0.165575  0.089403

# %%
# 20. 예측 정확도 상위/하위 10개 선박 선택
# 기준: 5분 horizon에서 MMSI별 평균 error_km
# 단, 최소 평가 횟수(MIN_SHIP_COUNT) 이상인 선박만 후보로 사용한다.

TOP_N = 5
SELECTION_HORIZON = 5
PLOT_HORIZONS = [5, 10, 15, 30]
MIN_SHIP_COUNT = 2


def select_paths_by_ship_mean_error(
    trajectory_results_df,
    trajectory_paths,
    top=True,
    n=10,
    horizon=5,
    min_ship_count=2
):
    horizon_df = trajectory_results_df[
        trajectory_results_df["forecast_minutes"] == horizon
    ].copy()

    ship_score_df = (
        horizon_df
        .groupby("MMSI")
        .agg(
            mean_error_km=("error_km", "mean"),
            median_error_km=("error_km", "median"),
            min_error_km=("error_km", "min"),
            max_error_km=("error_km", "max"),
            count=("error_km", "count")
        )
        .reset_index()
    )

    ship_score_df = ship_score_df[
        ship_score_df["count"] >= min_ship_count
    ].copy()

    ship_score_df = ship_score_df.sort_values(
        "mean_error_km",
        ascending=top
    ).head(n).reset_index(drop=True)

    selected_paths = []

    for _, ship_row in ship_score_df.iterrows():
        mmsi = ship_row["MMSI"]

        ship_records = horizon_df[horizon_df["MMSI"] == mmsi]

        if top:
            selected_record = ship_records.sort_values("error_km", ascending=True).iloc[0]
        else:
            selected_record = ship_records.sort_values("error_km", ascending=False).iloc[0]

        matched = [
            item for item in trajectory_paths
            if item["MMSI"] == selected_record["MMSI"]
            and item["base_time"] == selected_record["base_time"]
        ]

        if len(matched) > 0:
            selected_paths.append(matched[0])

    return ship_score_df, selected_paths


def get_plot_nodes_5min(item, plot_horizons):
    pred_nodes = item["pred_path"][
        item["pred_path"]["forecast_minutes"].isin(plot_horizons)
    ].copy()

    actual_nodes = item["actual_path"][
        item["actual_path"]["forecast_minutes"].isin(plot_horizons)
    ].copy()

    merged = pred_nodes.merge(
        actual_nodes,
        on="forecast_minutes",
        suffixes=("_pred", "_actual")
    )

    merged = merged.sort_values("forecast_minutes").reset_index(drop=True)

    if len(merged) == 0:
        return None

    return merged


top10_df, top10_paths = select_paths_by_ship_mean_error(
    trajectory_results_df,
    trajectory_paths,
    top=True,
    n=TOP_N,
    horizon=SELECTION_HORIZON,
    min_ship_count=MIN_SHIP_COUNT
)

bottom10_df, bottom10_paths = select_paths_by_ship_mean_error(
    trajectory_results_df,
    trajectory_paths,
    top=False,
    n=TOP_N,
    horizon=SELECTION_HORIZON,
    min_ship_count=MIN_SHIP_COUNT
)

print(f"예측 정확도 상위 {TOP_N}개 선박")
print(f"선정 기준: {SELECTION_HORIZON}분 예측 평균 오차, count >= {MIN_SHIP_COUNT}")
display(top10_df)

print(f"예측 정확도 하위 {TOP_N}개 선박")
print(f"선정 기준: {SELECTION_HORIZON}분 예측 평균 오차, count >= {MIN_SHIP_COUNT}")
display(bottom10_df)

print("top selected paths:", len(top10_paths))
print("bottom selected paths:", len(bottom10_paths))
# Out:
# 예측 정확도 상위 5개 선박
# 선정 기준: 5분 예측 평균 오차, count >= 2
#         MMSI  mean_error_km  median_error_km  min_error_km  max_error_km  \
# 0  636018904       0.021256         0.021256      0.017695      0.024818
# 1  229463000       0.033024         0.019876      0.019753      0.059442
# 2  565887000       0.038474         0.038474      0.027327      0.049620
# 3  431332000       0.054234         0.054234      0.049341      0.059127
# 4  255806502       0.056152         0.056152      0.048594      0.063710
#
#    count
# 0      2
# 1      3
# 2      2
# 3      2
# 4      2
# 예측 정확도 하위 5개 선박
# 선정 기준: 5분 예측 평균 오차, count >= 2
#         MMSI  mean_error_km  median_error_km  min_error_km  max_error_km  \
# 0  477947700       0.183090         0.183090      0.100935      0.265245
# 1  431981000       0.130384         0.130384      0.116127      0.144641
# 2  352001660       0.125877         0.112942      0.091946      0.172744
# 3  441701000       0.097310         0.097310      0.066333      0.128288
# 4  636018380       0.091087         0.091087      0.062785      0.119390
#
#    count
# 0      2
# 1      2
# 2      3
# 3      2
# 4      2
# top selected paths: 5
# bottom selected paths: 5

# %%
# 21. 상위/하위 5개 선박: 예측 움직임 vs 실제 움직임 그래프
# 노드: 5분, 10분, 15분, 30분, 1시간

def plot_pred_actual_paths(selected_paths, title):
    plt.figure(figsize=(11, 9))
    colors = plt.cm.tab10(np.linspace(0, 1, max(len(selected_paths), 1)))
    plot_count = 0

    for i, item in enumerate(selected_paths):
        color = colors[i]
        merged = get_plot_nodes_5min(item, PLOT_HORIZONS)

        if merged is None:
            continue

        plot_count += 1

        plt.scatter(
            item["start_lon"], item["start_lat"],
            color=color, marker="o", s=70,
            edgecolor="black", linewidth=0.8
        )

        plt.plot(
            merged["lon_actual"], merged["lat_actual"],
            color=color, linestyle="-", marker="x", linewidth=1.5,
            label=f"Actual {i}: {item['MMSI']}"
        )

        plt.plot(
            merged["lon_pred"], merged["lat_pred"],
            color=color, linestyle="--", marker="*", linewidth=1.5,
            label=f"Pred {i}: {item['MMSI']}"
        )

        for _, row in merged.iterrows():
            plt.text(
                row["lon_pred"],
                row["lat_pred"],
                f"{int(row['forecast_minutes'])}min",
                fontsize=7,
                color=color
            )

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.grid(True)
    plt.legend(fontsize=8, ncol=2)

    ax = plt.gca()
    ax.xaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.ticklabel_format(style="plain", axis="both")

    plt.show()
    print("plotted vessels:", plot_count)


plot_pred_actual_paths(
    top10_paths,
    "Top 5 Vessels: Predicted vs Actual Trajectories"
)

plot_pred_actual_paths(
    bottom10_paths,
    "Bottom 5 Vessels: Predicted vs Actual Trajectories"
)
# Out:
# plotted vessels: 5
# plotted vessels: 5

# %%
# 22. 상위/하위 10개 선박: 예측-실제 연결선 그래프
# 같은 horizon의 예측 위치와 실제 위치를 선으로 연결한다.

def plot_error_line_paths(selected_paths, title):
    plt.figure(figsize=(11, 9))
    colors = plt.cm.tab10(np.linspace(0, 1, max(len(selected_paths), 1)))
    plot_count = 0

    for i, item in enumerate(selected_paths):
        color = colors[i]
        merged = get_plot_nodes_5min(item, PLOT_HORIZONS)

        if merged is None:
            continue

        plot_count += 1

        plt.scatter(
            item["start_lon"], item["start_lat"],
            color=color, marker="o", s=70,
            edgecolor="black", linewidth=0.8,
            label=f"Start {i}: {item['MMSI']}"
        )

        plt.plot(
            merged["lon_actual"], merged["lat_actual"],
            color=color, linestyle="-", marker="x", linewidth=1.5,
            label=f"Actual {i}: {item['MMSI']}"
        )

        plt.plot(
            merged["lon_pred"], merged["lat_pred"],
            color=color, linestyle="--", marker="*", linewidth=1.5,
            label=f"Pred {i}: {item['MMSI']}"
        )

        for _, row in merged.iterrows():
            plt.plot(
                [row["lon_actual"], row["lon_pred"]],
                [row["lat_actual"], row["lat_pred"]],
                color=color,
                alpha=0.35,
                linewidth=0.9
            )

            mid_lon = (row["lon_actual"] + row["lon_pred"]) / 2
            mid_lat = (row["lat_actual"] + row["lat_pred"]) / 2

            plt.text(
                mid_lon,
                mid_lat,
                f"{int(row['forecast_minutes'])}min",
                fontsize=7,
                color=color
            )

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.grid(True)
    plt.legend(fontsize=8, ncol=2)

    ax = plt.gca()
    ax.xaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.ticklabel_format(style="plain", axis="both")

    plt.show()
    print("plotted vessels:", plot_count)


plot_error_line_paths(
    top10_paths,
    "Top 5 Vessels: Error Lines Between Actual and Predicted Positions"
)

plot_error_line_paths(
    bottom10_paths,
    "Bottom 5 Vessels: Error Lines Between Actual and Predicted Positions"
)
# Out:
# plotted vessels: 5
# plotted vessels: 5

# %%
# 23. ?? ??: Horizon? ?? ?? ?? ??
# ?? ??? ??? ? ???? ????.

if len(trajectory_results_df) == 0:
    raise ValueError("trajectory_results_df? ?? ????. 19? ?? ?? ?? ?? ?????.")

trajectory_summary_df = (
    trajectory_results_df
    .groupby("forecast_minutes")
    .agg(
        valid_count=("error_km", "count"),
        mean_error_km=("error_km", "mean"),
        median_error_km=("error_km", "median"),
        rmse_km=("error_km", lambda x: np.sqrt(np.mean(np.square(x)))),
        p90_error_km=("error_km", lambda x: np.percentile(x, 90)),
        max_error_km=("error_km", "max"),
        mean_error_nm=("error_nm", "mean"),
        median_error_nm=("error_nm", "median")
    )
    .reset_index()
)

display(trajectory_summary_df)

plt.figure(figsize=(10, 5))
plt.plot(
    trajectory_summary_df["forecast_minutes"],
    trajectory_summary_df["mean_error_km"],
    marker="o",
    label="Mean error"
)
plt.plot(
    trajectory_summary_df["forecast_minutes"],
    trajectory_summary_df["median_error_km"],
    marker="s",
    label="Median error"
)
plt.plot(
    trajectory_summary_df["forecast_minutes"],
    trajectory_summary_df["p90_error_km"],
    marker="^",
    label="P90 error"
)

plt.xlabel("Forecast Horizon (minutes)")
plt.ylabel("Haversine Error (km)")
plt.title("Trajectory Prediction Error by Forecast Horizon")
plt.grid(True)
plt.legend()
plt.show()
# Out:
#    forecast_minutes  valid_count  mean_error_km  median_error_km    rmse_km  \
# 0                 5          139       0.078997         0.062785   0.101409
# 1                10          105       0.218830         0.153236   0.284401
# 2                15           77       0.418079         0.344355   0.565143
# 3                30           13       1.373419         0.768981   2.025313
# 4                60            1      11.565052        11.565052  11.565052
#
#    p90_error_km  max_error_km  mean_error_nm  median_error_nm
# 0      0.134434      0.529116       0.042655         0.033901
# 1      0.454904      1.204130       0.118159         0.082741
# 2      0.858763      2.578222       0.225744         0.185937
# 3      2.971226      5.677651       0.741587         0.415216
# 4     11.565052     11.565052       6.244628         6.244628

# %%
# Folium 지도 시각화: 실제 궤적 vs 예측 궤적 + 예측 오차 연결선

import folium
import pandas as pd
import numpy as np
from pathlib import Path
from IPython.display import display

trajectory_results_df = pd.DataFrame(trajectory_records)

BUSAN_PORT_CENTER = [35.104, 129.075]


def error_color(error_m):
    if error_m <= 50:
        return "#16a34a"   # green
    if error_m <= 100:
        return "#f97316"   # orange
    return "#dc2626"       # red


def popup_html(row):
    return "<br>".join([
        f"<b>MMSI</b>: {int(row['mmsi'])}",
        f"<b>Sample</b>: {int(row['sample_index'])}",
        f"<b>Step</b>: {int(row['step'])}",
        f"<b>Forecast</b>: {int(row['forecast_minutes'])} min",
        f"<b>Base Time</b>: {row['base_time']}",
        f"<b>True</b>: ({row['true_lat']:.6f}, {row['true_lon']:.6f})",
        f"<b>Pred</b>: ({row['pred_lat']:.6f}, {row['pred_lon']:.6f})",
        f"<b>Error</b>: {row['error_m']:.2f} m",
    ])


def add_label(row, layer):
    color = error_color(float(row["error_m"]))
    label = f"{int(row['forecast_minutes'])}min: {float(row['error_m']):.1f}m"

    html = (
        f'<div style="font-size:11px;font-weight:700;color:{color};'
        'background:rgba(255,255,255,0.82);border:1px solid #d1d5db;'
        'border-radius:3px;padding:1px 3px;white-space:nowrap;">'
        f"{label}</div>"
    )

    folium.Marker(
        location=[float(row["pred_lat"]), float(row["pred_lon"])],
        icon=folium.DivIcon(html=html),
    ).add_to(layer)


def build_map_dataframe(trajectory_results_df, trajectory_paths):
    result_df = trajectory_results_df.copy()

    result_df = result_df.rename(columns={
        "MMSI": "mmsi",
        "actual_lat": "true_lat",
        "actual_lon": "true_lon"
    })

    start_rows = []

    for sample_index, item in enumerate(trajectory_paths):
        start_rows.append({
            "sample_index": sample_index,
            "mmsi": item["MMSI"],
            "base_time": item["base_time"],
            "last_lat": item["start_lat"],
            "last_lon": item["start_lon"]
        })

    start_df = pd.DataFrame(start_rows)

    result_df = result_df.merge(
        start_df,
        on=["mmsi", "base_time"],
        how="inner"
    )

    result_df["step"] = (result_df["forecast_minutes"] // 5).astype(int)
    result_df["error_m"] = result_df["error_km"] * 1000

    result_df = result_df[
        [
            "sample_index",
            "mmsi",
            "base_time",
            "step",
            "forecast_minutes",
            "last_lat",
            "last_lon",
            "true_lat",
            "true_lon",
            "pred_lat",
            "pred_lon",
            "error_m"
        ]
    ].dropna()

    return result_df


def visualize_trajectory_map(
    trajectory_results_df,
    trajectory_paths,
    output_path="trajectory_prediction_map.html",
    max_samples=30,
    max_steps=20,
    center_lat=BUSAN_PORT_CENTER[0],
    center_lon=BUSAN_PORT_CENTER[1],
    zoom=12
):
    data = build_map_dataframe(trajectory_results_df, trajectory_paths)

    data["sample_index"] = data["sample_index"].astype(int)
    data["step"] = data["step"].astype(int)

    selected_samples = data["sample_index"].drop_duplicates().head(max_samples)
    data = data[
        data["sample_index"].isin(selected_samples)
        & data["step"].le(max_steps)
    ].copy()

    busan_map = folium.Map(
        location=[center_lat, center_lon],
        zoom_start=zoom,
        tiles="OpenStreetMap"
    )

    start_layer = folium.FeatureGroup(name="Last observed positions", show=True)
    true_layer = folium.FeatureGroup(name="Actual future trajectories", show=True)
    pred_layer = folium.FeatureGroup(name="Predicted future trajectories", show=True)
    error_layer = folium.FeatureGroup(name="Prediction error lines", show=True)
    label_layer = folium.FeatureGroup(name="Error labels", show=True)

    for sample_index, group in data.groupby("sample_index", sort=False):
        group = group.sort_values("step")
        mmsi = int(group.iloc[0]["mmsi"])

        true_locations = group[["true_lat", "true_lon"]].to_numpy(dtype=float).tolist()
        pred_locations = group[["pred_lat", "pred_lon"]].to_numpy(dtype=float).tolist()

        folium.CircleMarker(
            location=[float(group.iloc[0]["last_lat"]), float(group.iloc[0]["last_lon"])],
            radius=5,
            color="#0f172a",
            fill=True,
            fill_opacity=0.9,
            tooltip=f"MMSI {mmsi} sample {sample_index} last observed",
        ).add_to(start_layer)

        if len(true_locations) >= 2:
            folium.PolyLine(
                true_locations,
                color="#2563eb",
                weight=3,
                opacity=0.75,
                tooltip=f"MMSI {mmsi} actual"
            ).add_to(true_layer)

        if len(pred_locations) >= 2:
            folium.PolyLine(
                pred_locations,
                color="#dc2626",
                weight=3,
                opacity=0.8,
                tooltip=f"MMSI {mmsi} predicted"
            ).add_to(pred_layer)

        for _, row in group.iterrows():
            true_point = [float(row["true_lat"]), float(row["true_lon"])]
            pred_point = [float(row["pred_lat"]), float(row["pred_lon"])]
            color = error_color(float(row["error_m"]))

            folium.CircleMarker(
                location=pred_point,
                radius=4,
                color=color,
                fill=True,
                fill_opacity=0.9,
                popup=folium.Popup(popup_html(row), max_width=360),
                tooltip=f"{int(row['forecast_minutes'])}min: {float(row['error_m']):.1f}m",
            ).add_to(pred_layer)

            folium.PolyLine(
                [true_point, pred_point],
                color=color,
                weight=1.5,
                opacity=0.65
            ).add_to(error_layer)

            add_label(row, label_layer)

    for layer in [start_layer, true_layer, pred_layer, error_layer, label_layer]:
        layer.add_to(busan_map)

    folium.LayerControl().add_to(busan_map)

    output_path = Path(output_path)
    busan_map.save(output_path)

    print(f"Saved map: {output_path.resolve()}")
    display(busan_map)

    return busan_map


trajectory_map = visualize_trajectory_map(
    trajectory_results_df,
    trajectory_paths,
    output_path="trajectory_prediction_map.html",
    max_samples=30,
    max_steps=20,
    zoom=12
)
# Out:
# Saved map: C:\Users\HP\Downloads\trajectory_prediction_map.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fedfed22baffb035011c709a09cdb54 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fedfed22baffb035011c709a09cdb54&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fedfed22baffb035011c709a09cdb54 = L.map(
#                 &quot;map_5fedfed22baffb035011c709a09cdb54&quot;,
#                 {
#                     center: [35.104, 129.075],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ed2aa1fd9e30132640e23621eb61106 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ed2aa1fd9e30132640e23621eb61106.addTo(map_5fedfed22baffb035011c709a09cdb54);
#
#
#             var feature_group_832311c82e2c6d8c3614761c0e5cf6a5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_ee643911dd64c31e31ecac8f491691e2 = L.circleMarker(
#                 [35.010711888888885, 128.7900478333334],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_832311c82e2c6d8c3614761c0e5cf6a5);
#
#
#             circle_marker_ee643911dd64c31e31ecac8f491691e2.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 477845600 sample 0 last observed
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_d49f77a494d2c6813c1fc8c8a7daa78a = L.circleMarker(
#                 [35.07336977777778, 128.78043761111107],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_832311c82e2c6d8c3614761c0e5cf6a5);
#
#
#             circle_marker_d49f77a494d2c6813c1fc8c8a7daa78a.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 440189000 sample 1 last observed
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_b48aed1e59e80245e82174509200e294 = L.circleMarker(
#                 [34.974091111111115, 128.80351000000007],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_832311c82e2c6d8c3614761c0e5cf6a5);
#
#
#             circle_marker_b48aed1e59e80245e82174509200e294.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 636013522 sample 2 last observed
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_1cc3975043bc040e043b150b60942101 = L.circleMarker(
#                 [34.99655403225806, 128.79457069892482],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_832311c82e2c6d8c3614761c0e5cf6a5);
#
#
#             circle_marker_1cc3975043bc040e043b150b60942101.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 636022111 sample 3 last observed

# %%
def visualize_trajectory_map(
    trajectory_results_df,
    trajectory_paths,
    output_path="trajectory_prediction_map.html",
    max_steps=20,
    top_n=5,
    bottom_n=5,
    selection_horizon=5,
    center_lat=BUSAN_PORT_CENTER[0],
    center_lon=BUSAN_PORT_CENTER[1],
    zoom=12
):
    data = build_map_dataframe(trajectory_results_df, trajectory_paths)

    data["sample_index"] = data["sample_index"].astype(int)
    data["step"] = data["step"].astype(int)

    horizon_data = data[data["forecast_minutes"] == selection_horizon].copy()

    top_samples = (
        horizon_data
        .sort_values("error_m", ascending=True)
        ["sample_index"]
        .drop_duplicates()
        .head(top_n)
    )

    bottom_samples = (
        horizon_data
        .sort_values("error_m", ascending=False)
        ["sample_index"]
        .drop_duplicates()
        .head(bottom_n)
    )

    selected_samples = pd.concat([top_samples, bottom_samples]).drop_duplicates()

    data = data[
        data["sample_index"].isin(selected_samples)
        & data["step"].le(max_steps)
    ].copy()

    print(f"Selected top samples: {list(top_samples)}")
    print(f"Selected bottom samples: {list(bottom_samples)}")
    print(f"Total displayed samples: {data['sample_index'].nunique()}")

    busan_map = folium.Map(
        location=[center_lat, center_lon],
        zoom_start=zoom,
        tiles="OpenStreetMap"
    )

    start_layer = folium.FeatureGroup(name="Last observed positions", show=True)
    true_layer = folium.FeatureGroup(name="Actual future trajectories", show=True)
    pred_layer = folium.FeatureGroup(name="Predicted future trajectories", show=True)
    error_layer = folium.FeatureGroup(name="Prediction error lines", show=True)
    label_layer = folium.FeatureGroup(name="Error labels", show=True)

    for sample_index, group in data.groupby("sample_index", sort=False):
        group = group.sort_values("step")
        mmsi = int(group.iloc[0]["mmsi"])

        true_locations = group[["true_lat", "true_lon"]].to_numpy(dtype=float).tolist()
        pred_locations = group[["pred_lat", "pred_lon"]].to_numpy(dtype=float).tolist()

        folium.CircleMarker(
            location=[float(group.iloc[0]["last_lat"]), float(group.iloc[0]["last_lon"])],
            radius=5,
            color="#0f172a",
            fill=True,
            fill_opacity=0.9,
            tooltip=f"MMSI {mmsi} sample {sample_index} last observed",
        ).add_to(start_layer)

        if len(true_locations) >= 2:
            folium.PolyLine(
                true_locations,
                color="#2563eb",
                weight=3,
                opacity=0.75,
                tooltip=f"MMSI {mmsi} actual"
            ).add_to(true_layer)

        if len(pred_locations) >= 2:
            folium.PolyLine(
                pred_locations,
                color="#dc2626",
                weight=3,
                opacity=0.8,
                tooltip=f"MMSI {mmsi} predicted"
            ).add_to(pred_layer)

        for _, row in group.iterrows():
            true_point = [float(row["true_lat"]), float(row["true_lon"])]
            pred_point = [float(row["pred_lat"]), float(row["pred_lon"])]
            color = error_color(float(row["error_m"]))

            folium.CircleMarker(
                location=pred_point,
                radius=4,
                color=color,
                fill=True,
                fill_opacity=0.9,
                popup=folium.Popup(popup_html(row), max_width=360),
                tooltip=f"{int(row['forecast_minutes'])}min: {float(row['error_m']):.1f}m",
            ).add_to(pred_layer)

            folium.PolyLine(
                [true_point, pred_point],
                color=color,
                weight=1.5,
                opacity=0.65
            ).add_to(error_layer)

            add_label(row, label_layer)

    for layer in [start_layer, true_layer, pred_layer, error_layer, label_layer]:
        layer.add_to(busan_map)

    folium.LayerControl().add_to(busan_map)

    output_path = Path(output_path)
    busan_map.save(output_path)

    print(f"Saved map: {output_path.resolve()}")
    display(busan_map)

    return busan_map


trajectory_map = visualize_trajectory_map(
    trajectory_results_df,
    trajectory_paths,
    output_path="trajectory_prediction_map_top5_bottom5.html",
    top_n=5,
    bottom_n=5,
    selection_horizon=5,
    max_steps=20,
    zoom=12
)
# Out:
# Selected top samples: [41, 3, 97, 17, 119]
# Selected bottom samples: [107, 15, 138, 132, 82]
# Total displayed samples: 10
# Saved map: C:\Users\HP\Downloads\trajectory_prediction_map_top5_bottom5.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_317a9f94e3cfb1da91784b405d1af540 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_317a9f94e3cfb1da91784b405d1af540&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_317a9f94e3cfb1da91784b405d1af540 = L.map(
#                 &quot;map_317a9f94e3cfb1da91784b405d1af540&quot;,
#                 {
#                     center: [35.104, 129.075],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_600622e02f1f518ae93fc0231146aad5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_600622e02f1f518ae93fc0231146aad5.addTo(map_317a9f94e3cfb1da91784b405d1af540);
#
#
#             var feature_group_a0b8634e8d4dc4c7c269426b8cbabd53 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_6f4ea7f84d70ed1add6bb6ba26de60de = L.circleMarker(
#                 [34.99655403225806, 128.79457069892482],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a0b8634e8d4dc4c7c269426b8cbabd53);
#
#
#             circle_marker_6f4ea7f84d70ed1add6bb6ba26de60de.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 636022111 sample 3 last observed
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_9913b2038b47fe928dd6debd57ad98dd = L.circleMarker(
#                 [35.05208688888889, 128.78179911111113],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a0b8634e8d4dc4c7c269426b8cbabd53);
#
#
#             circle_marker_9913b2038b47fe928dd6debd57ad98dd.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 211886810 sample 15 last observed
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_4029b4a98a7ff33936cbaaf78ed76b01 = L.circleMarker(
#                 [35.0741861111111, 128.79410882716044],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a0b8634e8d4dc4c7c269426b8cbabd53);
#
#
#             circle_marker_4029b4a98a7ff33936cbaaf78ed76b01.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 563004600 sample 17 last observed
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_f8ecb257b0b2854ff0afc611acaf2d12 = L.circleMarker(
#                 [35.074709166666665, 128.8005083333333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_a0b8634e8d4dc4c7c269426b8cbabd53);
#
#
#             circle_marker_f8ecb257b0b2854ff0afc611acaf2d12.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 477871500 sample 41 last observed

# %%
# 24. 속도 구간별 예측 오차 분석
# 목적: 저속/접안/대기 구간에서 예측 오차가 커지는지 확인

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


def add_start_sog_if_missing(trajectory_results_df, trajectory_paths):
    result_df = trajectory_results_df.copy()

    if "start_sog" in result_df.columns:
        return result_df

    start_sog_rows = []

    for item in trajectory_paths:
        row = {
            "MMSI": item["MMSI"],
            "base_time": item["base_time"],
            "start_sog": np.nan
        }

        if "raw_seq" in item:
            row["start_sog"] = item["raw_seq"][-1][2]

        start_sog_rows.append(row)

    start_sog_df = pd.DataFrame(start_sog_rows)

    if len(start_sog_df) == 0:
        print("start_sog를 복구할 수 없습니다. #19에서 start_sog를 저장하도록 수정하는 것이 좋습니다.")
        result_df["start_sog"] = np.nan
        return result_df

    result_df = result_df.merge(
        start_sog_df,
        on=["MMSI", "base_time"],
        how="left"
    )

    return result_df


trajectory_sog_df = add_start_sog_if_missing(
    trajectory_results_df,
    trajectory_paths
)

if trajectory_sog_df["start_sog"].isna().all():
    print("start_sog 값이 모두 비어 있습니다.")
    print("정확한 분석을 위해 #18 또는 #19에서 start_sog를 trajectory_results_df에 저장해야 합니다.")
else:
    trajectory_sog_df["sog_bin"] = pd.cut(
        trajectory_sog_df["start_sog"],
        bins=[-0.1, 1, 5, 100],
        labels=[
            "0-1 kt (very low / docking)",
            "1-5 kt (low-speed maneuvering)",
            "5+ kt (moving)"
        ]
    )

    sog_error_summary = (
        trajectory_sog_df
        .dropna(subset=["sog_bin"])
        .groupby(["forecast_minutes", "sog_bin"])
        .agg(
            count=("error_km", "count"),
            mean_error_km=("error_km", "mean"),
            median_error_km=("error_km", "median"),
            rmse_km=("error_km", lambda x: np.sqrt(np.mean(np.square(x)))),
            p90_error_km=("error_km", lambda x: np.percentile(x, 90)),
            max_error_km=("error_km", "max")
        )
        .reset_index()
    )

    display(sog_error_summary)

    plt.figure(figsize=(10, 5))

    for sog_bin, group in sog_error_summary.groupby("sog_bin"):
        plt.plot(
            group["forecast_minutes"],
            group["mean_error_km"],
            marker="o",
            label=str(sog_bin)
        )

    plt.xlabel("Forecast Horizon (minutes)")
    plt.ylabel("Mean Haversine Error (km)")
    plt.title("Trajectory Prediction Error by SOG Group")
    plt.grid(True)
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))

    for sog_bin, group in sog_error_summary.groupby("sog_bin"):
        plt.plot(
            group["forecast_minutes"],
            group["median_error_km"],
            marker="s",
            label=str(sog_bin)
        )

    plt.xlabel("Forecast Horizon (minutes)")
    plt.ylabel("Median Haversine Error (km)")
    plt.title("Median Prediction Error by SOG Group")
    plt.grid(True)
    plt.legend()
    plt.show()
# Out:
#     forecast_minutes                         sog_bin  count  mean_error_km  \
# 0                  5     0-1 kt (very low / docking)      7       0.041077
# 1                  5  1-5 kt (low-speed maneuvering)     51       0.068081
# 2                  5                  5+ kt (moving)     81       0.089147
# 3                 10     0-1 kt (very low / docking)      2       0.025340
# 4                 10  1-5 kt (low-speed maneuvering)     38       0.166878
# 5                 10                  5+ kt (moving)     65       0.255155
# 6                 15     0-1 kt (very low / docking)      2       0.333475
# 7                 15  1-5 kt (low-speed maneuvering)     21       0.371117
# 8                 15                  5+ kt (moving)     54       0.439475
# 9                 30     0-1 kt (very low / docking)      1       0.779326
# 10                30  1-5 kt (low-speed maneuvering)      2       3.012409
# 11                30                  5+ kt (moving)     10       1.105031
# 12                60  1-5 kt (low-speed maneuvering)      1      11.565052
#
#     median_error_km    rmse_km  p90_error_km  max_error_km
# 0          0.026912   0.050143      0.083345      0.094540
# 1          0.050312   0.102289      0.116854      0.529116
# 2          0.076426   0.104126      0.139014      0.306974
# 3          0.025340   0.026494      0.031528      0.033075
# 4          0.112972   0.266496      0.308368      1.204130
# 5          0.251952   0.298527      0.468363      0.725465
# 6          0.333475   0.389648      0.494711      0.535020
# 7          0.175864   0.657737      0.724446      2.578222
# 8          0.379305   0.530620      0.859300      1.367470
# 9          0.779326   0.779326      0.779326      0.779326
# 10         3.012409   4.022204      5.144603      5.677651
# 11         0.671470   1.426920      2.521034      3.099852
# 12        11.565052  11.565052     11.565052     11.565052

# %%
# Folium 지도 시각화: 5/10/15/30분 평균 오차 기준 상위 5개, 하위 5개 샘플만 표시

import folium
import pandas as pd
import numpy as np
from pathlib import Path
from IPython.display import display

trajectory_results_df = pd.DataFrame(trajectory_records)

BUSAN_PORT_CENTER = [35.104, 129.075]


def error_color(error_m):
    if error_m <= 50:
        return "#16a34a"   # green
    if error_m <= 100:
        return "#f97316"   # orange
    return "#dc2626"       # red


def popup_html(row):
    return "<br>".join([
        f"<b>MMSI</b>: {int(row['mmsi'])}",
        f"<b>Sample</b>: {int(row['sample_index'])}",
        f"<b>Step</b>: {int(row['step'])}",
        f"<b>Forecast</b>: {int(row['forecast_minutes'])} min",
        f"<b>Base Time</b>: {row['base_time']}",
        f"<b>True</b>: ({row['true_lat']:.6f}, {row['true_lon']:.6f})",
        f"<b>Pred</b>: ({row['pred_lat']:.6f}, {row['pred_lon']:.6f})",
        f"<b>Error</b>: {row['error_m']:.2f} m",
    ])


def add_label(row, layer):
    color = error_color(float(row["error_m"]))
    label = f"{int(row['forecast_minutes'])}min: {float(row['error_m']):.1f}m"

    html = (
        f'<div style="font-size:11px;font-weight:700;color:{color};'
        'background:rgba(255,255,255,0.82);border:1px solid #d1d5db;'
        'border-radius:3px;padding:1px 3px;white-space:nowrap;">'
        f"{label}</div>"
    )

    folium.Marker(
        location=[float(row["pred_lat"]), float(row["pred_lon"])],
        icon=folium.DivIcon(html=html),
    ).add_to(layer)


def build_map_dataframe(trajectory_results_df, trajectory_paths):
    result_df = trajectory_results_df.copy()

    result_df = result_df.rename(columns={
        "MMSI": "mmsi",
        "actual_lat": "true_lat",
        "actual_lon": "true_lon"
    })

    start_rows = []

    for sample_index, item in enumerate(trajectory_paths):
        start_rows.append({
            "sample_index": sample_index,
            "mmsi": item["MMSI"],
            "base_time": item["base_time"],
            "last_lat": item["start_lat"],
            "last_lon": item["start_lon"]
        })

    start_df = pd.DataFrame(start_rows)

    result_df = result_df.merge(
        start_df,
        on=["mmsi", "base_time"],
        how="inner"
    )

    result_df["step"] = (result_df["forecast_minutes"] // 5).astype(int)
    result_df["error_m"] = result_df["error_km"] * 1000

    result_df = result_df[
        [
            "sample_index",
            "mmsi",
            "base_time",
            "step",
            "forecast_minutes",
            "last_lat",
            "last_lon",
            "true_lat",
            "true_lon",
            "pred_lat",
            "pred_lon",
            "error_m"
        ]
    ].dropna()

    return result_df


def visualize_top_bottom_trajectory_map(
    trajectory_results_df,
    trajectory_paths,
    output_path="trajectory_prediction_map_top5_bottom5_30min.html",
    top_n=5,
    bottom_n=5,
    selection_horizons=[5, 10, 15, 30],
    center_lat=BUSAN_PORT_CENTER[0],
    center_lon=BUSAN_PORT_CENTER[1],
    zoom=12
):
    data = build_map_dataframe(trajectory_results_df, trajectory_paths)

    data["sample_index"] = data["sample_index"].astype(int)
    data["step"] = data["step"].astype(int)

    horizon_data = data[
        data["forecast_minutes"].isin(selection_horizons)
    ].copy()

    sample_score_df = (
        horizon_data
        .groupby("sample_index")
        .agg(
            mmsi=("mmsi", "first"),
            base_time=("base_time", "first"),
            mean_error_m=("error_m", "mean"),
            median_error_m=("error_m", "median"),
            max_error_m=("error_m", "max"),
            count=("error_m", "count")
        )
        .reset_index()
    )

    # 5/10/15/30분 네 horizon이 모두 있는 샘플만 후보로 사용
    sample_score_df = sample_score_df[
        sample_score_df["count"] >= len(selection_horizons)
    ].copy()

    top_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=True)
        .head(top_n)
    )

    bottom_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=False)
        .head(bottom_n)
    )

    selected_sample_ids = pd.concat([
        top_samples["sample_index"],
        bottom_samples["sample_index"]
    ]).drop_duplicates()

    data = data[
        data["sample_index"].isin(selected_sample_ids)
        & data["forecast_minutes"].isin(selection_horizons)
    ].copy()

    print("Selection horizons:", selection_horizons)

    print("Top samples by mean error")
    display(top_samples)

    print("Bottom samples by mean error")
    display(bottom_samples)

    print("Displayed samples:", data["sample_index"].nunique())

    busan_map = folium.Map(
        location=[center_lat, center_lon],
        zoom_start=zoom,
        tiles="OpenStreetMap"
    )

    start_layer = folium.FeatureGroup(name="Last observed positions", show=True)
    true_layer = folium.FeatureGroup(name="Actual future trajectories", show=True)
    pred_layer = folium.FeatureGroup(name="Predicted future trajectories", show=True)
    error_layer = folium.FeatureGroup(name="Prediction error lines", show=True)
    label_layer = folium.FeatureGroup(name="Error labels", show=True)

    for sample_index, group in data.groupby("sample_index", sort=False):
        group = group.sort_values("step")
        mmsi = int(group.iloc[0]["mmsi"])

        true_locations = group[["true_lat", "true_lon"]].to_numpy(dtype=float).tolist()
        pred_locations = group[["pred_lat", "pred_lon"]].to_numpy(dtype=float).tolist()

        folium.CircleMarker(
            location=[float(group.iloc[0]["last_lat"]), float(group.iloc[0]["last_lon"])],
            radius=5,
            color="#0f172a",
            fill=True,
            fill_opacity=0.9,
            tooltip=f"MMSI {mmsi} sample {sample_index} last observed",
        ).add_to(start_layer)

        if len(true_locations) >= 2:
            folium.PolyLine(
                true_locations,
                color="#2563eb",
                weight=3,
                opacity=0.75,
                tooltip=f"MMSI {mmsi} actual"
            ).add_to(true_layer)

        if len(pred_locations) >= 2:
            folium.PolyLine(
                pred_locations,
                color="#dc2626",
                weight=3,
                opacity=0.8,
                tooltip=f"MMSI {mmsi} predicted"
            ).add_to(pred_layer)

        for _, row in group.iterrows():
            true_point = [float(row["true_lat"]), float(row["true_lon"])]
            pred_point = [float(row["pred_lat"]), float(row["pred_lon"])]
            color = error_color(float(row["error_m"]))

            folium.CircleMarker(
                location=pred_point,
                radius=4,
                color=color,
                fill=True,
                fill_opacity=0.9,
                popup=folium.Popup(popup_html(row), max_width=360),
                tooltip=f"{int(row['forecast_minutes'])}min: {float(row['error_m']):.1f}m",
            ).add_to(pred_layer)

            folium.PolyLine(
                [true_point, pred_point],
                color=color,
                weight=1.5,
                opacity=0.65
            ).add_to(error_layer)

            add_label(row, label_layer)

    for layer in [start_layer, true_layer, pred_layer, error_layer, label_layer]:
        layer.add_to(busan_map)

    folium.LayerControl().add_to(busan_map)

    output_path = Path(output_path)
    busan_map.save(output_path)

    print(f"Saved map: {output_path.resolve()}")
    display(busan_map)

    return busan_map, top_samples, bottom_samples


trajectory_map, top_samples_df, bottom_samples_df = visualize_top_bottom_trajectory_map(
    trajectory_results_df,
    trajectory_paths,
    output_path="trajectory_prediction_map_top5_bottom5_30min.html",
    top_n=5,
    bottom_n=5,
    selection_horizons=[5, 10, 15, 30],
    zoom=12
)
# Out:
# Selection horizons: [5, 10, 15, 30]
# Top samples by mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 23             23  256592000 2024-08-07 03:20:00    305.906312
# 100           100  636018572 2024-08-23 01:50:00    333.652834
# 36             36  232024772 2024-08-10 11:05:00    378.068640
# 77             77  211111000 2024-08-19 03:20:00    383.832208
# 60             60  219629000 2024-08-16 03:00:00    409.077383
#
#      median_error_m  max_error_m  count
# 23       344.855517   433.031866      4
# 100      319.512755   587.418499      4
# 36       428.343801   567.152593      4
# 77       348.777745   768.980882      4
# 60       396.649790   678.092005      4
# Bottom samples by mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 107           107  356093000 2024-08-24 19:30:00   2497.279888
# 16             16  636018380 2024-08-06 00:20:00   1276.853177
# 82             82  538005732 2024-08-20 08:55:00   1073.421271
# 15             15  211886810 2024-08-05 11:15:00    536.446359
# 22             22  636021244 2024-08-07 00:35:00    452.264000
#
#      median_error_m  max_error_m  count
# 107     1891.176068  5677.651193      4
# 16       944.085496  3099.851854      4
# 82       818.727889  2456.721232      4
# 15       564.280141   710.251277      4
# 22       200.575992  1355.001652      4
# Displayed samples: 10
# Saved map: C:\Users\HP\Downloads\trajectory_prediction_map_top5_bottom5_30min.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d84526a8dc60f1f5f89dfefbf8ad961f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d84526a8dc60f1f5f89dfefbf8ad961f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d84526a8dc60f1f5f89dfefbf8ad961f = L.map(
#                 &quot;map_d84526a8dc60f1f5f89dfefbf8ad961f&quot;,
#                 {
#                     center: [35.104, 129.075],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7076e4d660c91f11bfae8d54e9ff71c6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7076e4d660c91f11bfae8d54e9ff71c6.addTo(map_d84526a8dc60f1f5f89dfefbf8ad961f);
#
#
#             var feature_group_c08d2d2e1bee37b798883ec89d5c1865 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_2334a5d373696a834ae306842259edbb = L.circleMarker(
#                 [35.05208688888889, 128.78179911111113],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c08d2d2e1bee37b798883ec89d5c1865);
#
#
#             circle_marker_2334a5d373696a834ae306842259edbb.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 211886810 sample 15 last observed
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_bc48e2d1871469f07443809ee3962186 = L.circleMarker(
#                 [35.046226875, 128.78431249999997],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c08d2d2e1bee37b798883ec89d5c1865);
#
#
#             circle_marker_bc48e2d1871469f07443809ee3962186.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 636018380 sample 16 last observed
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_fc6571812ccec2b9582008e63713549b = L.circleMarker(
#                 [35.06578811111111, 128.79164316666663],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c08d2d2e1bee37b798883ec89d5c1865);
#
#
#             circle_marker_fc6571812ccec2b9582008e63713549b.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 636021244 sample 22 last observed
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_d14f425f98973668dcee3f0481a29d24 = L.circleMarker(
#                 [35.06917500000001, 128.803977],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0f172a&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0f172a&quot;, &quot;fillOpacity&quot;: 0.9, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_c08d2d2e1bee37b798883ec89d5c1865);
#
#
#             circle_marker_d14f425f98973668dcee3f0481a29d24.bindTooltip(
#                 `&lt;div&gt;
#                      MMSI 256592000 sample 23 last observed

# %%
# 상위 5개 / 하위 5개 샘플: 위도-경도 그래프
# 기준: 5/10/15/30분 평균 오차
# 60분 제외

import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import pandas as pd
import numpy as np


SELECTION_HORIZONS = [5, 10, 15, 30]
TOP_N = 5
BOTTOM_N = 5


def build_plot_dataframe(trajectory_results_df, trajectory_paths):
    result_df = trajectory_results_df.copy()

    result_df = result_df.rename(columns={
        "MMSI": "mmsi",
        "actual_lat": "true_lat",
        "actual_lon": "true_lon"
    })

    start_rows = []

    for sample_index, item in enumerate(trajectory_paths):
        start_rows.append({
            "sample_index": sample_index,
            "mmsi": item["MMSI"],
            "base_time": item["base_time"],
            "last_lat": item["start_lat"],
            "last_lon": item["start_lon"]
        })

    start_df = pd.DataFrame(start_rows)

    result_df = result_df.merge(
        start_df,
        on=["mmsi", "base_time"],
        how="inner"
    )

    result_df["error_m"] = result_df["error_km"] * 1000

    result_df = result_df[
        [
            "sample_index",
            "mmsi",
            "base_time",
            "forecast_minutes",
            "last_lat",
            "last_lon",
            "true_lat",
            "true_lon",
            "pred_lat",
            "pred_lon",
            "error_m"
        ]
    ].dropna()

    return result_df


def select_top_bottom_samples_for_plot(
    trajectory_results_df,
    trajectory_paths,
    selection_horizons=[5, 10, 15, 30],
    top_n=5,
    bottom_n=5
):
    plot_df = build_plot_dataframe(trajectory_results_df, trajectory_paths)

    horizon_df = plot_df[
        plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    sample_score_df = (
        horizon_df
        .groupby("sample_index")
        .agg(
            mmsi=("mmsi", "first"),
            base_time=("base_time", "first"),
            mean_error_m=("error_m", "mean"),
            median_error_m=("error_m", "median"),
            max_error_m=("error_m", "max"),
            count=("error_m", "count")
        )
        .reset_index()
    )

    # 5/10/15/30분 결과가 모두 있는 샘플만 사용
    sample_score_df = sample_score_df[
        sample_score_df["count"] >= len(selection_horizons)
    ].copy()

    top_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=True)
        .head(top_n)
    )

    bottom_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=False)
        .head(bottom_n)
    )

    return plot_df, top_samples, bottom_samples


def plot_latlon_pred_actual(
    plot_df,
    selected_samples,
    title,
    selection_horizons=[5, 10, 15, 30],
    draw_error_lines=False
):
    selected_ids = selected_samples["sample_index"].tolist()

    data = plot_df[
        plot_df["sample_index"].isin(selected_ids)
        & plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    plt.figure(figsize=(11, 9))

    colors = plt.cm.tab10(np.linspace(0, 1, max(len(selected_ids), 1)))
    plot_count = 0

    for i, sample_index in enumerate(selected_ids):
        group = data[data["sample_index"] == sample_index].sort_values("forecast_minutes")

        if len(group) == 0:
            continue

        color = colors[i]
        plot_count += 1

        mmsi = int(group.iloc[0]["mmsi"])

        # 시작 위치
        plt.scatter(
            group.iloc[0]["last_lon"],
            group.iloc[0]["last_lat"],
            color=color,
            marker="o",
            s=70,
            edgecolor="black",
            linewidth=0.8
        )

        # 실제 움직임
        plt.plot(
            group["true_lon"],
            group["true_lat"],
            color=color,
            linestyle="-",
            marker="x",
            linewidth=1.5,
            label=f"Actual {i}: {mmsi}"
        )

        # 예측 움직임
        plt.plot(
            group["pred_lon"],
            group["pred_lat"],
            color=color,
            linestyle="--",
            marker="*",
            linewidth=1.5,
            label=f"Pred {i}: {mmsi}"
        )

        # forecast label
        for _, row in group.iterrows():
            plt.text(
                row["pred_lon"],
                row["pred_lat"],
                f"{int(row['forecast_minutes'])}min",
                fontsize=7,
                color=color
            )

        # 예측-실제 연결선
        if draw_error_lines:
            for _, row in group.iterrows():
                plt.plot(
                    [row["true_lon"], row["pred_lon"]],
                    [row["true_lat"], row["pred_lat"]],
                    color=color,
                    alpha=0.35,
                    linewidth=0.9
                )

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.grid(True)
    plt.legend(fontsize=8, ncol=2)

    ax = plt.gca()
    ax.xaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.ticklabel_format(style="plain", axis="both")

    plt.show()

    print("plotted samples:", plot_count)


plot_df, top_samples_df, bottom_samples_df = select_top_bottom_samples_for_plot(
    trajectory_results_df,
    trajectory_paths,
    selection_horizons=SELECTION_HORIZONS,
    top_n=TOP_N,
    bottom_n=BOTTOM_N
)

print("Top 5 samples by mean error")
display(top_samples_df)

print("Bottom 5 samples by mean error")
display(bottom_samples_df)

# 상위 5개: 실제 vs 예측 궤적
plot_latlon_pred_actual(
    plot_df,
    top_samples_df,
    title="Top 5 Samples: Predicted vs Actual Trajectories",
    selection_horizons=SELECTION_HORIZONS,
    draw_error_lines=False
)

# 상위 5개: 예측-실제 연결선 포함
plot_latlon_pred_actual(
    plot_df,
    top_samples_df,
    title="Top 5 Samples: Prediction Error Lines",
    selection_horizons=SELECTION_HORIZONS,
    draw_error_lines=True
)

# 하위 5개: 실제 vs 예측 궤적
plot_latlon_pred_actual(
    plot_df,
    bottom_samples_df,
    title="Bottom 5 Samples: Predicted vs Actual Trajectories",
    selection_horizons=SELECTION_HORIZONS,
    draw_error_lines=False
)

# 하위 5개: 예측-실제 연결선 포함
plot_latlon_pred_actual(
    plot_df,
    bottom_samples_df,
    title="Bottom 5 Samples: Prediction Error Lines",
    selection_horizons=SELECTION_HORIZONS,
    draw_error_lines=True
)
# Out:
# Top 5 samples by mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 23             23  256592000 2024-08-07 03:20:00    305.906312
# 100           100  636018572 2024-08-23 01:50:00    333.652834
# 36             36  232024772 2024-08-10 11:05:00    378.068640
# 77             77  211111000 2024-08-19 03:20:00    383.832208
# 60             60  219629000 2024-08-16 03:00:00    409.077383
#
#      median_error_m  max_error_m  count
# 23       344.855517   433.031866      4
# 100      319.512755   587.418499      4
# 36       428.343801   567.152593      4
# 77       348.777745   768.980882      4
# 60       396.649790   678.092005      4
# Bottom 5 samples by mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 107           107  356093000 2024-08-24 19:30:00   2497.279888
# 16             16  636018380 2024-08-06 00:20:00   1276.853177
# 82             82  538005732 2024-08-20 08:55:00   1073.421271
# 15             15  211886810 2024-08-05 11:15:00    536.446359
# 22             22  636021244 2024-08-07 00:35:00    452.264000
#
#      median_error_m  max_error_m  count
# 107     1891.176068  5677.651193      4
# 16       944.085496  3099.851854      4
# 82       818.727889  2456.721232      4
# 15       564.280141   710.251277      4
# 22       200.575992  1355.001652      4
# plotted samples: 5
# plotted samples: 5
# plotted samples: 5
# plotted samples: 5

# %%
# horizon별 실제 데이터가 있는 선박/샘플 수 확인

horizon_valid_summary = (
    trajectory_results_df
    .groupby("forecast_minutes")
    .agg(
        row_count=("error_km", "count"),
        vessel_count=("MMSI", "nunique"),
        sample_count=("base_time", "count")
    )
    .reset_index()
)

display(horizon_valid_summary)
# Out:
#    forecast_minutes  row_count  vessel_count  sample_count
# 0                 5        139           122           139
# 1                10        105            97           105
# 2                15         77            73            77
# 3                30         13            13            13
# 4                60          1             1             1

# %%
# 상위 5개 / 하위 5개 샘플: 15분까지 예측 그래프
# 기준: 5/10/15분 평균 오차
# x축: Longitude, y축: Latitude

import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import pandas as pd
import numpy as np


SELECTION_HORIZONS = [5, 10, 15]
TOP_N = 5
BOTTOM_N = 5


def build_plot_dataframe_15min(trajectory_results_df, trajectory_paths):
    result_df = trajectory_results_df.copy()

    result_df = result_df.rename(columns={
        "MMSI": "mmsi",
        "actual_lat": "true_lat",
        "actual_lon": "true_lon"
    })

    start_rows = []

    for sample_index, item in enumerate(trajectory_paths):
        start_rows.append({
            "sample_index": sample_index,
            "mmsi": item["MMSI"],
            "base_time": item["base_time"],
            "last_lat": item["start_lat"],
            "last_lon": item["start_lon"]
        })

    start_df = pd.DataFrame(start_rows)

    result_df = result_df.merge(
        start_df,
        on=["mmsi", "base_time"],
        how="inner"
    )

    result_df["error_m"] = result_df["error_km"] * 1000

    result_df = result_df[
        [
            "sample_index",
            "mmsi",
            "base_time",
            "forecast_minutes",
            "last_lat",
            "last_lon",
            "true_lat",
            "true_lon",
            "pred_lat",
            "pred_lon",
            "error_m"
        ]
    ].dropna()

    return result_df


def select_top_bottom_samples_15min(
    trajectory_results_df,
    trajectory_paths,
    selection_horizons=[5, 10, 15],
    top_n=5,
    bottom_n=5
):
    plot_df = build_plot_dataframe_15min(trajectory_results_df, trajectory_paths)

    horizon_df = plot_df[
        plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    sample_score_df = (
        horizon_df
        .groupby("sample_index")
        .agg(
            mmsi=("mmsi", "first"),
            base_time=("base_time", "first"),
            mean_error_m=("error_m", "mean"),
            median_error_m=("error_m", "median"),
            max_error_m=("error_m", "max"),
            count=("error_m", "count")
        )
        .reset_index()
    )

    # 5/10/15분 결과가 모두 있는 샘플만 사용
    sample_score_df = sample_score_df[
        sample_score_df["count"] >= len(selection_horizons)
    ].copy()

    top_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=True)
        .head(top_n)
    )

    bottom_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=False)
        .head(bottom_n)
    )

    return plot_df, top_samples, bottom_samples


def plot_latlon_pred_actual_15min(
    plot_df,
    selected_samples,
    title,
    selection_horizons=[5, 10, 15],
    draw_error_lines=False
):
    selected_ids = selected_samples["sample_index"].tolist()

    data = plot_df[
        plot_df["sample_index"].isin(selected_ids)
        & plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    plt.figure(figsize=(11, 9))

    colors = plt.cm.tab10(np.linspace(0, 1, max(len(selected_ids), 1)))
    plot_count = 0

    for i, sample_index in enumerate(selected_ids):
        group = data[data["sample_index"] == sample_index].sort_values("forecast_minutes")

        if len(group) == 0:
            continue

        color = colors[i]
        plot_count += 1

        mmsi = int(group.iloc[0]["mmsi"])

        # 시작 위치
        plt.scatter(
            group.iloc[0]["last_lon"],
            group.iloc[0]["last_lat"],
            color=color,
            marker="o",
            s=70,
            edgecolor="black",
            linewidth=0.8
        )

        # 실제 움직임
        plt.plot(
            group["true_lon"],
            group["true_lat"],
            color=color,
            linestyle="-",
            marker="x",
            linewidth=1.5,
            label=f"Actual {i}: {mmsi}"
        )

        # 예측 움직임
        plt.plot(
            group["pred_lon"],
            group["pred_lat"],
            color=color,
            linestyle="--",
            marker="*",
            linewidth=1.5,
            label=f"Pred {i}: {mmsi}"
        )

        # forecast label
        for _, row in group.iterrows():
            plt.text(
                row["pred_lon"],
                row["pred_lat"],
                f"{int(row['forecast_minutes'])}min",
                fontsize=7,
                color=color
            )

        # 예측-실제 연결선
        if draw_error_lines:
            for _, row in group.iterrows():
                plt.plot(
                    [row["true_lon"], row["pred_lon"]],
                    [row["true_lat"], row["pred_lat"]],
                    color=color,
                    alpha=0.35,
                    linewidth=0.9
                )

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.grid(True)
    plt.legend(fontsize=8, ncol=2)

    ax = plt.gca()
    ax.xaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.ticklabel_format(style="plain", axis="both")

    plt.show()

    print("plotted samples:", plot_count)


plot_df_15min, top_samples_15min_df, bottom_samples_15min_df = select_top_bottom_samples_15min(
    trajectory_results_df,
    trajectory_paths,
    selection_horizons=SELECTION_HORIZONS,
    top_n=TOP_N,
    bottom_n=BOTTOM_N
)

print("Top 5 samples by 5/10/15min mean error")
display(top_samples_15min_df)

print("Bottom 5 samples by 5/10/15min mean error")
display(bottom_samples_15min_df)

# 상위 5개: 실제 vs 예측 궤적
plot_latlon_pred_actual_15min(
    plot_df_15min,
    top_samples_15min_df,
    title="Top 5 Samples: Predicted vs Actual Trajectories (up to 15min)",
    selection_horizons=SELECTION_HORIZONS,
    draw_error_lines=False
)

# 상위 5개: 예측-실제 연결선 포함
plot_latlon_pred_actual_15min(
    plot_df_15min,
    top_samples_15min_df,
    title="Top 5 Samples: Prediction Error Lines (up to 15min)",
    selection_horizons=SELECTION_HORIZONS,
    draw_error_lines=True
)

# 하위 5개: 실제 vs 예측 궤적
plot_latlon_pred_actual_15min(
    plot_df_15min,
    bottom_samples_15min_df,
    title="Bottom 5 Samples: Predicted vs Actual Trajectories (up to 15min)",
    selection_horizons=SELECTION_HORIZONS,
    draw_error_lines=False
)

# 하위 5개: 예측-실제 연결선 포함
plot_latlon_pred_actual_15min(
    plot_df_15min,
    bottom_samples_15min_df,
    title="Bottom 5 Samples: Prediction Error Lines (up to 15min)",
    selection_horizons=SELECTION_HORIZONS,
    draw_error_lines=True
)
# Out:
# Top 5 samples by 5/10/15min mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 0               0  477845600 2024-08-01 05:55:00     44.788671
# 54             54  309046000 2024-08-14 15:20:00     48.219927
# 116           116  477690700 2024-08-26 02:00:00     49.291610
# 109           109  431241000 2024-08-25 09:00:00     50.044513
# 7               7  351248000 2024-08-02 11:55:00     52.533173
#
#      median_error_m  max_error_m  count
# 0         46.153556    55.578457      3
# 54        42.613017    69.636440      3
# 116       25.351059    99.571332      3
# 109       60.343059    63.928056      3
# 7         72.396288    75.520398      3
# Bottom 5 samples by 5/10/15min mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 107           107  356093000 2024-08-24 19:30:00   1437.156120
# 16             16  636018380 2024-08-06 00:20:00    669.186952
# 138           138  477947700 2024-08-31 19:25:00    623.670769
# 82             82  538005732 2024-08-20 08:55:00    612.321284
# 6               6  431808000 2024-08-02 04:15:00    597.376134
#
#      median_error_m  max_error_m  count
# 107     1204.129931  2578.222205      3
# 16       520.700668  1367.470325      3
# 138      725.465191   880.302080      3
# 82       587.092339  1050.363438      3
# 6        621.207736   974.285580      3
# plotted samples: 5
# plotted samples: 5
# plotted samples: 5
# plotted samples: 5

# %%
# 24. 15분 이내 예측: 선박 속도 구간별 오류 변화 분석
# 기준 horizon: 5분, 10분, 15분

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

HORIZONS_15MIN = [5, 10, 15, 30, 60]

if "start_sog" not in trajectory_results_df.columns:
    raise ValueError(
        "trajectory_results_df에 start_sog 컬럼이 없습니다. "
        "#18/#19에서 start_sog를 저장하도록 수정한 뒤 다시 실행해야 합니다."
    )

sog_analysis_df = trajectory_results_df[
    trajectory_results_df["forecast_minutes"].isin(HORIZONS_15MIN)
].copy()

sog_analysis_df["sog_bin"] = pd.cut(
    sog_analysis_df["start_sog"],
    bins=[-0.1, 1, 5, 100],
    labels=[
        "0-1 kt (very low / docking)",
        "1-5 kt (low-speed maneuvering)",
        "5+ kt (moving)"
    ]
)

sog_error_summary_15min = (
    sog_analysis_df
    .dropna(subset=["sog_bin"])
    .groupby(["forecast_minutes", "sog_bin"])
    .agg(
        count=("error_km", "count"),
        mean_error_km=("error_km", "mean"),
        median_error_km=("error_km", "median"),
        rmse_km=("error_km", lambda x: np.sqrt(np.mean(np.square(x)))),
        p90_error_km=("error_km", lambda x: np.percentile(x, 90)),
        max_error_km=("error_km", "max")
    )
    .reset_index()
)

display(sog_error_summary_15min)

# 평균 오차 그래프
plt.figure(figsize=(10, 5))

for sog_bin, group in sog_error_summary_15min.groupby("sog_bin"):
    plt.plot(
        group["forecast_minutes"],
        group["mean_error_km"],
        marker="o",
        linewidth=1.8,
        label=str(sog_bin)
    )

plt.xlabel("Forecast Horizon (minutes)")
plt.ylabel("Mean Haversine Error (km)")
plt.title("Mean Prediction Error by SOG Group (up to 15min)")
plt.xticks(HORIZONS_15MIN)
plt.grid(True)
plt.legend()
plt.show()


# 중앙값 오차 그래프
plt.figure(figsize=(10, 5))

for sog_bin, group in sog_error_summary_15min.groupby("sog_bin"):
    plt.plot(
        group["forecast_minutes"],
        group["median_error_km"],
        marker="s",
        linewidth=1.8,
        label=str(sog_bin)
    )

plt.xlabel("Forecast Horizon (minutes)")
plt.ylabel("Median Haversine Error (km)")
plt.title("Median Prediction Error by SOG Group (up to 15min)")
plt.xticks(HORIZONS_15MIN)
plt.grid(True)
plt.legend()
plt.show()
# Out:
#     forecast_minutes                         sog_bin  count  mean_error_km  \
# 0                  5     0-1 kt (very low / docking)      7       0.041077
# 1                  5  1-5 kt (low-speed maneuvering)     51       0.068081
# 2                  5                  5+ kt (moving)     81       0.089147
# 3                 10     0-1 kt (very low / docking)      2       0.025340
# 4                 10  1-5 kt (low-speed maneuvering)     38       0.166878
# 5                 10                  5+ kt (moving)     65       0.255155
# 6                 15     0-1 kt (very low / docking)      2       0.333475
# 7                 15  1-5 kt (low-speed maneuvering)     21       0.371117
# 8                 15                  5+ kt (moving)     54       0.439475
# 9                 30     0-1 kt (very low / docking)      1       0.779326
# 10                30  1-5 kt (low-speed maneuvering)      2       3.012409
# 11                30                  5+ kt (moving)     10       1.105031
# 12                60  1-5 kt (low-speed maneuvering)      1      11.565052
#
#     median_error_km    rmse_km  p90_error_km  max_error_km
# 0          0.026912   0.050143      0.083345      0.094540
# 1          0.050312   0.102289      0.116854      0.529116
# 2          0.076426   0.104126      0.139014      0.306974
# 3          0.025340   0.026494      0.031528      0.033075
# 4          0.112972   0.266496      0.308368      1.204130
# 5          0.251952   0.298527      0.468363      0.725465
# 6          0.333475   0.389648      0.494711      0.535020
# 7          0.175864   0.657737      0.724446      2.578222
# 8          0.379305   0.530620      0.859300      1.367470
# 9          0.779326   0.779326      0.779326      0.779326
# 10         3.012409   4.022204      5.144603      5.677651
# 11         0.671470   1.426920      2.521034      3.099852
# 12        11.565052  11.565052     11.565052     11.565052

# %%
# 19-B. 4~8월 전체 데이터 대상 Multi-horizon 선박 궤적 예측 실행
# 기존 test-only 결과 변수와 섞이지 않도록 allmonth_ 접두사를 사용한다.
# 주의: 4~7월은 학습/검증 기간이므로 최종 test 성능이 아니라 coverage/시각화/분석용이다.

ALLMONTH_NUM_BASE_TIMES = 1500
ALLMONTH_PREDICTION_SCOPE = "All months 4-8"

allmonth_prediction_raw = moving_resampled.copy()
allmonth_prediction_norm = all_norm.copy()

print("Prediction scope:", ALLMONTH_PREDICTION_SCOPE)
print("allmonth_prediction_raw:", allmonth_prediction_raw.shape)
print("allmonth_prediction_norm:", allmonth_prediction_norm.shape)

allmonth_base_times = generate_base_times(
    allmonth_prediction_raw,
    forecast_minutes=MAX_FORECAST_MINUTES,
    num_base_times=ALLMONTH_NUM_BASE_TIMES
)

allmonth_trajectory_records = []
allmonth_trajectory_paths = []

model.eval()

for base_idx, base_time in enumerate(allmonth_base_times):
    print(f"[{base_idx + 1}/{len(allmonth_base_times)}] base_time: {base_time}")

    allmonth_pred_inputs = make_prediction_inputs_at_base_time(
        allmonth_prediction_raw,
        allmonth_prediction_norm,
        base_time,
        seq_len=SEQ_LEN
    )

    if len(allmonth_pred_inputs) == 0:
        print("예측 가능한 이동 선박 없음. skip")
        continue

    print("prediction input vessels:", len(allmonth_pred_inputs))

    for item in allmonth_pred_inputs:
        mmsi = item["MMSI"]
        vessel_base_time = item["base_time"]

        allmonth_pred_path = recursive_forecast_path(
            model,
            item["raw_seq"],
            item["norm_seq"],
            forecast_minutes=MAX_FORECAST_MINUTES
        )

        allmonth_actual_path = get_actual_path_for_horizons(
            allmonth_prediction_raw,
            mmsi,
            vessel_base_time,
            FORECAST_MINUTES_LIST
        )

        if len(allmonth_actual_path) == 0:
            continue

        allmonth_pred_horizon = allmonth_pred_path[
            allmonth_pred_path["forecast_minutes"].isin(FORECAST_MINUTES_LIST)
        ].copy()

        allmonth_merged = allmonth_pred_horizon.merge(
            allmonth_actual_path,
            on="forecast_minutes",
            suffixes=("_pred", "_actual")
        )

        if len(allmonth_merged) == 0:
            continue

        for _, row in allmonth_merged.iterrows():
            allmonth_error_km = haversine_km(
                row["lat_actual"],
                row["lon_actual"],
                row["lat_pred"],
                row["lon_pred"]
            )

            allmonth_trajectory_records.append({
                "prediction_scope": ALLMONTH_PREDICTION_SCOPE,
                "base_time": vessel_base_time,
                "MMSI": mmsi,
                "start_sog": item.get("start_sog", np.nan),
                "forecast_minutes": row["forecast_minutes"],
                "pred_lat": row["lat_pred"],
                "pred_lon": row["lon_pred"],
                "actual_lat": row["lat_actual"],
                "actual_lon": row["lon_actual"],
                "error_km": allmonth_error_km,
                "error_nm": allmonth_error_km / 1.852
            })

        allmonth_trajectory_paths.append({
            "prediction_scope": ALLMONTH_PREDICTION_SCOPE,
            "base_time": vessel_base_time,
            "MMSI": mmsi,
            "start_lat": item["start_lat"],
            "start_lon": item["start_lon"],
            "start_sog": item.get("start_sog", np.nan),
            "raw_seq": item["raw_seq"],
            "pred_path": allmonth_pred_horizon.reset_index(drop=True),
            "actual_path": allmonth_actual_path.reset_index(drop=True)
        })

allmonth_trajectory_results_df = pd.DataFrame(allmonth_trajectory_records)

print("allmonth trajectory result rows:", len(allmonth_trajectory_results_df))
print("allmonth trajectory paths:", len(allmonth_trajectory_paths))

if len(allmonth_trajectory_results_df) > 0:
    display(allmonth_trajectory_results_df.head())
else:
    print("평가 가능한 allmonth trajectory 결과가 없습니다.")
# Out:
# Prediction scope: All months 4-8
# allmonth_prediction_raw: (86871, 12)
# allmonth_prediction_norm: (86871, 12)
# [1/1500] base_time: 2024-04-01 00:00:00
# 예측 가능한 이동 선박 없음. skip
# [2/1500] base_time: 2024-04-01 02:00:00
# prediction input vessels: 1
# [3/1500] base_time: 2024-04-01 04:25:00
# prediction input vessels: 1
# [4/1500] base_time: 2024-04-01 06:25:00
# prediction input vessels: 5
# [5/1500] base_time: 2024-04-01 09:30:00
# prediction input vessels: 1
# [6/1500] base_time: 2024-04-01 12:45:00
# 예측 가능한 이동 선박 없음. skip
# [7/1500] base_time: 2024-04-01 14:50:00
# prediction input vessels: 5
# [8/1500] base_time: 2024-04-01 16:50:00
# prediction input vessels: 3
# [9/1500] base_time: 2024-04-01 18:50:00
# prediction input vessels: 3
# [10/1500] base_time: 2024-04-01 22:20:00
# 예측 가능한 이동 선박 없음. skip
# [11/1500] base_time: 2024-04-02 00:20:00
# prediction input vessels: 2
# [12/1500] base_time: 2024-04-02 02:25:00
# prediction input vessels: 6
# [13/1500] base_time: 2024-04-02 05:45:00
# prediction input vessels: 2
# [14/1500] base_time: 2024-04-02 12:10:00
# prediction input vessels: 1
# [15/1500] base_time: 2024-04-02 17:55:00
# 예측 가능한 이동 선박 없음. skip
# [16/1500] base_time: 2024-04-02 19:55:00
# prediction input vessels: 4
# [17/1500] base_time: 2024-04-03 02:25:00
# 예측 가능한 이동 선박 없음. skip
# [18/1500] base_time: 2024-04-03 05:05:00
# prediction input vessels: 2
# [19/1500] base_time: 2024-04-03 07:05:00
# prediction input vessels: 3
# [20/1500] base_time: 2024-04-03 09:05:00
# prediction input vessels: 6
# [21/1500] base_time: 2024-04-03 11:50:00
# 예측 가능한 이동 선박 없음. skip
# [22/1500] base_time: 2024-04-03 13:50:00
# prediction input vessels: 3
# [23/1500] base_time: 2024-04-03 15:55:00
# prediction input vessels: 6
# [24/1500] base_time: 2024-04-03 18:00:00
# prediction input vessels: 4
# [25/1500] base_time: 2024-04-03 20:55:00
# prediction input vessels: 1
# [26/1500] base_time: 2024-04-03 23:40:00
# 예측 가능한 이동 선박 없음. skip
# [27/1500] base_time: 2024-04-04 01:40:00
# prediction input vessels: 3
# [28/1500] base_time: 2024-04-04 03:45:00
# prediction input vessels: 3
# [29/1500] base_time: 2024-04-04 06:15:00
# 예측 가능한 이동 선박 없음. skip
# [30/1500] base_time: 2024-04-04 09:05:00
# prediction input vessels: 1
# [31/1500] base_time: 2024-04-04 11:15:00
# 예측 가능한 이동 선박 없음. skip
# [32/1500] base_time: 2024-04-04 13:25:00
# prediction input vessels: 8
# [33/1500] base_time: 2024-04-04 16:35:00
# prediction input vessels: 3
# [34/1500] base_time: 2024-04-04 18:35:00
# prediction input vessels: 5
# [35/1500] base_time: 2024-04-04 23:05:00
# prediction input vessels: 2
# [36/1500] base_time: 2024-04-05 01:55:00
# 예측 가능한 이동 선박 없음. skip
# [37/1500] base_time: 2024-04-05 03:55:00
# prediction input vessels: 2
# [38/1500] base_time: 2024-04-05 06:00:00
# prediction input vessels: 4
# [39/1500] base_time: 2024-04-05 08:00:00
# prediction input vessels: 3
# [40/1500] base_time: 2024-04-05 12:10:00
# prediction input vessels: 1
# [41/1500] base_time: 2024-04-05 14:20:00
# prediction input vessels: 2
# [42/1500] base_time: 2024-04-05 17:15:00
# prediction input vessels: 2
# [43/1500] base_time: 2024-04-05 19:15:00
# prediction input vessels: 5
# [44/1500] base_time: 2024-04-05 23:35:00
# prediction input vessels: 3
# [45/1500] base_time: 2024-04-06 01:35:00
# prediction input vessels: 3
# [46/1500] base_time: 2024-04-06 03:45:00
# prediction input vessels: 5
# [47/1500] base_time: 2024-04-06 06:30:00
# 예측 가능한 이동 선박 없음. skip
# [48/1500] base_time: 2024-04-06 09:15:00
# 예측 가능한 이동 선박 없음. skip
# [49/1500] base_time: 2024-04-06 11:20:00
# prediction input vessels: 2
# [50/1500] base_time: 2024-04-06 13:20:00
# prediction input vessels: 2
# [51/1500] base_time: 2024-04-06 15:20:00
# prediction input vessels: 4
# [52/1500] base_time: 2024-04-06 17:20:00
# prediction input vessels: 3
# [53/1500] base_time: 2024-04-06 20:25:00
# prediction input vessels: 1
# [54/1500] base_time: 2024-04-06 22:30:00
# prediction input vessels: 3
# [55/1500] base_time: 2024-04-07 00:40:00
# prediction input vessels: 2
# [56/1500] base_time: 2024-04-07 02:40:00
# prediction input vessels: 2
# [57/1500] base_time: 2024-04-07 05:00:00
# prediction input vessels: 1
# [58/1500] base_time: 2024-04-07 07:00:00
# prediction input vessels: 4
# [59/1500] base_time: 2024-04-07 09:05:00
# prediction input vessels: 5
# [60/1500] base_time: 2024-04-07 11:05:00
# prediction input vessels: 5
# [61/1500] base_time: 2024-04-07 13:50:00
# prediction input vessels: 1
# [62/1500] base_time: 2024-04-07 16:10:00
# prediction input vessels: 1
# [63/1500] base_time: 2024-04-07 18:20:00
# prediction input vessels: 2
# [64/1500] base_time: 2024-04-07 20:20:00
# prediction input vessels: 2
# [65/1500] base_time: 2024-04-07 22:35:00
# prediction input vessels: 1
# [66/1500] base_time: 2024-04-08 00:35:00
# prediction input vessels: 7
# [67/1500] base_time: 2024-04-08 03:10:00
# prediction input vessels: 2
# [68/1500] base_time: 2024-04-08 06:35:00
# prediction input vessels: 2
# [69/1500] base_time: 2024-04-08 09:50:00
# prediction input vessels: 1
# [70/1500] base_time: 2024-04-08 13:15:00
# 예측 가능한 이동 선박 없음. skip
# [71/1500] base_time: 2024-04-08 15:15:00
# prediction input vessels: 1
# [72/1500] base_time: 2024-04-08 18:05:00
# prediction input vessels: 1
# [73/1500] base_time: 2024-04-08 20:05:00
# prediction input vessels: 2
# [74/1500] base_time: 2024-04-08 23:00:00
# prediction input vessels: 1
# [75/1500] base_time: 2024-04-09 03:30:00
# 예측 가능한 이동 선박 없음. skip
# [76/1500] base_time: 2024-04-09 06:00:00
# prediction input vessels: 1
# [77/1500] base_time: 2024-04-09 08:00:00
# prediction input vessels: 4
# [78/1500] base_time: 2024-04-09 10:00:00
# prediction input vessels: 5
# [79/1500] base_time: 2024-04-09 14:15:00
# 예측 가능한 이동 선박 없음. skip
# [80/1500] base_time: 2024-04-09 16:45:00
# prediction input vessels: 4
# [81/1500] base_time: 2024-04-09 18:45:00
# prediction input vessels: 3
# [82/1500] base_time: 2024-04-09 21:10:00
# prediction input vessels: 3
# [83/1500] base_time: 2024-04-09 23:10:00
# prediction input vessels: 4
# [84/1500] base_time: 2024-04-10 02:50:00
# 예측 가능한 이동 선박 없음. skip
# [85/1500] base_time: 2024-04-10 06:00:00
# prediction input vessels: 1
# [86/1500] base_time: 2024-04-10 08:05:00
# prediction input vessels: 3
# [87/1500] base_time: 2024-04-10 11:05:00
# 예측 가능한 이동 선박 없음. skip
# [88/1500] base_time: 2024-04-10 13:20:00
# prediction input vessels: 2
# [89/1500] base_time: 2024-04-10 15:20:00
# prediction input vessels: 3
# [90/1500] base_time: 2024-04-10 17:20:00
# prediction input vessels: 5
# [91/1500] base_time: 2024-04-10 19:40:00
# prediction input vessels: 6
# [92/1500] base_time: 2024-04-11 00:00:00
# 예측 가능한 이동 선박 없음. skip
# [93/1500] base_time: 2024-04-11 02:00:00
# prediction input vessels: 1
# [94/1500] base_time: 2024-04-11 04:50:00
# prediction input vessels: 1
# [95/1500] base_time: 2024-04-11 06:50:00
# prediction input vessels: 2
# [96/1500] base_time: 2024-04-11 08:55:00
# prediction input vessels: 7
# [97/1500] base_time: 2024-04-11 10:55:00
# prediction input vessels: 3
# [98/1500] base_time: 2024-04-11 12:55:00
# prediction input vessels: 2
# [99/1500] base_time: 2024-04-11 15:10:00
# prediction input vessels: 1
# [100/1500] base_time: 2024-04-11 17:10:00
# prediction input vessels: 6
# [101/1500] base_time: 2024-04-11 19:15:00
# prediction input vessels: 3
# [102/1500] base_time: 2024-04-11 21:15:00
# prediction input vessels: 2
# [103/1500] base_time: 2024-04-11 23:15:00
# prediction input vessels: 2
# [104/1500] base_time: 2024-04-12 02:00:00
# prediction input vessels: 1
# [105/1500] base_time: 2024-04-12 04:00:00
# prediction input vessels: 3
# [106/1500] base_time: 2024-04-12 06:05:00
# 예측 가능한 이동 선박 없음. skip
# [107/1500] base_time: 2024-04-12 09:15:00
# prediction input vessels: 1
# [108/1500] base_time: 2024-04-12 11:35:00
# prediction input vessels: 1
# [109/1500] base_time: 2024-04-12 13:35:00
# prediction input vessels: 2
# [110/1500] base_time: 2024-04-12 17:00:00
# 예측 가능한 이동 선박 없음. skip
# [111/1500] base_time: 2024-04-12 19:05:00
# prediction input vessels: 1
# [112/1500] base_time: 2024-04-12 21:10:00
# prediction input vessels: 2
# [113/1500] base_time: 2024-04-12 23:40:00
# prediction input vessels: 1
# [114/1500] base_time: 2024-04-13 02:00:00
# prediction input vessels: 2
# [115/1500] base_time: 2024-04-13 04:40:00
# prediction input vessels: 7
# [116/1500] base_time: 2024-04-13 06:45:00
# prediction input vessels: 1
# [117/1500] base_time: 2024-04-13 08:50:00
# prediction input vessels: 2
# [118/1500] base_time: 2024-04-13 11:00:00
# prediction input vessels: 2
# [119/1500] base_time: 2024-04-13 14:40:00
# prediction input vessels: 2
# [120/1500] base_time: 2024-04-13 16:40:00
# prediction input vessels: 4
# [121/1500] base_time: 2024-04-13 18:40:00
# prediction input vessels: 2
# [122/1500] base_time: 2024-04-13 21:00:00
# prediction input vessels: 2
# [123/1500] base_time: 2024-04-13 23:00:00
# prediction input vessels: 3
# [124/1500] base_time: 2024-04-14 01:00:00
# prediction input vessels: 4
# [125/1500] base_time: 2024-04-14 03:00:00
# prediction input vessels: 4
# [126/1500] base_time: 2024-04-14 05:20:00
# prediction input vessels: 1
# [127/1500] base_time: 2024-04-14 08:10:00
# prediction input vessels: 4
# [128/1500] base_time: 2024-04-14 11:25:00
# 예측 가능한 이동 선박 없음. skip
# [129/1500] base_time: 2024-04-14 14:25:00
# 예측 가능한 이동 선박 없음. skip
# [130/1500] base_time: 2024-04-14 16:25:00
# prediction input vessels: 2
# [131/1500] base_time: 2024-04-14 19:10:00
# 예측 가능한 이동 선박 없음. skip
# [132/1500] base_time: 2024-04-14 21:40:00
# prediction input vessels: 2
# [133/1500] base_time: 2024-04-14 23:45:00
# prediction input vessels: 6
# [134/1500] base_time: 2024-04-15 04:50:00
# 예측 가능한 이동 선박 없음. skip
# [135/1500] base_time: 2024-04-15 06:50:00
# prediction input vessels: 2
# [136/1500] base_time: 2024-04-15 09:10:00
# prediction input vessels: 1
# [137/1500] base_time: 2024-04-15 11:10:00
# prediction input vessels: 3
# [138/1500] base_time: 2024-04-15 13:15:00
# prediction input vessels: 4
# [139/1500] base_time: 2024-04-15 15:15:00
# prediction input vessels: 3
# [140/1500] base_time: 2024-04-15 17:15:00
# prediction input vessels: 5
# [141/1500] base_time: 2024-04-15 19:15:00
# prediction input vessels: 2
# [142/1500] base_time: 2024-04-15 22:35:00
# 예측 가능한 이동 선박 없음. skip
# [143/1500] base_time: 2024-04-16 01:00:00
# prediction input vessels: 1
# [144/1500] base_time: 2024-04-16 04:15:00
# prediction input vessels: 3
# [145/1500] base_time: 2024-04-16 06:15:00
# prediction input vessels: 3
# [146/1500] base_time: 2024-04-16 08:15:00
# prediction input vessels: 1
# [147/1500] base_time: 2024-04-16 10:15:00
# prediction input vessels: 3
# [148/1500] base_time: 2024-04-16 12:20:00
# prediction input vessels: 1
# [149/1500] base_time: 2024-04-16 15:20:00
# prediction input vessels: 1
# [150/1500] base_time: 2024-04-16 17:25:00
# prediction input vessels: 1
# [151/1500] base_time: 2024-04-16 19:25:00
# prediction input vessels: 2
# [152/1500] base_time: 2024-04-16 22:25:00
# prediction input vessels: 2
# [153/1500] base_time: 2024-04-17 01:45:00
# prediction input vessels: 2
# [154/1500] base_time: 2024-04-17 04:05:00
# prediction input vessels: 1
# [155/1500] base_time: 2024-04-17 06:05:00
# prediction input vessels: 3
# [156/1500] base_time: 2024-04-17 08:05:00
# prediction input vessels: 4
# [157/1500] base_time: 2024-04-17 13:20:00
# 예측 가능한 이동 선박 없음. skip
# [158/1500] base_time: 2024-04-17 16:25:00
# prediction input vessels: 1
# [159/1500] base_time: 2024-04-17 18:30:00
# prediction input vessels: 4
# [160/1500] base_time: 2024-04-17 20:30:00
# prediction input vessels: 5
# [161/1500] base_time: 2024-04-17 22:50:00
# 예측 가능한 이동 선박 없음. skip
# [162/1500] base_time: 2024-04-18 00:50:00
# prediction input vessels: 3
# [163/1500] base_time: 2024-04-18 02:50:00
# prediction input vessels: 1
# [164/1500] base_time: 2024-04-18 05:50:00
# prediction input vessels: 3
# [165/1500] base_time: 2024-04-18 07:55:00
# prediction input vessels: 5
# [166/1500] base_time: 2024-04-18 09:55:00
# prediction input vessels: 2
# [167/1500] base_time: 2024-04-18 13:20:00
# prediction input vessels: 2
# [168/1500] base_time: 2024-04-18 16:00:00
# 예측 가능한 이동 선박 없음. skip
# [169/1500] base_time: 2024-04-18 18:50:00
# prediction input vessels: 3
# [170/1500] base_time: 2024-04-18 21:15:00
# prediction input vessels: 1
# [171/1500] base_time: 2024-04-18 23:15:00
# prediction input vessels: 1
# [172/1500] base_time: 2024-04-19 01:15:00
# prediction input vessels: 3
# [173/1500] base_time: 2024-04-19 05:50:00
# prediction input vessels: 2
# [174/1500] base_time: 2024-04-19 08:10:00
# prediction input vessels: 5
# [175/1500] base_time: 2024-04-19 10:20:00
# prediction input vessels: 2
# [176/1500] base_time: 2024-04-19 12:30:00
# prediction input vessels: 2
# [177/1500] base_time: 2024-04-19 14:30:00
# prediction input vessels: 3
# [178/1500] base_time: 2024-04-19 16:35:00
# prediction input vessels: 2
# [179/1500] base_time: 2024-04-19 18:50:00
# prediction input vessels: 2
# [180/1500] base_time: 2024-04-19 22:35:00
# 예측 가능한 이동 선박 없음. skip
# [181/1500] base_time: 2024-04-20 00:35:00
# prediction input vessels: 1
# [182/1500] base_time: 2024-04-20 02:35:00
# prediction input vessels: 3
# [183/1500] base_time: 2024-04-20 07:00:00
# 예측 가능한 이동 선박 없음. skip
# [184/1500] base_time: 2024-04-20 09:55:00
# 예측 가능한 이동 선박 없음. skip
# [185/1500] base_time: 2024-04-20 11:55:00
# prediction input vessels: 4
# [186/1500] base_time: 2024-04-20 14:05:00
# prediction input vessels: 2
# [187/1500] base_time: 2024-04-20 16:40:00
# 예측 가능한 이동 선박 없음. skip
# [188/1500] base_time: 2024-04-20 18:40:00
# prediction input vessels: 2
# [189/1500] base_time: 2024-04-20 20:45:00
# prediction input vessels: 1
# [190/1500] base_time: 2024-04-20 23:50:00
# 예측 가능한 이동 선박 없음. skip
# [191/1500] base_time: 2024-04-21 02:15:00
# prediction input vessels: 4
# [192/1500] base_time: 2024-04-21 05:10:00
# prediction input vessels: 3
# [193/1500] base_time: 2024-04-21 07:10:00
# prediction input vessels: 2
# [194/1500] base_time: 2024-04-21 09:35:00
# prediction input vessels: 2
# [195/1500] base_time: 2024-04-21 11:35:00
# prediction input vessels: 2
# [196/1500] base_time: 2024-04-21 13:40:00
# prediction input vessels: 3
# [197/1500] base_time: 2024-04-21 15:40:00
# prediction input vessels: 3
# [198/1500] base_time: 2024-04-21 19:05:00
# prediction input vessels: 1
# [199/1500] base_time: 2024-04-21 21:30:00
# 예측 가능한 이동 선박 없음. skip
# [200/1500] base_time: 2024-04-21 23:30:00
# prediction input vessels: 3
# [201/1500] base_time: 2024-04-22 01:35:00
# prediction input vessels: 3
# [202/1500] base_time: 2024-04-22 04:55:00
# 예측 가능한 이동 선박 없음. skip
# [203/1500] base_time: 2024-04-22 07:05:00
# prediction input vessels: 4
# [204/1500] base_time: 2024-04-22 09:05:00
# prediction input vessels: 3
# [205/1500] base_time: 2024-04-22 11:05:00
# prediction input vessels: 3
# [206/1500] base_time: 2024-04-22 13:25:00
# 예측 가능한 이동 선박 없음. skip
# [207/1500] base_time: 2024-04-22 15:40:00
# prediction input vessels: 2
# [208/1500] base_time: 2024-04-22 18:00:00
# prediction input vessels: 2
# [209/1500] base_time: 2024-04-22 20:00:00
# prediction input vessels: 3
# [210/1500] base_time: 2024-04-23 00:05:00
# 예측 가능한 이동 선박 없음. skip
# [211/1500] base_time: 2024-04-23 02:05:00
# prediction input vessels: 5
# [212/1500] base_time: 2024-04-23 05:10:00
# prediction input vessels: 1
# [213/1500] base_time: 2024-04-23 07:10:00
# prediction input vessels: 1
# [214/1500] base_time: 2024-04-23 09:10:00
# prediction input vessels: 3
# [215/1500] base_time: 2024-04-23 11:10:00
# prediction input vessels: 4
# [216/1500] base_time: 2024-04-23 13:10:00
# prediction input vessels: 3
# [217/1500] base_time: 2024-04-23 15:15:00
# prediction input vessels: 2
# [218/1500] base_time: 2024-04-23 17:15:00
# prediction input vessels: 3
# [219/1500] base_time: 2024-04-23 20:25:00
# 예측 가능한 이동 선박 없음. skip
# [220/1500] base_time: 2024-04-24 00:00:00
# prediction input vessels: 1
# [221/1500] base_time: 2024-04-24 03:10:00
# 예측 가능한 이동 선박 없음. skip
# [222/1500] base_time: 2024-04-24 05:15:00
# prediction input vessels: 3
# [223/1500] base_time: 2024-04-24 07:15:00
# prediction input vessels: 1
# [224/1500] base_time: 2024-04-24 09:45:00
# 예측 가능한 이동 선박 없음. skip
# [225/1500] base_time: 2024-04-24 12:35:00
# 예측 가능한 이동 선박 없음. skip
# [226/1500] base_time: 2024-04-24 15:20:00
# prediction input vessels: 2
# [227/1500] base_time: 2024-04-24 17:20:00
# prediction input vessels: 6
# [228/1500] base_time: 2024-04-24 19:25:00
# prediction input vessels: 2
# [229/1500] base_time: 2024-04-24 21:25:00
# prediction input vessels: 3
# [230/1500] base_time: 2024-04-24 23:25:00
# prediction input vessels: 3
# [231/1500] base_time: 2024-04-25 01:30:00
# prediction input vessels: 2
# [232/1500] base_time: 2024-04-25 03:30:00
# prediction input vessels: 3
# [233/1500] base_time: 2024-04-25 06:05:00
# prediction input vessels: 1
# [234/1500] base_time: 2024-04-25 08:05:00
# prediction input vessels: 3
# [235/1500] base_time: 2024-04-25 10:05:00
# prediction input vessels: 2
# [236/1500] base_time: 2024-04-25 14:30:00
# 예측 가능한 이동 선박 없음. skip
# [237/1500] base_time: 2024-04-25 16:30:00
# prediction input vessels: 4
# [238/1500] base_time: 2024-04-25 18:35:00
# prediction input vessels: 4
# [239/1500] base_time: 2024-04-25 21:35:00
# 예측 가능한 이동 선박 없음. skip
# [240/1500] base_time: 2024-04-25 23:40:00
# prediction input vessels: 1
# [241/1500] base_time: 2024-04-26 04:40:00
# 예측 가능한 이동 선박 없음. skip
# [242/1500] base_time: 2024-04-26 06:50:00
# prediction input vessels: 1
# [243/1500] base_time: 2024-04-26 08:55:00
# prediction input vessels: 2
# [244/1500] base_time: 2024-04-26 11:50:00
# prediction input vessels: 2
# [245/1500] base_time: 2024-04-26 14:05:00
# prediction input vessels: 4
# [246/1500] base_time: 2024-04-26 16:05:00
# prediction input vessels: 4
# [247/1500] base_time: 2024-04-26 19:40:00
# prediction input vessels: 2
# [248/1500] base_time: 2024-04-26 21:40:00
# prediction input vessels: 2
# [249/1500] base_time: 2024-04-27 00:00:00
# prediction input vessels: 1
# [250/1500] base_time: 2024-04-27 02:00:00
# prediction input vessels: 3
# [251/1500] base_time: 2024-04-27 04:00:00
# prediction input vessels: 1
# [252/1500] base_time: 2024-04-27 06:00:00
# prediction input vessels: 1
# [253/1500] base_time: 2024-04-27 08:20:00
# prediction input vessels: 3
# [254/1500] base_time: 2024-04-27 12:30:00
# prediction input vessels: 1
# [255/1500] base_time: 2024-04-27 14:30:00
# prediction input vessels: 2
# [256/1500] base_time: 2024-04-27 16:30:00
# prediction input vessels: 2
# [257/1500] base_time: 2024-04-27 19:30:00
# prediction input vessels: 2
# [258/1500] base_time: 2024-04-27 21:30:00
# prediction input vessels: 3
# [259/1500] base_time: 2024-04-28 00:05:00
# prediction input vessels: 4
# [260/1500] base_time: 2024-04-28 02:05:00
# prediction input vessels: 4
# [261/1500] base_time: 2024-04-28 04:40:00
# prediction input vessels: 2
# [262/1500] base_time: 2024-04-28 06:40:00
# prediction input vessels: 2
# [263/1500] base_time: 2024-04-28 08:40:00
# prediction input vessels: 4
# [264/1500] base_time: 2024-04-28 11:30:00
# prediction input vessels: 2
# [265/1500] base_time: 2024-04-28 13:45:00
# prediction input vessels: 2
# [266/1500] base_time: 2024-04-28 15:45:00
# prediction input vessels: 2
# [267/1500] base_time: 2024-04-28 18:35:00
# prediction input vessels: 1
# [268/1500] base_time: 2024-04-28 20:35:00
# prediction input vessels: 4
# [269/1500] base_time: 2024-04-28 22:35:00
# prediction input vessels: 3
# [270/1500] base_time: 2024-04-29 03:05:00
# 예측 가능한 이동 선박 없음. skip
# [271/1500] base_time: 2024-04-29 05:05:00
# prediction input vessels: 4
# [272/1500] base_time: 2024-04-29 07:50:00
# 예측 가능한 이동 선박 없음. skip
# [273/1500] base_time: 2024-04-29 10:10:00
# prediction input vessels: 1
# [274/1500] base_time: 2024-04-29 13:05:00
# prediction input vessels: 2
# [275/1500] base_time: 2024-04-29 16:10:00
# prediction input vessels: 1
# [276/1500] base_time: 2024-04-29 19:00:00
# 예측 가능한 이동 선박 없음. skip
# [277/1500] base_time: 2024-04-29 21:15:00
# prediction input vessels: 1
# [278/1500] base_time: 2024-04-29 23:15:00
# prediction input vessels: 2
# [279/1500] base_time: 2024-04-30 01:15:00
# prediction input vessels: 3
# [280/1500] base_time: 2024-04-30 03:20:00
# prediction input vessels: 1
# [281/1500] base_time: 2024-04-30 05:40:00
# 예측 가능한 이동 선박 없음. skip
# [282/1500] base_time: 2024-04-30 07:40:00
# prediction input vessels: 3
# [283/1500] base_time: 2024-04-30 09:40:00
# prediction input vessels: 2
# [284/1500] base_time: 2024-04-30 11:40:00
# prediction input vessels: 1
# [285/1500] base_time: 2024-04-30 14:00:00
# prediction input vessels: 1
# [286/1500] base_time: 2024-04-30 16:05:00
# prediction input vessels: 6
# [287/1500] base_time: 2024-04-30 18:05:00
# prediction input vessels: 2
# [288/1500] base_time: 2024-04-30 20:05:00
# prediction input vessels: 2
# [289/1500] base_time: 2024-04-30 22:05:00
# prediction input vessels: 3
# [290/1500] base_time: 2024-05-01 01:55:00
# prediction input vessels: 3
# [291/1500] base_time: 2024-05-01 04:00:00
# prediction input vessels: 3
# [292/1500] base_time: 2024-05-01 07:10:00
# 예측 가능한 이동 선박 없음. skip
# [293/1500] base_time: 2024-05-01 09:10:00
# 예측 가능한 이동 선박 없음. skip
# [294/1500] base_time: 2024-05-01 12:05:00
# prediction input vessels: 2
# [295/1500] base_time: 2024-05-01 15:10:00
# prediction input vessels: 1
# [296/1500] base_time: 2024-05-01 18:15:00
# 예측 가능한 이동 선박 없음. skip
# [297/1500] base_time: 2024-05-01 20:15:00
# prediction input vessels: 5
# [298/1500] base_time: 2024-05-01 22:15:00
# prediction input vessels: 2
# [299/1500] base_time: 2024-05-02 00:15:00
# prediction input vessels: 2
# [300/1500] base_time: 2024-05-02 02:15:00
# prediction input vessels: 3
# [301/1500] base_time: 2024-05-02 04:20:00
# prediction input vessels: 2
# [302/1500] base_time: 2024-05-02 06:20:00
# prediction input vessels: 3
# [303/1500] base_time: 2024-05-02 08:40:00
# prediction input vessels: 1
# [304/1500] base_time: 2024-05-02 11:00:00
# prediction input vessels: 3
# [305/1500] base_time: 2024-05-02 13:00:00
# prediction input vessels: 3
# [306/1500] base_time: 2024-05-02 15:15:00
# prediction input vessels: 3
# [307/1500] base_time: 2024-05-02 17:30:00
# prediction input vessels: 1
# [308/1500] base_time: 2024-05-02 19:30:00
# prediction input vessels: 2
# [309/1500] base_time: 2024-05-02 23:20:00
# 예측 가능한 이동 선박 없음. skip
# [310/1500] base_time: 2024-05-03 02:30:00
# 예측 가능한 이동 선박 없음. skip
# [311/1500] base_time: 2024-05-03 04:30:00
# prediction input vessels: 2
# [312/1500] base_time: 2024-05-03 07:25:00
# 예측 가능한 이동 선박 없음. skip
# [313/1500] base_time: 2024-05-03 10:15:00
# 예측 가능한 이동 선박 없음. skip
# [314/1500] base_time: 2024-05-03 12:15:00
# prediction input vessels: 4
# [315/1500] base_time: 2024-05-03 14:15:00
# prediction input vessels: 1
# [316/1500] base_time: 2024-05-03 16:15:00
# prediction input vessels: 3
# [317/1500] base_time: 2024-05-03 20:25:00
# 예측 가능한 이동 선박 없음. skip
# [318/1500] base_time: 2024-05-03 22:50:00
# 예측 가능한 이동 선박 없음. skip
# [319/1500] base_time: 2024-05-04 00:50:00
# prediction input vessels: 4
# [320/1500] base_time: 2024-05-04 02:50:00
# prediction input vessels: 1
# [321/1500] base_time: 2024-05-04 05:10:00
# prediction input vessels: 1
# [322/1500] base_time: 2024-05-04 07:30:00
# prediction input vessels: 4
# [323/1500] base_time: 2024-05-04 10:35:00
# 예측 가능한 이동 선박 없음. skip
# [324/1500] base_time: 2024-05-04 12:35:00
# prediction input vessels: 4
# [325/1500] base_time: 2024-05-04 15:40:00
# prediction input vessels: 4
# [326/1500] base_time: 2024-05-04 17:40:00
# prediction input vessels: 11
# [327/1500] base_time: 2024-05-04 19:40:00
# prediction input vessels: 5
# [328/1500] base_time: 2024-05-04 21:45:00
# prediction input vessels: 4
# [329/1500] base_time: 2024-05-04 23:55:00
# prediction input vessels: 1
# [330/1500] base_time: 2024-05-05 02:05:00
# prediction input vessels: 1
# [331/1500] base_time: 2024-05-05 04:05:00
# prediction input vessels: 1
# [332/1500] base_time: 2024-05-05 06:05:00
# prediction input vessels: 1
# [333/1500] base_time: 2024-05-05 08:10:00
# prediction input vessels: 1
# [334/1500] base_time: 2024-05-05 10:10:00
# prediction input vessels: 2
# [335/1500] base_time: 2024-05-05 12:10:00
# prediction input vessels: 1
# [336/1500] base_time: 2024-05-05 14:10:00
# prediction input vessels: 4
# [337/1500] base_time: 2024-05-05 16:30:00
# 예측 가능한 이동 선박 없음. skip
# [338/1500] base_time: 2024-05-05 18:35:00
# prediction input vessels: 4
# [339/1500] base_time: 2024-05-05 20:35:00
# prediction input vessels: 4
# [340/1500] base_time: 2024-05-05 23:40:00
# prediction input vessels: 2
# [341/1500] base_time: 2024-05-06 05:50:00
# prediction input vessels: 1
# [342/1500] base_time: 2024-05-06 07:50:00
# prediction input vessels: 5
# [343/1500] base_time: 2024-05-06 10:00:00
# prediction input vessels: 3
# [344/1500] base_time: 2024-05-06 13:55:00
# prediction input vessels: 1
# [345/1500] base_time: 2024-05-06 15:55:00
# prediction input vessels: 2
# [346/1500] base_time: 2024-05-06 18:00:00
# prediction input vessels: 3
# [347/1500] base_time: 2024-05-06 20:30:00
# prediction input vessels: 2
# [348/1500] base_time: 2024-05-06 22:50:00
# prediction input vessels: 3
# [349/1500] base_time: 2024-05-07 01:05:00
# prediction input vessels: 3
# [350/1500] base_time: 2024-05-07 03:05:00
# prediction input vessels: 3
# [351/1500] base_time: 2024-05-07 05:05:00
# prediction input vessels: 1
# [352/1500] base_time: 2024-05-07 08:55:00
# 예측 가능한 이동 선박 없음. skip
# [353/1500] base_time: 2024-05-07 10:55:00
# prediction input vessels: 2
# [354/1500] base_time: 2024-05-07 13:25:00
# prediction input vessels: 2
# [355/1500] base_time: 2024-05-07 16:10:00
# prediction input vessels: 1
# [356/1500] base_time: 2024-05-07 19:05:00
# prediction input vessels: 1
# [357/1500] base_time: 2024-05-07 21:05:00
# prediction input vessels: 2
# [358/1500] base_time: 2024-05-08 00:10:00
# 예측 가능한 이동 선박 없음. skip
# [359/1500] base_time: 2024-05-08 02:15:00
# prediction input vessels: 1
# [360/1500] base_time: 2024-05-08 06:10:00
# prediction input vessels: 1
# [361/1500] base_time: 2024-05-08 08:10:00
# prediction input vessels: 1
# [362/1500] base_time: 2024-05-08 10:10:00
# prediction input vessels: 4
# [363/1500] base_time: 2024-05-08 12:25:00
# prediction input vessels: 1
# [364/1500] base_time: 2024-05-08 15:00:00
# prediction input vessels: 3
# [365/1500] base_time: 2024-05-08 17:00:00
# prediction input vessels: 1
# [366/1500] base_time: 2024-05-08 19:00:00
# prediction input vessels: 4
# [367/1500] base_time: 2024-05-08 22:10:00
# 예측 가능한 이동 선박 없음. skip
# [368/1500] base_time: 2024-05-09 00:35:00
# prediction input vessels: 2
# [369/1500] base_time: 2024-05-09 02:35:00
# prediction input vessels: 5
# [370/1500] base_time: 2024-05-09 04:45:00
# 예측 가능한 이동 선박 없음. skip
# [371/1500] base_time: 2024-05-09 06:45:00
# prediction input vessels: 2
# [372/1500] base_time: 2024-05-09 09:05:00
# prediction input vessels: 2
# [373/1500] base_time: 2024-05-09 12:10:00
# 예측 가능한 이동 선박 없음. skip
# [374/1500] base_time: 2024-05-09 14:10:00
# prediction input vessels: 3
# [375/1500] base_time: 2024-05-09 16:50:00
# prediction input vessels: 2
# [376/1500] base_time: 2024-05-09 20:10:00
# prediction input vessels: 1
# [377/1500] base_time: 2024-05-09 22:45:00
# prediction input vessels: 1
# [378/1500] base_time: 2024-05-10 00:45:00
# prediction input vessels: 6
# [379/1500] base_time: 2024-05-10 02:45:00
# prediction input vessels: 3
# [380/1500] base_time: 2024-05-10 04:50:00
# prediction input vessels: 6
# [381/1500] base_time: 2024-05-10 08:20:00
# 예측 가능한 이동 선박 없음. skip
# [382/1500] base_time: 2024-05-10 10:35:00
# prediction input vessels: 2
# [383/1500] base_time: 2024-05-10 12:35:00
# prediction input vessels: 4
# [384/1500] base_time: 2024-05-10 16:50:00
# prediction input vessels: 1
# [385/1500] base_time: 2024-05-10 19:10:00
# prediction input vessels: 3
# [386/1500] base_time: 2024-05-10 21:10:00
# prediction input vessels: 4
# [387/1500] base_time: 2024-05-10 23:10:00
# prediction input vessels: 6
# [388/1500] base_time: 2024-05-11 01:25:00
# prediction input vessels: 1
# [389/1500] base_time: 2024-05-11 03:25:00
# prediction input vessels: 3
# [390/1500] base_time: 2024-05-11 05:35:00
# 예측 가능한 이동 선박 없음. skip
# [391/1500] base_time: 2024-05-11 09:30:00
# 예측 가능한 이동 선박 없음. skip
# [392/1500] base_time: 2024-05-11 12:15:00
# prediction input vessels: 1
# [393/1500] base_time: 2024-05-11 14:15:00
# prediction input vessels: 2
# [394/1500] base_time: 2024-05-11 16:15:00
# prediction input vessels: 2
# [395/1500] base_time: 2024-05-11 20:00:00
# prediction input vessels: 1
# [396/1500] base_time: 2024-05-11 22:10:00
# prediction input vessels: 2
# [397/1500] base_time: 2024-05-12 00:10:00
# prediction input vessels: 3
# [398/1500] base_time: 2024-05-12 02:55:00
# 예측 가능한 이동 선박 없음. skip
# [399/1500] base_time: 2024-05-12 05:45:00
# prediction input vessels: 6
# [400/1500] base_time: 2024-05-12 07:50:00
# prediction input vessels: 2
# [401/1500] base_time: 2024-05-12 10:10:00
# prediction input vessels: 3
# [402/1500] base_time: 2024-05-12 12:10:00
# prediction input vessels: 4
# [403/1500] base_time: 2024-05-12 14:15:00
# prediction input vessels: 5
# [404/1500] base_time: 2024-05-12 16:15:00
# prediction input vessels: 3
# [405/1500] base_time: 2024-05-12 18:15:00
# prediction input vessels: 5
# [406/1500] base_time: 2024-05-12 20:20:00
# prediction input vessels: 2
# [407/1500] base_time: 2024-05-12 22:25:00
# prediction input vessels: 2
# [408/1500] base_time: 2024-05-13 02:10:00
# prediction input vessels: 1
# [409/1500] base_time: 2024-05-13 05:50:00
# prediction input vessels: 3
# [410/1500] base_time: 2024-05-13 08:35:00
# prediction input vessels: 1
# [411/1500] base_time: 2024-05-13 10:35:00
# prediction input vessels: 2
# [412/1500] base_time: 2024-05-13 12:50:00
# prediction input vessels: 3
# [413/1500] base_time: 2024-05-13 14:55:00
# prediction input vessels: 3
# [414/1500] base_time: 2024-05-13 17:10:00
# prediction input vessels: 2
# [415/1500] base_time: 2024-05-13 19:35:00
# prediction input vessels: 3
# [416/1500] base_time: 2024-05-13 21:35:00
# prediction input vessels: 2
# [417/1500] base_time: 2024-05-13 23:40:00
# prediction input vessels: 1
# [418/1500] base_time: 2024-05-14 01:45:00
# prediction input vessels: 2
# [419/1500] base_time: 2024-05-14 03:45:00
# prediction input vessels: 3
# [420/1500] base_time: 2024-05-14 06:05:00
# prediction input vessels: 3
# [421/1500] base_time: 2024-05-14 08:05:00
# prediction input vessels: 3
# [422/1500] base_time: 2024-05-14 10:10:00
# prediction input vessels: 4
# [423/1500] base_time: 2024-05-14 12:25:00
# prediction input vessels: 1
# [424/1500] base_time: 2024-05-14 14:25:00
# prediction input vessels: 3
# [425/1500] base_time: 2024-05-14 16:40:00
# prediction input vessels: 2
# [426/1500] base_time: 2024-05-14 19:10:00
# 예측 가능한 이동 선박 없음. skip
# [427/1500] base_time: 2024-05-14 21:10:00
# prediction input vessels: 1
# [428/1500] base_time: 2024-05-14 23:15:00
# prediction input vessels: 2
# [429/1500] base_time: 2024-05-15 02:15:00
# prediction input vessels: 3
# [430/1500] base_time: 2024-05-15 04:15:00
# prediction input vessels: 2
# [431/1500] base_time: 2024-05-15 06:30:00
# prediction input vessels: 3
# [432/1500] base_time: 2024-05-15 08:30:00
# prediction input vessels: 5
# [433/1500] base_time: 2024-05-15 10:50:00
# prediction input vessels: 1
# [434/1500] base_time: 2024-05-15 12:55:00
# prediction input vessels: 1
# [435/1500] base_time: 2024-05-15 14:55:00
# prediction input vessels: 3
# [436/1500] base_time: 2024-05-15 16:55:00
# prediction input vessels: 5
# [437/1500] base_time: 2024-05-15 19:40:00
# prediction input vessels: 1
# [438/1500] base_time: 2024-05-15 21:45:00
# prediction input vessels: 2
# [439/1500] base_time: 2024-05-16 00:05:00
# prediction input vessels: 4
# [440/1500] base_time: 2024-05-16 02:05:00
# prediction input vessels: 2
# [441/1500] base_time: 2024-05-16 05:15:00
# prediction input vessels: 1
# [442/1500] base_time: 2024-05-16 07:15:00
# prediction input vessels: 2
# [443/1500] base_time: 2024-05-16 10:15:00
# prediction input vessels: 1
# [444/1500] base_time: 2024-05-16 12:15:00
# prediction input vessels: 3
# [445/1500] base_time: 2024-05-16 14:50:00
# prediction input vessels: 1
# [446/1500] base_time: 2024-05-16 19:45:00
# prediction input vessels: 2
# [447/1500] base_time: 2024-05-16 22:00:00
# prediction input vessels: 1
# [448/1500] base_time: 2024-05-17 00:30:00
# 예측 가능한 이동 선박 없음. skip
# [449/1500] base_time: 2024-05-17 02:35:00
# prediction input vessels: 2
# [450/1500] base_time: 2024-05-17 04:50:00
# prediction input vessels: 3
# [451/1500] base_time: 2024-05-17 06:50:00
# prediction input vessels: 2
# [452/1500] base_time: 2024-05-17 10:35:00
# prediction input vessels: 1
# [453/1500] base_time: 2024-05-17 12:35:00
# prediction input vessels: 3
# [454/1500] base_time: 2024-05-17 15:25:00
# prediction input vessels: 1
# [455/1500] base_time: 2024-05-17 17:40:00
# prediction input vessels: 2
# [456/1500] base_time: 2024-05-17 19:40:00
# prediction input vessels: 6
# [457/1500] base_time: 2024-05-17 21:40:00
# prediction input vessels: 6
# [458/1500] base_time: 2024-05-18 01:10:00
# 예측 가능한 이동 선박 없음. skip
# [459/1500] base_time: 2024-05-18 03:15:00
# prediction input vessels: 1
# [460/1500] base_time: 2024-05-18 05:15:00
# prediction input vessels: 3
# [461/1500] base_time: 2024-05-18 08:15:00
# 예측 가능한 이동 선박 없음. skip
# [462/1500] base_time: 2024-05-18 10:35:00
# prediction input vessels: 1
# [463/1500] base_time: 2024-05-18 12:40:00
# prediction input vessels: 3
# [464/1500] base_time: 2024-05-18 15:05:00
# prediction input vessels: 1
# [465/1500] base_time: 2024-05-18 17:05:00
# prediction input vessels: 3
# [466/1500] base_time: 2024-05-18 19:05:00
# prediction input vessels: 5
# [467/1500] base_time: 2024-05-18 21:05:00
# prediction input vessels: 4
# [468/1500] base_time: 2024-05-18 23:05:00
# prediction input vessels: 4
# [469/1500] base_time: 2024-05-19 01:40:00
# prediction input vessels: 2
# [470/1500] base_time: 2024-05-19 03:45:00
# prediction input vessels: 3
# [471/1500] base_time: 2024-05-19 05:45:00
# prediction input vessels: 1
# [472/1500] base_time: 2024-05-19 07:45:00
# prediction input vessels: 3
# [473/1500] base_time: 2024-05-19 11:30:00
# 예측 가능한 이동 선박 없음. skip
# [474/1500] base_time: 2024-05-19 13:30:00
# prediction input vessels: 2
# [475/1500] base_time: 2024-05-19 15:35:00
# prediction input vessels: 3
# [476/1500] base_time: 2024-05-19 17:35:00
# prediction input vessels: 4
# [477/1500] base_time: 2024-05-19 19:35:00
# prediction input vessels: 4
# [478/1500] base_time: 2024-05-19 22:20:00
# 예측 가능한 이동 선박 없음. skip
# [479/1500] base_time: 2024-05-20 00:20:00
# prediction input vessels: 4
# [480/1500] base_time: 2024-05-20 02:35:00
# prediction input vessels: 3
# [481/1500] base_time: 2024-05-20 05:25:00
# 예측 가능한 이동 선박 없음. skip
# [482/1500] base_time: 2024-05-20 08:30:00
# prediction input vessels: 3
# [483/1500] base_time: 2024-05-20 10:30:00
# prediction input vessels: 2
# [484/1500] base_time: 2024-05-20 13:30:00
# 예측 가능한 이동 선박 없음. skip
# [485/1500] base_time: 2024-05-20 16:05:00
# 예측 가능한 이동 선박 없음. skip
# [486/1500] base_time: 2024-05-20 18:05:00
# prediction input vessels: 1
# [487/1500] base_time: 2024-05-20 20:05:00
# prediction input vessels: 4
# [488/1500] base_time: 2024-05-21 04:30:00
# 예측 가능한 이동 선박 없음. skip
# [489/1500] base_time: 2024-05-21 08:45:00
# 예측 가능한 이동 선박 없음. skip
# [490/1500] base_time: 2024-05-21 10:45:00
# prediction input vessels: 3
# [491/1500] base_time: 2024-05-21 12:50:00
# prediction input vessels: 3
# [492/1500] base_time: 2024-05-21 15:20:00
# 예측 가능한 이동 선박 없음. skip
# [493/1500] base_time: 2024-05-21 17:50:00
# prediction input vessels: 1
# [494/1500] base_time: 2024-05-21 20:05:00
# prediction input vessels: 1
# [495/1500] base_time: 2024-05-21 23:55:00
# prediction input vessels: 1
# [496/1500] base_time: 2024-05-22 02:05:00
# prediction input vessels: 2
# [497/1500] base_time: 2024-05-22 04:05:00
# prediction input vessels: 3
# [498/1500] base_time: 2024-05-22 06:05:00
# prediction input vessels: 2
# [499/1500] base_time: 2024-05-22 09:00:00
# prediction input vessels: 2
# [500/1500] base_time: 2024-05-22 12:00:00
# 예측 가능한 이동 선박 없음. skip
# [501/1500] base_time: 2024-05-22 14:15:00
# prediction input vessels: 3
# [502/1500] base_time: 2024-05-22 16:15:00
# prediction input vessels: 4
# [503/1500] base_time: 2024-05-22 18:15:00
# prediction input vessels: 3
# [504/1500] base_time: 2024-05-22 21:10:00
# 예측 가능한 이동 선박 없음. skip
# [505/1500] base_time: 2024-05-22 23:10:00
# prediction input vessels: 2
# [506/1500] base_time: 2024-05-23 01:15:00
# prediction input vessels: 3
# [507/1500] base_time: 2024-05-23 03:15:00
# prediction input vessels: 3
# [508/1500] base_time: 2024-05-23 05:15:00
# prediction input vessels: 5
# [509/1500] base_time: 2024-05-23 07:15:00
# prediction input vessels: 5
# [510/1500] base_time: 2024-05-23 10:40:00
# 예측 가능한 이동 선박 없음. skip
# [511/1500] base_time: 2024-05-23 12:40:00
# prediction input vessels: 3
# [512/1500] base_time: 2024-05-23 15:25:00
# 예측 가능한 이동 선박 없음. skip
# [513/1500] base_time: 2024-05-23 17:25:00
# prediction input vessels: 1
# [514/1500] base_time: 2024-05-23 21:15:00
# 예측 가능한 이동 선박 없음. skip
# [515/1500] base_time: 2024-05-23 23:55:00
# prediction input vessels: 2
# [516/1500] base_time: 2024-05-24 01:55:00
# prediction input vessels: 1
# [517/1500] base_time: 2024-05-24 04:45:00
# prediction input vessels: 1
# [518/1500] base_time: 2024-05-24 06:45:00
# prediction input vessels: 6
# [519/1500] base_time: 2024-05-24 08:45:00
# prediction input vessels: 4
# [520/1500] base_time: 2024-05-24 12:10:00
# prediction input vessels: 2
# [521/1500] base_time: 2024-05-24 14:15:00
# prediction input vessels: 1
# [522/1500] base_time: 2024-05-24 16:20:00
# prediction input vessels: 3
# [523/1500] base_time: 2024-05-24 18:20:00
# prediction input vessels: 3
# [524/1500] base_time: 2024-05-24 20:20:00
# prediction input vessels: 3
# [525/1500] base_time: 2024-05-24 23:25:00
# 예측 가능한 이동 선박 없음. skip
# [526/1500] base_time: 2024-05-25 01:25:00
# prediction input vessels: 3
# [527/1500] base_time: 2024-05-25 05:00:00
# prediction input vessels: 2
# [528/1500] base_time: 2024-05-25 07:00:00
# prediction input vessels: 9
# [529/1500] base_time: 2024-05-25 09:00:00
# prediction input vessels: 2
# [530/1500] base_time: 2024-05-25 11:00:00
# prediction input vessels: 3
# [531/1500] base_time: 2024-05-25 13:00:00
# prediction input vessels: 2
# [532/1500] base_time: 2024-05-25 15:00:00
# prediction input vessels: 2
# [533/1500] base_time: 2024-05-25 17:15:00
# prediction input vessels: 2
# [534/1500] base_time: 2024-05-25 19:15:00
# prediction input vessels: 1
# [535/1500] base_time: 2024-05-25 21:15:00
# prediction input vessels: 2
# [536/1500] base_time: 2024-05-26 00:25:00
# prediction input vessels: 3
# [537/1500] base_time: 2024-05-26 03:25:00
# prediction input vessels: 1
# [538/1500] base_time: 2024-05-26 05:30:00
# prediction input vessels: 1
# [539/1500] base_time: 2024-05-26 07:30:00
# prediction input vessels: 4
# [540/1500] base_time: 2024-05-26 09:30:00
# prediction input vessels: 5
# [541/1500] base_time: 2024-05-26 11:45:00
# prediction input vessels: 2
# [542/1500] base_time: 2024-05-26 13:45:00
# prediction input vessels: 3
# [543/1500] base_time: 2024-05-26 16:25:00
# prediction input vessels: 1
# [544/1500] base_time: 2024-05-26 18:25:00
# prediction input vessels: 2
# [545/1500] base_time: 2024-05-26 21:05:00
# 예측 가능한 이동 선박 없음. skip
# [546/1500] base_time: 2024-05-26 23:05:00
# prediction input vessels: 2
# [547/1500] base_time: 2024-05-27 01:05:00
# prediction input vessels: 4
# [548/1500] base_time: 2024-05-27 03:05:00
# prediction input vessels: 1
# [549/1500] base_time: 2024-05-27 05:10:00
# prediction input vessels: 3
# [550/1500] base_time: 2024-05-27 07:25:00
# prediction input vessels: 3
# [551/1500] base_time: 2024-05-27 10:05:00
# prediction input vessels: 1
# [552/1500] base_time: 2024-05-27 12:10:00
# prediction input vessels: 1
# [553/1500] base_time: 2024-05-27 14:35:00
# 예측 가능한 이동 선박 없음. skip
# [554/1500] base_time: 2024-05-27 17:15:00
# 예측 가능한 이동 선박 없음. skip
# [555/1500] base_time: 2024-05-27 19:15:00
# prediction input vessels: 2
# [556/1500] base_time: 2024-05-27 21:30:00
# prediction input vessels: 2
# [557/1500] base_time: 2024-05-28 03:50:00
# 예측 가능한 이동 선박 없음. skip
# [558/1500] base_time: 2024-05-28 06:15:00
# 예측 가능한 이동 선박 없음. skip
# [559/1500] base_time: 2024-05-28 08:20:00
# prediction input vessels: 4
# [560/1500] base_time: 2024-05-28 10:20:00
# prediction input vessels: 3
# [561/1500] base_time: 2024-05-28 12:20:00
# prediction input vessels: 1
# [562/1500] base_time: 2024-05-28 15:00:00
# 예측 가능한 이동 선박 없음. skip
# [563/1500] base_time: 2024-05-28 17:20:00
# prediction input vessels: 1
# [564/1500] base_time: 2024-05-28 19:25:00
# prediction input vessels: 4
# [565/1500] base_time: 2024-05-28 21:25:00
# prediction input vessels: 1
# [566/1500] base_time: 2024-05-29 01:05:00
# 예측 가능한 이동 선박 없음. skip
# [567/1500] base_time: 2024-05-29 03:05:00
# prediction input vessels: 4
# [568/1500] base_time: 2024-05-29 05:25:00
# 예측 가능한 이동 선박 없음. skip
# [569/1500] base_time: 2024-05-29 07:25:00
# prediction input vessels: 4
# [570/1500] base_time: 2024-05-29 09:30:00
# prediction input vessels: 2
# [571/1500] base_time: 2024-05-29 12:25:00
# prediction input vessels: 1
# [572/1500] base_time: 2024-05-29 14:25:00
# prediction input vessels: 2
# [573/1500] base_time: 2024-05-29 16:50:00
# prediction input vessels: 1
# [574/1500] base_time: 2024-05-29 19:05:00
# 예측 가능한 이동 선박 없음. skip
# [575/1500] base_time: 2024-05-29 21:10:00
# prediction input vessels: 2
# [576/1500] base_time: 2024-05-29 23:40:00
# prediction input vessels: 1
# [577/1500] base_time: 2024-05-30 01:40:00
# prediction input vessels: 5
# [578/1500] base_time: 2024-05-30 04:00:00
# prediction input vessels: 1
# [579/1500] base_time: 2024-05-30 06:00:00
# prediction input vessels: 2
# [580/1500] base_time: 2024-05-30 08:05:00
# prediction input vessels: 1
# [581/1500] base_time: 2024-05-30 10:20:00
# prediction input vessels: 1
# [582/1500] base_time: 2024-05-30 12:20:00
# prediction input vessels: 1
# [583/1500] base_time: 2024-05-30 14:55:00
# 예측 가능한 이동 선박 없음. skip
# [584/1500] base_time: 2024-05-30 16:55:00
# prediction input vessels: 2
# [585/1500] base_time: 2024-05-30 19:20:00
# 예측 가능한 이동 선박 없음. skip
# [586/1500] base_time: 2024-05-30 21:35:00
# prediction input vessels: 2
# [587/1500] base_time: 2024-05-30 23:35:00
# prediction input vessels: 3
# [588/1500] base_time: 2024-05-31 04:45:00
# 예측 가능한 이동 선박 없음. skip
# [589/1500] base_time: 2024-05-31 06:45:00
# prediction input vessels: 3
# [590/1500] base_time: 2024-05-31 08:45:00
# prediction input vessels: 4
# [591/1500] base_time: 2024-05-31 11:45:00
# 예측 가능한 이동 선박 없음. skip
# [592/1500] base_time: 2024-05-31 14:50:00
# 예측 가능한 이동 선박 없음. skip
# [593/1500] base_time: 2024-05-31 17:00:00
# prediction input vessels: 3
# [594/1500] base_time: 2024-05-31 19:05:00
# prediction input vessels: 1
# [595/1500] base_time: 2024-05-31 22:05:00
# 예측 가능한 이동 선박 없음. skip
# [596/1500] base_time: 2024-06-01 00:25:00
# prediction input vessels: 3
# [597/1500] base_time: 2024-06-01 02:25:00
# prediction input vessels: 1
# [598/1500] base_time: 2024-06-01 04:25:00
# prediction input vessels: 4
# [599/1500] base_time: 2024-06-01 07:15:00
# 예측 가능한 이동 선박 없음. skip
# [600/1500] base_time: 2024-06-01 09:25:00
# prediction input vessels: 1
# [601/1500] base_time: 2024-06-01 11:30:00
# prediction input vessels: 2
# [602/1500] base_time: 2024-06-01 13:30:00
# prediction input vessels: 3
# [603/1500] base_time: 2024-06-01 15:35:00
# prediction input vessels: 3
# [604/1500] base_time: 2024-06-01 17:35:00
# prediction input vessels: 4
# [605/1500] base_time: 2024-06-01 19:35:00
# prediction input vessels: 3
# [606/1500] base_time: 2024-06-01 21:40:00
# prediction input vessels: 4
# [607/1500] base_time: 2024-06-01 23:40:00
# prediction input vessels: 6
# [608/1500] base_time: 2024-06-02 01:40:00
# prediction input vessels: 2
# [609/1500] base_time: 2024-06-02 04:05:00
# prediction input vessels: 1
# [610/1500] base_time: 2024-06-02 06:05:00
# prediction input vessels: 3
# [611/1500] base_time: 2024-06-02 08:10:00
# prediction input vessels: 1
# [612/1500] base_time: 2024-06-02 10:25:00
# prediction input vessels: 1
# [613/1500] base_time: 2024-06-02 13:45:00
# 예측 가능한 이동 선박 없음. skip
# [614/1500] base_time: 2024-06-02 16:00:00
# prediction input vessels: 1
# [615/1500] base_time: 2024-06-02 18:10:00
# prediction input vessels: 1
# [616/1500] base_time: 2024-06-02 20:10:00
# prediction input vessels: 2
# [617/1500] base_time: 2024-06-02 23:35:00
# prediction input vessels: 1
# [618/1500] base_time: 2024-06-03 01:35:00
# prediction input vessels: 2
# [619/1500] base_time: 2024-06-03 03:35:00
# prediction input vessels: 2
# [620/1500] base_time: 2024-06-03 06:05:00
# 예측 가능한 이동 선박 없음. skip
# [621/1500] base_time: 2024-06-03 10:00:00
# 예측 가능한 이동 선박 없음. skip
# [622/1500] base_time: 2024-06-03 12:15:00
# prediction input vessels: 2
# [623/1500] base_time: 2024-06-03 14:15:00
# prediction input vessels: 1
# [624/1500] base_time: 2024-06-03 16:25:00
# prediction input vessels: 3
# [625/1500] base_time: 2024-06-03 18:25:00
# prediction input vessels: 2
# [626/1500] base_time: 2024-06-03 22:25:00
# 예측 가능한 이동 선박 없음. skip
# [627/1500] base_time: 2024-06-04 00:30:00
# prediction input vessels: 4
# [628/1500] base_time: 2024-06-04 03:10:00
# prediction input vessels: 1
# [629/1500] base_time: 2024-06-04 05:15:00
# prediction input vessels: 1
# [630/1500] base_time: 2024-06-04 07:15:00
# prediction input vessels: 4
# [631/1500] base_time: 2024-06-04 13:30:00
# prediction input vessels: 2
# [632/1500] base_time: 2024-06-04 17:45:00
# prediction input vessels: 1
# [633/1500] base_time: 2024-06-04 20:10:00
# prediction input vessels: 1
# [634/1500] base_time: 2024-06-04 22:10:00
# prediction input vessels: 4
# [635/1500] base_time: 2024-06-05 00:30:00
# prediction input vessels: 1
# [636/1500] base_time: 2024-06-05 02:55:00
# prediction input vessels: 1
# [637/1500] base_time: 2024-06-05 05:10:00
# prediction input vessels: 1
# [638/1500] base_time: 2024-06-05 07:15:00
# prediction input vessels: 1
# [639/1500] base_time: 2024-06-05 09:15:00
# prediction input vessels: 2
# [640/1500] base_time: 2024-06-05 12:00:00
# prediction input vessels: 2
# [641/1500] base_time: 2024-06-05 14:25:00
# prediction input vessels: 2
# [642/1500] base_time: 2024-06-05 18:15:00
# 예측 가능한 이동 선박 없음. skip
# [643/1500] base_time: 2024-06-05 20:20:00
# prediction input vessels: 2
# [644/1500] base_time: 2024-06-05 22:20:00
# prediction input vessels: 5
# [645/1500] base_time: 2024-06-06 00:20:00
# prediction input vessels: 5
# [646/1500] base_time: 2024-06-06 02:20:00
# prediction input vessels: 3
# [647/1500] base_time: 2024-06-06 04:20:00
# prediction input vessels: 3
# [648/1500] base_time: 2024-06-06 06:40:00
# prediction input vessels: 3
# [649/1500] base_time: 2024-06-06 08:40:00
# prediction input vessels: 4
# [650/1500] base_time: 2024-06-06 10:40:00
# prediction input vessels: 5
# [651/1500] base_time: 2024-06-06 13:10:00
# prediction input vessels: 2
# [652/1500] base_time: 2024-06-06 15:30:00
# prediction input vessels: 2
# [653/1500] base_time: 2024-06-06 19:30:00
# 예측 가능한 이동 선박 없음. skip
# [654/1500] base_time: 2024-06-06 21:50:00
# prediction input vessels: 3
# [655/1500] base_time: 2024-06-06 23:50:00
# prediction input vessels: 2
# [656/1500] base_time: 2024-06-07 01:50:00
# prediction input vessels: 3
# [657/1500] base_time: 2024-06-07 03:50:00
# prediction input vessels: 4
# [658/1500] base_time: 2024-06-07 06:05:00
# prediction input vessels: 3
# [659/1500] base_time: 2024-06-07 08:10:00
# prediction input vessels: 5
# [660/1500] base_time: 2024-06-07 10:10:00
# prediction input vessels: 4
# [661/1500] base_time: 2024-06-07 12:10:00
# prediction input vessels: 2
# [662/1500] base_time: 2024-06-07 14:15:00
# prediction input vessels: 1
# [663/1500] base_time: 2024-06-07 16:15:00
# prediction input vessels: 2
# [664/1500] base_time: 2024-06-07 19:20:00
# prediction input vessels: 2
# [665/1500] base_time: 2024-06-07 23:20:00
# prediction input vessels: 1
# [666/1500] base_time: 2024-06-08 01:20:00
# prediction input vessels: 5
# [667/1500] base_time: 2024-06-08 03:20:00
# prediction input vessels: 1
# [668/1500] base_time: 2024-06-08 05:20:00
# prediction input vessels: 4
# [669/1500] base_time: 2024-06-08 07:25:00
# prediction input vessels: 2
# [670/1500] base_time: 2024-06-08 10:15:00
# prediction input vessels: 3
# [671/1500] base_time: 2024-06-08 12:40:00
# prediction input vessels: 1
# [672/1500] base_time: 2024-06-08 14:40:00
# prediction input vessels: 6
# [673/1500] base_time: 2024-06-08 16:45:00
# prediction input vessels: 1
# [674/1500] base_time: 2024-06-08 18:45:00
# prediction input vessels: 4
# [675/1500] base_time: 2024-06-08 20:50:00
# prediction input vessels: 2
# [676/1500] base_time: 2024-06-08 23:00:00
# prediction input vessels: 1
# [677/1500] base_time: 2024-06-09 01:00:00
# prediction input vessels: 2
# [678/1500] base_time: 2024-06-09 04:00:00
# 예측 가능한 이동 선박 없음. skip
# [679/1500] base_time: 2024-06-09 06:10:00
# 예측 가능한 이동 선박 없음. skip
# [680/1500] base_time: 2024-06-09 08:15:00
# prediction input vessels: 4
# [681/1500] base_time: 2024-06-09 10:15:00
# prediction input vessels: 3
# [682/1500] base_time: 2024-06-09 14:15:00
# prediction input vessels: 2
# [683/1500] base_time: 2024-06-09 16:15:00
# prediction input vessels: 4
# [684/1500] base_time: 2024-06-09 18:15:00
# prediction input vessels: 5
# [685/1500] base_time: 2024-06-09 20:40:00
# prediction input vessels: 2
# [686/1500] base_time: 2024-06-09 22:40:00
# prediction input vessels: 3
# [687/1500] base_time: 2024-06-10 02:45:00
# prediction input vessels: 1
# [688/1500] base_time: 2024-06-10 05:20:00
# prediction input vessels: 3
# [689/1500] base_time: 2024-06-10 07:50:00
# prediction input vessels: 1
# [690/1500] base_time: 2024-06-10 09:50:00
# prediction input vessels: 2
# [691/1500] base_time: 2024-06-10 11:55:00
# prediction input vessels: 2
# [692/1500] base_time: 2024-06-10 14:35:00
# 예측 가능한 이동 선박 없음. skip
# [693/1500] base_time: 2024-06-10 16:50:00
# prediction input vessels: 3
# [694/1500] base_time: 2024-06-10 19:40:00
# 예측 가능한 이동 선박 없음. skip
# [695/1500] base_time: 2024-06-10 21:45:00
# prediction input vessels: 1
# ...
# prediction input vessels: 1
# [1288/1500] base_time: 2024-08-10 07:05:00
# 예측 가능한 이동 선박 없음. skip
# [1289/1500] base_time: 2024-08-10 10:05:00
# prediction input vessels: 1
# [1290/1500] base_time: 2024-08-10 12:10:00
# prediction input vessels: 4
# [1291/1500] base_time: 2024-08-10 14:10:00
# prediction input vessels: 3
# [1292/1500] base_time: 2024-08-10 17:55:00
# 예측 가능한 이동 선박 없음. skip
# [1293/1500] base_time: 2024-08-10 19:55:00
# prediction input vessels: 3
# [1294/1500] base_time: 2024-08-10 21:55:00
# prediction input vessels: 5
# [1295/1500] base_time: 2024-08-11 00:00:00
# prediction input vessels: 2
# [1296/1500] base_time: 2024-08-11 02:00:00
# prediction input vessels: 3
# [1297/1500] base_time: 2024-08-11 06:15:00
# 예측 가능한 이동 선박 없음. skip
# [1298/1500] base_time: 2024-08-11 09:45:00
# prediction input vessels: 2
# [1299/1500] base_time: 2024-08-11 11:45:00
# prediction input vessels: 3
# [1300/1500] base_time: 2024-08-11 14:00:00
# prediction input vessels: 1
# [1301/1500] base_time: 2024-08-11 17:05:00
# 예측 가능한 이동 선박 없음. skip
# [1302/1500] base_time: 2024-08-11 20:20:00
# 예측 가능한 이동 선박 없음. skip
# [1303/1500] base_time: 2024-08-11 22:40:00
# prediction input vessels: 1
# [1304/1500] base_time: 2024-08-12 00:40:00
# prediction input vessels: 5
# [1305/1500] base_time: 2024-08-12 02:40:00
# prediction input vessels: 4
# [1306/1500] base_time: 2024-08-12 04:45:00
# prediction input vessels: 2
# [1307/1500] base_time: 2024-08-12 07:30:00
# prediction input vessels: 1
# [1308/1500] base_time: 2024-08-12 10:35:00
# 예측 가능한 이동 선박 없음. skip
# [1309/1500] base_time: 2024-08-12 14:10:00
# prediction input vessels: 2
# [1310/1500] base_time: 2024-08-12 16:20:00
# prediction input vessels: 2
# [1311/1500] base_time: 2024-08-12 18:25:00
# prediction input vessels: 3
# [1312/1500] base_time: 2024-08-12 21:05:00
# prediction input vessels: 1
# [1313/1500] base_time: 2024-08-13 00:05:00
# 예측 가능한 이동 선박 없음. skip
# [1314/1500] base_time: 2024-08-13 03:05:00
# 예측 가능한 이동 선박 없음. skip
# [1315/1500] base_time: 2024-08-13 05:05:00
# prediction input vessels: 5
# [1316/1500] base_time: 2024-08-13 08:00:00
# 예측 가능한 이동 선박 없음. skip
# [1317/1500] base_time: 2024-08-13 10:00:00
# prediction input vessels: 5
# [1318/1500] base_time: 2024-08-13 12:10:00
# prediction input vessels: 1
# [1319/1500] base_time: 2024-08-13 14:10:00
# prediction input vessels: 2
# [1320/1500] base_time: 2024-08-13 17:45:00
# 예측 가능한 이동 선박 없음. skip
# [1321/1500] base_time: 2024-08-13 20:35:00
# prediction input vessels: 2
# [1322/1500] base_time: 2024-08-13 23:40:00
# prediction input vessels: 1
# [1323/1500] base_time: 2024-08-14 01:40:00
# prediction input vessels: 3
# [1324/1500] base_time: 2024-08-14 03:40:00
# prediction input vessels: 2
# [1325/1500] base_time: 2024-08-14 05:40:00
# 예측 가능한 이동 선박 없음. skip
# [1326/1500] base_time: 2024-08-14 07:40:00
# prediction input vessels: 4
# [1327/1500] base_time: 2024-08-14 10:30:00
# prediction input vessels: 1
# [1328/1500] base_time: 2024-08-14 12:30:00
# prediction input vessels: 5
# [1329/1500] base_time: 2024-08-14 15:05:00
# prediction input vessels: 2
# [1330/1500] base_time: 2024-08-14 17:05:00
# prediction input vessels: 3
# [1331/1500] base_time: 2024-08-14 20:10:00
# prediction input vessels: 1
# [1332/1500] base_time: 2024-08-15 00:05:00
# 예측 가능한 이동 선박 없음. skip
# [1333/1500] base_time: 2024-08-15 02:05:00
# prediction input vessels: 2
# [1334/1500] base_time: 2024-08-15 04:35:00
# prediction input vessels: 3
# [1335/1500] base_time: 2024-08-15 07:20:00
# prediction input vessels: 1
# [1336/1500] base_time: 2024-08-15 09:20:00
# prediction input vessels: 4
# [1337/1500] base_time: 2024-08-15 12:00:00
# prediction input vessels: 4
# [1338/1500] base_time: 2024-08-15 14:15:00
# prediction input vessels: 1
# [1339/1500] base_time: 2024-08-15 18:00:00
# 예측 가능한 이동 선박 없음. skip
# [1340/1500] base_time: 2024-08-15 20:00:00
# prediction input vessels: 2
# [1341/1500] base_time: 2024-08-15 22:00:00
# prediction input vessels: 1
# [1342/1500] base_time: 2024-08-16 00:10:00
# prediction input vessels: 1
# [1343/1500] base_time: 2024-08-16 02:15:00
# prediction input vessels: 2
# [1344/1500] base_time: 2024-08-16 04:40:00
# prediction input vessels: 3
# [1345/1500] base_time: 2024-08-16 06:40:00
# prediction input vessels: 2
# [1346/1500] base_time: 2024-08-16 08:40:00
# prediction input vessels: 5
# [1347/1500] base_time: 2024-08-16 10:40:00
# prediction input vessels: 3
# [1348/1500] base_time: 2024-08-16 12:55:00
# prediction input vessels: 3
# [1349/1500] base_time: 2024-08-16 15:25:00
# prediction input vessels: 2
# [1350/1500] base_time: 2024-08-16 17:40:00
# prediction input vessels: 3
# [1351/1500] base_time: 2024-08-16 21:10:00
# prediction input vessels: 1
# [1352/1500] base_time: 2024-08-16 23:50:00
# prediction input vessels: 3
# [1353/1500] base_time: 2024-08-17 01:55:00
# prediction input vessels: 1
# [1354/1500] base_time: 2024-08-17 06:05:00
# 예측 가능한 이동 선박 없음. skip
# [1355/1500] base_time: 2024-08-17 08:45:00
# prediction input vessels: 3
# [1356/1500] base_time: 2024-08-17 10:45:00
# prediction input vessels: 4
# [1357/1500] base_time: 2024-08-17 12:45:00
# prediction input vessels: 5
# [1358/1500] base_time: 2024-08-17 15:05:00
# prediction input vessels: 1
# [1359/1500] base_time: 2024-08-17 17:05:00
# prediction input vessels: 3
# [1360/1500] base_time: 2024-08-17 19:25:00
# prediction input vessels: 1
# [1361/1500] base_time: 2024-08-17 21:25:00
# prediction input vessels: 3
# [1362/1500] base_time: 2024-08-18 00:30:00
# prediction input vessels: 3
# [1363/1500] base_time: 2024-08-18 03:00:00
# prediction input vessels: 2
# [1364/1500] base_time: 2024-08-18 05:05:00
# prediction input vessels: 3
# [1365/1500] base_time: 2024-08-18 07:05:00
# prediction input vessels: 4
# [1366/1500] base_time: 2024-08-18 09:05:00
# prediction input vessels: 4
# [1367/1500] base_time: 2024-08-18 11:25:00
# prediction input vessels: 2
# [1368/1500] base_time: 2024-08-18 13:25:00
# prediction input vessels: 4
# [1369/1500] base_time: 2024-08-18 15:30:00
# prediction input vessels: 2
# [1370/1500] base_time: 2024-08-18 18:25:00
# prediction input vessels: 2
# [1371/1500] base_time: 2024-08-18 20:25:00
# prediction input vessels: 2
# [1372/1500] base_time: 2024-08-18 22:45:00
# prediction input vessels: 5
# [1373/1500] base_time: 2024-08-19 01:30:00
# prediction input vessels: 4
# [1374/1500] base_time: 2024-08-19 03:35:00
# prediction input vessels: 5
# [1375/1500] base_time: 2024-08-19 06:20:00
# 예측 가능한 이동 선박 없음. skip
# [1376/1500] base_time: 2024-08-19 10:00:00
# prediction input vessels: 2
# [1377/1500] base_time: 2024-08-19 14:45:00
# 예측 가능한 이동 선박 없음. skip
# [1378/1500] base_time: 2024-08-19 17:05:00
# 예측 가능한 이동 선박 없음. skip
# [1379/1500] base_time: 2024-08-19 19:05:00
# prediction input vessels: 7
# [1380/1500] base_time: 2024-08-19 21:15:00
# prediction input vessels: 1
# [1381/1500] base_time: 2024-08-20 00:20:00
# 예측 가능한 이동 선박 없음. skip
# [1382/1500] base_time: 2024-08-20 02:20:00
# prediction input vessels: 2
# [1383/1500] base_time: 2024-08-20 04:20:00
# prediction input vessels: 5
# [1384/1500] base_time: 2024-08-20 06:20:00
# prediction input vessels: 3
# [1385/1500] base_time: 2024-08-20 08:50:00
# prediction input vessels: 2
# [1386/1500] base_time: 2024-08-20 11:00:00
# prediction input vessels: 2
# [1387/1500] base_time: 2024-08-20 13:00:00
# prediction input vessels: 6
# [1388/1500] base_time: 2024-08-20 15:05:00
# prediction input vessels: 1
# [1389/1500] base_time: 2024-08-20 17:40:00
# prediction input vessels: 2
# [1390/1500] base_time: 2024-08-20 19:45:00
# prediction input vessels: 2
# [1391/1500] base_time: 2024-08-20 22:00:00
# prediction input vessels: 2
# [1392/1500] base_time: 2024-08-21 01:35:00
# 예측 가능한 이동 선박 없음. skip
# [1393/1500] base_time: 2024-08-21 04:45:00
# 예측 가능한 이동 선박 없음. skip
# [1394/1500] base_time: 2024-08-21 08:30:00
# prediction input vessels: 1
# [1395/1500] base_time: 2024-08-21 10:35:00
# prediction input vessels: 4
# [1396/1500] base_time: 2024-08-21 12:35:00
# prediction input vessels: 5
# [1397/1500] base_time: 2024-08-21 14:35:00
# prediction input vessels: 5
# [1398/1500] base_time: 2024-08-21 16:45:00
# prediction input vessels: 5
# [1399/1500] base_time: 2024-08-21 19:10:00
# prediction input vessels: 6
# [1400/1500] base_time: 2024-08-21 22:15:00
# 예측 가능한 이동 선박 없음. skip
# [1401/1500] base_time: 2024-08-22 00:20:00
# prediction input vessels: 2
# [1402/1500] base_time: 2024-08-22 02:40:00
# prediction input vessels: 1
# [1403/1500] base_time: 2024-08-22 04:40:00
# prediction input vessels: 3
# [1404/1500] base_time: 2024-08-22 07:10:00
# 예측 가능한 이동 선박 없음. skip
# [1405/1500] base_time: 2024-08-22 09:50:00
# 예측 가능한 이동 선박 없음. skip
# [1406/1500] base_time: 2024-08-22 12:30:00
# 예측 가능한 이동 선박 없음. skip
# [1407/1500] base_time: 2024-08-22 14:30:00
# prediction input vessels: 2
# [1408/1500] base_time: 2024-08-22 16:30:00
# prediction input vessels: 4
# [1409/1500] base_time: 2024-08-22 18:30:00
# prediction input vessels: 3
# [1410/1500] base_time: 2024-08-22 20:30:00
# prediction input vessels: 1
# [1411/1500] base_time: 2024-08-22 22:45:00
# prediction input vessels: 2
# [1412/1500] base_time: 2024-08-23 00:45:00
# prediction input vessels: 4
# [1413/1500] base_time: 2024-08-23 02:45:00
# prediction input vessels: 4
# [1414/1500] base_time: 2024-08-23 05:00:00
# prediction input vessels: 1
# [1415/1500] base_time: 2024-08-23 07:00:00
# prediction input vessels: 2
# [1416/1500] base_time: 2024-08-23 09:35:00
# prediction input vessels: 2
# [1417/1500] base_time: 2024-08-23 12:15:00
# prediction input vessels: 1
# [1418/1500] base_time: 2024-08-23 14:25:00
# prediction input vessels: 3
# [1419/1500] base_time: 2024-08-23 18:35:00
# prediction input vessels: 3
# [1420/1500] base_time: 2024-08-23 21:45:00
# 예측 가능한 이동 선박 없음. skip
# [1421/1500] base_time: 2024-08-24 00:05:00
# prediction input vessels: 1
# [1422/1500] base_time: 2024-08-24 03:50:00
# 예측 가능한 이동 선박 없음. skip
# [1423/1500] base_time: 2024-08-24 05:50:00
# prediction input vessels: 3
# [1424/1500] base_time: 2024-08-24 08:00:00
# prediction input vessels: 3
# [1425/1500] base_time: 2024-08-24 10:25:00
# prediction input vessels: 2
# [1426/1500] base_time: 2024-08-24 13:15:00
# prediction input vessels: 1
# [1427/1500] base_time: 2024-08-24 15:55:00
# prediction input vessels: 1
# [1428/1500] base_time: 2024-08-24 17:55:00
# 예측 가능한 이동 선박 없음. skip
# [1429/1500] base_time: 2024-08-24 19:55:00
# prediction input vessels: 4
# [1430/1500] base_time: 2024-08-24 22:15:00
# prediction input vessels: 1
# [1431/1500] base_time: 2024-08-25 00:15:00
# prediction input vessels: 2
# [1432/1500] base_time: 2024-08-25 04:45:00
# prediction input vessels: 1
# [1433/1500] base_time: 2024-08-25 07:15:00
# 예측 가능한 이동 선박 없음. skip
# [1434/1500] base_time: 2024-08-25 09:15:00
# prediction input vessels: 5
# [1435/1500] base_time: 2024-08-25 13:00:00
# prediction input vessels: 7
# [1436/1500] base_time: 2024-08-25 15:00:00
# prediction input vessels: 4
# [1437/1500] base_time: 2024-08-25 17:05:00
# prediction input vessels: 3
# [1438/1500] base_time: 2024-08-25 19:45:00
# prediction input vessels: 1
# [1439/1500] base_time: 2024-08-25 21:45:00
# prediction input vessels: 3
# [1440/1500] base_time: 2024-08-25 23:55:00
# prediction input vessels: 2
# [1441/1500] base_time: 2024-08-26 01:55:00
# prediction input vessels: 5
# [1442/1500] base_time: 2024-08-26 04:30:00
# prediction input vessels: 1
# [1443/1500] base_time: 2024-08-26 07:35:00
# prediction input vessels: 2
# [1444/1500] base_time: 2024-08-26 09:35:00
# prediction input vessels: 3
# [1445/1500] base_time: 2024-08-26 11:45:00
# prediction input vessels: 4
# [1446/1500] base_time: 2024-08-26 13:45:00
# prediction input vessels: 3
# [1447/1500] base_time: 2024-08-26 16:45:00
# prediction input vessels: 3
# [1448/1500] base_time: 2024-08-26 21:30:00
# 예측 가능한 이동 선박 없음. skip
# [1449/1500] base_time: 2024-08-26 23:40:00
# prediction input vessels: 2
# [1450/1500] base_time: 2024-08-27 01:50:00
# prediction input vessels: 1
# [1451/1500] base_time: 2024-08-27 03:50:00
# prediction input vessels: 2
# [1452/1500] base_time: 2024-08-27 05:50:00
# prediction input vessels: 4
# [1453/1500] base_time: 2024-08-27 08:10:00
# prediction input vessels: 2
# [1454/1500] base_time: 2024-08-27 10:30:00
# prediction input vessels: 2
# [1455/1500] base_time: 2024-08-27 13:00:00
# prediction input vessels: 1
# [1456/1500] base_time: 2024-08-27 15:05:00
# prediction input vessels: 1
# [1457/1500] base_time: 2024-08-27 17:05:00
# prediction input vessels: 1
# [1458/1500] base_time: 2024-08-27 19:20:00
# prediction input vessels: 1
# [1459/1500] base_time: 2024-08-27 21:20:00
# prediction input vessels: 2
# [1460/1500] base_time: 2024-08-28 00:00:00
# prediction input vessels: 3
# [1461/1500] base_time: 2024-08-28 02:30:00
# prediction input vessels: 1
# [1462/1500] base_time: 2024-08-28 04:30:00
# prediction input vessels: 3
# [1463/1500] base_time: 2024-08-28 07:05:00
# prediction input vessels: 1
# [1464/1500] base_time: 2024-08-28 09:10:00
# prediction input vessels: 2
# [1465/1500] base_time: 2024-08-28 11:10:00
# prediction input vessels: 3
# [1466/1500] base_time: 2024-08-28 13:10:00
# prediction input vessels: 1
# [1467/1500] base_time: 2024-08-28 15:15:00
# prediction input vessels: 1
# [1468/1500] base_time: 2024-08-28 18:00:00
# prediction input vessels: 2
# [1469/1500] base_time: 2024-08-28 20:35:00
# 예측 가능한 이동 선박 없음. skip
# [1470/1500] base_time: 2024-08-28 22:40:00
# prediction input vessels: 1
# [1471/1500] base_time: 2024-08-29 00:50:00
# prediction input vessels: 1
# [1472/1500] base_time: 2024-08-29 02:50:00
# prediction input vessels: 3
# [1473/1500] base_time: 2024-08-29 07:05:00
# prediction input vessels: 1
# [1474/1500] base_time: 2024-08-29 09:50:00
# prediction input vessels: 2
# [1475/1500] base_time: 2024-08-29 12:30:00
# 예측 가능한 이동 선박 없음. skip
# [1476/1500] base_time: 2024-08-29 15:05:00
# 예측 가능한 이동 선박 없음. skip
# [1477/1500] base_time: 2024-08-29 17:05:00
# prediction input vessels: 2
# [1478/1500] base_time: 2024-08-29 20:05:00
# 예측 가능한 이동 선박 없음. skip
# [1479/1500] base_time: 2024-08-29 22:20:00
# prediction input vessels: 1
# [1480/1500] base_time: 2024-08-30 00:20:00
# prediction input vessels: 4
# [1481/1500] base_time: 2024-08-30 02:20:00
# prediction input vessels: 3
# [1482/1500] base_time: 2024-08-30 04:20:00
# prediction input vessels: 2
# [1483/1500] base_time: 2024-08-30 06:40:00
# prediction input vessels: 1
# [1484/1500] base_time: 2024-08-30 08:40:00
# prediction input vessels: 5
# [1485/1500] base_time: 2024-08-30 12:25:00
# prediction input vessels: 1
# [1486/1500] base_time: 2024-08-30 14:50:00
# 예측 가능한 이동 선박 없음. skip
# [1487/1500] base_time: 2024-08-30 17:35:00
# prediction input vessels: 1
# [1488/1500] base_time: 2024-08-30 19:35:00
# prediction input vessels: 2
# [1489/1500] base_time: 2024-08-30 21:35:00
# prediction input vessels: 4
# [1490/1500] base_time: 2024-08-30 23:50:00
# 예측 가능한 이동 선박 없음. skip
# [1491/1500] base_time: 2024-08-31 01:50:00
# prediction input vessels: 1
# [1492/1500] base_time: 2024-08-31 04:40:00
# prediction input vessels: 1
# [1493/1500] base_time: 2024-08-31 07:05:00
# prediction input vessels: 3
# [1494/1500] base_time: 2024-08-31 09:05:00
# prediction input vessels: 2
# [1495/1500] base_time: 2024-08-31 11:10:00
# prediction input vessels: 2
# [1496/1500] base_time: 2024-08-31 13:20:00
# prediction input vessels: 1
# [1497/1500] base_time: 2024-08-31 15:25:00
# prediction input vessels: 1
# [1498/1500] base_time: 2024-08-31 17:25:00
# prediction input vessels: 5
# [1499/1500] base_time: 2024-08-31 19:25:00
# prediction input vessels: 4
# [1500/1500] base_time: 2024-08-31 22:55:00
# prediction input vessels: 2
# allmonth trajectory result rows: 1734
# allmonth trajectory paths: 760
#   prediction_scope           base_time       MMSI  start_sog  \
# 0   All months 4-8 2024-04-01 04:25:00  352002539   6.343333
# 1   All months 4-8 2024-04-01 04:25:00  352002539   6.343333
# 2   All months 4-8 2024-04-01 04:25:00  352002539   6.343333
# 3   All months 4-8 2024-04-01 06:25:00  477478700  11.806667
# 4   All months 4-8 2024-04-01 06:25:00  538007378   6.213333
#
#    forecast_minutes   pred_lat    pred_lon  actual_lat  actual_lon  error_km  \
# 0                 5  35.065132  128.780762   35.065947  128.780888  0.091365
# 1                10  35.070568  128.779221   35.071879  128.779009  0.147077
# 2                15  35.074364  128.777756   35.074621  128.776628  0.106509
# 3                 5  34.963753  128.807770   34.964300  128.807174  0.081545
# 4                 5  35.064312  128.788803   35.064401  128.788162  0.059172
#
#    error_nm
# 0  0.049333
# 1  0.079415
# 2  0.057511
# 3  0.044031
# 4  0.031950

# %%
# 4~8월 전체 예측 결과 기준: 60분까지 실제 데이터가 있는 선박/샘플 수 확인

REQUIRED_HORIZONS_60 = [5, 10, 15, 30, 60]

allmonth_60_availability = (
    allmonth_trajectory_results_df[
        allmonth_trajectory_results_df["forecast_minutes"].isin(REQUIRED_HORIZONS_60)
    ]
    .groupby(["MMSI", "base_time"])
    .agg(
        horizon_count=("forecast_minutes", "nunique"),
        horizons=("forecast_minutes", lambda x: sorted(x.unique())),
        mean_error_km=("error_km", "mean"),
        max_error_km=("error_km", "max")
    )
    .reset_index()
)

allmonth_complete_60_samples = allmonth_60_availability[
    allmonth_60_availability["horizon_count"] == len(REQUIRED_HORIZONS_60)
].copy()

print("5/10/15/30/60분이 모두 있는 sample 수:", len(allmonth_complete_60_samples))
print("5/10/15/30/60분이 모두 있는 고유 선박 수:", allmonth_complete_60_samples["MMSI"].nunique())

display(allmonth_complete_60_samples.head(30))
# Out:
# 5/10/15/30/60분이 모두 있는 sample 수: 2
# 5/10/15/30/60분이 모두 있는 고유 선박 수: 2
#           MMSI           base_time  horizon_count             horizons  \
# 458  477714600 2024-07-24 07:15:00              5  [5, 10, 15, 30, 60]
# 695  636020744 2024-04-07 00:40:00              5  [5, 10, 15, 30, 60]
#
#      mean_error_km  max_error_km
# 458       1.660342      3.915616
# 695       1.368971      3.240838

# %%
# 4~8월 전체 예측 결과 기준: 60분까지 상위 5개 / 하위 5개 그래프
# 기준 horizon: 5, 10, 15, 30, 60분 평균 오차

import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import pandas as pd
import numpy as np


ALLMONTH_SELECTION_HORIZONS_60 = [5, 10, 15, 30, 60]
ALLMONTH_TOP_N = 5
ALLMONTH_BOTTOM_N = 5


def build_allmonth_plot_dataframe(allmonth_trajectory_results_df, allmonth_trajectory_paths):
    result_df = allmonth_trajectory_results_df.copy()

    result_df = result_df.rename(columns={
        "MMSI": "mmsi",
        "actual_lat": "true_lat",
        "actual_lon": "true_lon"
    })

    start_rows = []

    for sample_index, item in enumerate(allmonth_trajectory_paths):
        start_rows.append({
            "sample_index": sample_index,
            "mmsi": item["MMSI"],
            "base_time": item["base_time"],
            "last_lat": item["start_lat"],
            "last_lon": item["start_lon"]
        })

    start_df = pd.DataFrame(start_rows)

    result_df = result_df.merge(
        start_df,
        on=["mmsi", "base_time"],
        how="inner"
    )

    result_df["error_m"] = result_df["error_km"] * 1000

    result_df = result_df[
        [
            "sample_index",
            "mmsi",
            "base_time",
            "forecast_minutes",
            "last_lat",
            "last_lon",
            "true_lat",
            "true_lon",
            "pred_lat",
            "pred_lon",
            "error_m"
        ]
    ].dropna()

    return result_df


def select_allmonth_top_bottom_samples_60min(
    allmonth_trajectory_results_df,
    allmonth_trajectory_paths,
    selection_horizons=[5, 10, 15, 30, 60],
    top_n=5,
    bottom_n=5
):
    plot_df = build_allmonth_plot_dataframe(
        allmonth_trajectory_results_df,
        allmonth_trajectory_paths
    )

    horizon_df = plot_df[
        plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    sample_score_df = (
        horizon_df
        .groupby("sample_index")
        .agg(
            mmsi=("mmsi", "first"),
            base_time=("base_time", "first"),
            mean_error_m=("error_m", "mean"),
            median_error_m=("error_m", "median"),
            max_error_m=("error_m", "max"),
            count=("error_m", "count")
        )
        .reset_index()
    )

    # 5/10/15/30/60분 결과가 모두 있는 샘플만 사용
    sample_score_df = sample_score_df[
        sample_score_df["count"] >= len(selection_horizons)
    ].copy()

    top_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=True)
        .head(top_n)
    )

    bottom_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=False)
        .head(bottom_n)
    )

    return plot_df, sample_score_df, top_samples, bottom_samples


def plot_allmonth_latlon_pred_actual_60min(
    plot_df,
    selected_samples,
    title,
    selection_horizons=[5, 10, 15, 30, 60],
    draw_error_lines=False
):
    selected_ids = selected_samples["sample_index"].tolist()

    data = plot_df[
        plot_df["sample_index"].isin(selected_ids)
        & plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    plt.figure(figsize=(11, 9))

    colors = plt.cm.tab10(np.linspace(0, 1, max(len(selected_ids), 1)))
    plot_count = 0

    for i, sample_index in enumerate(selected_ids):
        group = data[data["sample_index"] == sample_index].sort_values("forecast_minutes")

        if len(group) == 0:
            continue

        color = colors[i]
        plot_count += 1

        mmsi = int(group.iloc[0]["mmsi"])

        # 시작 위치
        plt.scatter(
            group.iloc[0]["last_lon"],
            group.iloc[0]["last_lat"],
            color=color,
            marker="o",
            s=70,
            edgecolor="black",
            linewidth=0.8
        )

        # 실제 움직임
        plt.plot(
            group["true_lon"],
            group["true_lat"],
            color=color,
            linestyle="-",
            marker="x",
            linewidth=1.5,
            label=f"Actual {i}: {mmsi}"
        )

        # 예측 움직임
        plt.plot(
            group["pred_lon"],
            group["pred_lat"],
            color=color,
            linestyle="--",
            marker="*",
            linewidth=1.5,
            label=f"Pred {i}: {mmsi}"
        )

        # forecast label
        for _, row in group.iterrows():
            plt.text(
                row["pred_lon"],
                row["pred_lat"],
                f"{int(row['forecast_minutes'])}min",
                fontsize=7,
                color=color
            )

        # 예측-실제 연결선
        if draw_error_lines:
            for _, row in group.iterrows():
                plt.plot(
                    [row["true_lon"], row["pred_lon"]],
                    [row["true_lat"], row["pred_lat"]],
                    color=color,
                    alpha=0.35,
                    linewidth=0.9
                )

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.grid(True)
    plt.legend(fontsize=8, ncol=2)

    ax = plt.gca()
    ax.xaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.ticklabel_format(style="plain", axis="both")

    plt.show()

    print("plotted samples:", plot_count)


allmonth_plot_df_60, allmonth_score_df_60, allmonth_top5_60_df, allmonth_bottom5_60_df = (
    select_allmonth_top_bottom_samples_60min(
        allmonth_trajectory_results_df,
        allmonth_trajectory_paths,
        selection_horizons=ALLMONTH_SELECTION_HORIZONS_60,
        top_n=ALLMONTH_TOP_N,
        bottom_n=ALLMONTH_BOTTOM_N
    )
)

print("60분까지 실제 데이터가 있는 sample 수:", len(allmonth_score_df_60))

print("Top 5 samples by 5/10/15/30/60min mean error")
display(allmonth_top5_60_df)

print("Bottom 5 samples by 5/10/15/30/60min mean error")
display(allmonth_bottom5_60_df)

# 상위 5개: 실제 vs 예측 궤적
plot_allmonth_latlon_pred_actual_60min(
    allmonth_plot_df_60,
    allmonth_top5_60_df,
    title="All Months Top 5 Samples: Predicted vs Actual Trajectories (up to 60min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_60,
    draw_error_lines=False
)

# 상위 5개: 예측-실제 연결선 포함
plot_allmonth_latlon_pred_actual_60min(
    allmonth_plot_df_60,
    allmonth_top5_60_df,
    title="All Months Top 5 Samples: Prediction Error Lines (up to 60min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_60,
    draw_error_lines=True
)

# 하위 5개: 실제 vs 예측 궤적
plot_allmonth_latlon_pred_actual_60min(
    allmonth_plot_df_60,
    allmonth_bottom5_60_df,
    title="All Months Bottom 5 Samples: Predicted vs Actual Trajectories (up to 60min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_60,
    draw_error_lines=False
)

# 하위 5개: 예측-실제 연결선 포함
plot_allmonth_latlon_pred_actual_60min(
    allmonth_plot_df_60,
    allmonth_bottom5_60_df,
    title="All Months Bottom 5 Samples: Prediction Error Lines (up to 60min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_60,
    draw_error_lines=True
)
# Out:
# 60분까지 실제 데이터가 있는 sample 수: 2
# Top 5 samples by 5/10/15/30/60min mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 31             31  636020744 2024-04-07 00:40:00   1368.971059
# 562           562  477714600 2024-07-24 07:15:00   1660.341901
#
#      median_error_m  max_error_m  count
# 31       838.075940  3240.838028      5
# 562     1336.602076  3915.615753      5
# Bottom 5 samples by 5/10/15/30/60min mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 562           562  477714600 2024-07-24 07:15:00   1660.341901
# 31             31  636020744 2024-04-07 00:40:00   1368.971059
#
#      median_error_m  max_error_m  count
# 562     1336.602076  3915.615753      5
# 31       838.075940  3240.838028      5
# plotted samples: 2
# plotted samples: 2
# plotted samples: 2
# plotted samples: 2

# %%
# 4~8월 전체 예측 결과 기준: 60분까지 상위 5개 / 하위 5개 그래프
# 기준 horizon: 5, 10, 15, 30, 60분 평균 오차

import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import pandas as pd
import numpy as np


ALLMONTH_SELECTION_HORIZONS_30 = [5, 10, 15, 30]
ALLMONTH_TOP_N = 5
ALLMONTH_BOTTOM_N = 5


def build_allmonth_plot_dataframe(allmonth_trajectory_results_df, allmonth_trajectory_paths):
    result_df = allmonth_trajectory_results_df.copy()

    result_df = result_df.rename(columns={
        "MMSI": "mmsi",
        "actual_lat": "true_lat",
        "actual_lon": "true_lon"
    })

    start_rows = []

    for sample_index, item in enumerate(allmonth_trajectory_paths):
        start_rows.append({
            "sample_index": sample_index,
            "mmsi": item["MMSI"],
            "base_time": item["base_time"],
            "last_lat": item["start_lat"],
            "last_lon": item["start_lon"]
        })

    start_df = pd.DataFrame(start_rows)

    result_df = result_df.merge(
        start_df,
        on=["mmsi", "base_time"],
        how="inner"
    )

    result_df["error_m"] = result_df["error_km"] * 1000

    result_df = result_df[
        [
            "sample_index",
            "mmsi",
            "base_time",
            "forecast_minutes",
            "last_lat",
            "last_lon",
            "true_lat",
            "true_lon",
            "pred_lat",
            "pred_lon",
            "error_m"
        ]
    ].dropna()

    return result_df


def select_allmonth_top_bottom_samples_30min(
    allmonth_trajectory_results_df,
    allmonth_trajectory_paths,
    selection_horizons=[5, 10, 15, 30],
    top_n=5,
    bottom_n=5
):
    plot_df = build_allmonth_plot_dataframe(
        allmonth_trajectory_results_df,
        allmonth_trajectory_paths
    )

    horizon_df = plot_df[
        plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    sample_score_df = (
        horizon_df
        .groupby("sample_index")
        .agg(
            mmsi=("mmsi", "first"),
            base_time=("base_time", "first"),
            mean_error_m=("error_m", "mean"),
            median_error_m=("error_m", "median"),
            max_error_m=("error_m", "max"),
            count=("error_m", "count")
        )
        .reset_index()
    )

    # 5/10/15/30/60분 결과가 모두 있는 샘플만 사용
    sample_score_df = sample_score_df[
        sample_score_df["count"] >= len(selection_horizons)
    ].copy()

    top_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=True)
        .head(top_n)
    )

    bottom_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=False)
        .head(bottom_n)
    )

    return plot_df, sample_score_df, top_samples, bottom_samples


def plot_allmonth_latlon_pred_actual_30min(
    plot_df,
    selected_samples,
    title,
    selection_horizons=[5, 10, 15, 30],
    draw_error_lines=False
):
    selected_ids = selected_samples["sample_index"].tolist()

    data = plot_df[
        plot_df["sample_index"].isin(selected_ids)
        & plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    plt.figure(figsize=(11, 9))

    colors = plt.cm.tab10(np.linspace(0, 1, max(len(selected_ids), 1)))
    plot_count = 0

    for i, sample_index in enumerate(selected_ids):
        group = data[data["sample_index"] == sample_index].sort_values("forecast_minutes")

        if len(group) == 0:
            continue

        color = colors[i]
        plot_count += 1

        mmsi = int(group.iloc[0]["mmsi"])

        # 시작 위치
        plt.scatter(
            group.iloc[0]["last_lon"],
            group.iloc[0]["last_lat"],
            color=color,
            marker="o",
            s=70,
            edgecolor="black",
            linewidth=0.8
        )

        # 실제 움직임
        plt.plot(
            group["true_lon"],
            group["true_lat"],
            color=color,
            linestyle="-",
            marker="x",
            linewidth=1.5,
            label=f"Actual {i}: {mmsi}"
        )

        # 예측 움직임
        plt.plot(
            group["pred_lon"],
            group["pred_lat"],
            color=color,
            linestyle="--",
            marker="*",
            linewidth=1.5,
            label=f"Pred {i}: {mmsi}"
        )

        # forecast label
        for _, row in group.iterrows():
            plt.text(
                row["pred_lon"],
                row["pred_lat"],
                f"{int(row['forecast_minutes'])}min",
                fontsize=7,
                color=color
            )

        # 예측-실제 연결선
        if draw_error_lines:
            for _, row in group.iterrows():
                plt.plot(
                    [row["true_lon"], row["pred_lon"]],
                    [row["true_lat"], row["pred_lat"]],
                    color=color,
                    alpha=0.35,
                    linewidth=0.9
                )

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.grid(True)
    plt.legend(fontsize=8, ncol=2)

    ax = plt.gca()
    ax.xaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.ticklabel_format(style="plain", axis="both")

    plt.show()

    print("plotted samples:", plot_count)


allmonth_plot_df_30, allmonth_score_df_30, allmonth_top5_30_df, allmonth_bottom5_30_df = (
    select_allmonth_top_bottom_samples_30min(
        allmonth_trajectory_results_df,
        allmonth_trajectory_paths,
        selection_horizons=ALLMONTH_SELECTION_HORIZONS_30,
        top_n=ALLMONTH_TOP_N,
        bottom_n=ALLMONTH_BOTTOM_N
    )
)

print("30분까지 실제 데이터가 있는 sample 수:", len(allmonth_score_df_30))

print("Top 5 samples by 5/10/15/30min mean error")
display(allmonth_top5_30_df)

print("Bottom 5 samples by 5/10/15/30min mean error")
display(allmonth_bottom5_30_df)

# 상위 5개: 실제 vs 예측 궤적
plot_allmonth_latlon_pred_actual_30min(
    allmonth_plot_df_30,
    allmonth_top5_30_df,
    title="All Months Top 5 Samples: Predicted vs Actual Trajectories (up to 30min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_30,
    draw_error_lines=False
)

# 상위 5개: 예측-실제 연결선 포함
plot_allmonth_latlon_pred_actual_30min(
    allmonth_plot_df_30,
    allmonth_top5_30_df,
    title="All Months Top 5 Samples: Prediction Error Lines (up to 30min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_30,
    draw_error_lines=True
)

# 하위 5개: 실제 vs 예측 궤적
plot_allmonth_latlon_pred_actual_30min(
    allmonth_plot_df_30,
    allmonth_bottom5_30_df,
    title="All Months Bottom 5 Samples: Predicted vs Actual Trajectories (up to 30min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_30,
    draw_error_lines=False
)

# 하위 5개: 예측-실제 연결선 포함
plot_allmonth_latlon_pred_actual_30min(
    allmonth_plot_df_30,
    allmonth_bottom5_30_df,
    title="All Months Bottom 5 Samples: Prediction Error Lines (up to 30min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_30,
    draw_error_lines=True
)
# Out:
# 30분까지 실제 데이터가 있는 sample 수: 52
# Top 5 samples by 5/10/15/30min mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 277           278  477790500 2024-05-29 12:25:00    138.285100
# 531           533  563035400 2024-07-19 03:50:00    141.909969
# 55             55  636021244 2024-04-11 08:55:00    183.637379
# 500           502  354646000 2024-07-13 11:10:00    205.690949
# 306           308  477528400 2024-06-07 03:50:00    232.734050
#
#      median_error_m  max_error_m  count
# 277      104.355986   303.459884      4
# 531      138.626605   168.870848      4
# 55       212.658033   295.165881      4
# 500      198.890111   380.684564      4
# 306      207.661091   430.903420      4
# Bottom 5 samples by 5/10/15/30min mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 592           594  563324000 2024-07-30 19:20:00   2680.393173
# 560           562  477714600 2024-07-24 07:15:00   1552.596869
# 190           191  441754000 2024-05-12 14:15:00   1264.591503
# 58             58  367578740 2024-04-11 17:10:00   1215.962742
# 81             81  636018380 2024-04-16 10:15:00   1154.687300
#
#      median_error_m  max_error_m  count
# 592     1897.719190  6298.900592      4
# 560     1026.454872  3915.615753      4
# 190      957.995518  3072.143036      4
# 58       908.427586  3005.775846      4
# 81       973.158515  2613.105330      4
# plotted samples: 5
# plotted samples: 5
# plotted samples: 5
# plotted samples: 5

# %%
# 4~8월 전체 예측 결과 기준: 60분까지 상위 5개 / 하위 5개 그래프
# 기준 horizon: 5, 10, 15, 30, 60분 평균 오차

import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import pandas as pd
import numpy as np


ALLMONTH_SELECTION_HORIZONS_15 = [5, 10, 15]
ALLMONTH_TOP_N = 5
ALLMONTH_BOTTOM_N = 5


def build_allmonth_plot_dataframe(allmonth_trajectory_results_df, allmonth_trajectory_paths):
    result_df = allmonth_trajectory_results_df.copy()

    result_df = result_df.rename(columns={
        "MMSI": "mmsi",
        "actual_lat": "true_lat",
        "actual_lon": "true_lon"
    })

    start_rows = []

    for sample_index, item in enumerate(allmonth_trajectory_paths):
        start_rows.append({
            "sample_index": sample_index,
            "mmsi": item["MMSI"],
            "base_time": item["base_time"],
            "last_lat": item["start_lat"],
            "last_lon": item["start_lon"]
        })

    start_df = pd.DataFrame(start_rows)

    result_df = result_df.merge(
        start_df,
        on=["mmsi", "base_time"],
        how="inner"
    )

    result_df["error_m"] = result_df["error_km"] * 1000

    result_df = result_df[
        [
            "sample_index",
            "mmsi",
            "base_time",
            "forecast_minutes",
            "last_lat",
            "last_lon",
            "true_lat",
            "true_lon",
            "pred_lat",
            "pred_lon",
            "error_m"
        ]
    ].dropna()

    return result_df


def select_allmonth_top_bottom_samples_15min(
    allmonth_trajectory_results_df,
    allmonth_trajectory_paths,
    selection_horizons=[5, 10, 15],
    top_n=5,
    bottom_n=5
):
    plot_df = build_allmonth_plot_dataframe(
        allmonth_trajectory_results_df,
        allmonth_trajectory_paths
    )

    horizon_df = plot_df[
        plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    sample_score_df = (
        horizon_df
        .groupby("sample_index")
        .agg(
            mmsi=("mmsi", "first"),
            base_time=("base_time", "first"),
            mean_error_m=("error_m", "mean"),
            median_error_m=("error_m", "median"),
            max_error_m=("error_m", "max"),
            count=("error_m", "count")
        )
        .reset_index()
    )

    # 5/10/15/30/60분 결과가 모두 있는 샘플만 사용
    sample_score_df = sample_score_df[
        sample_score_df["count"] >= len(selection_horizons)
    ].copy()

    top_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=True)
        .head(top_n)
    )

    bottom_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=False)
        .head(bottom_n)
    )

    return plot_df, sample_score_df, top_samples, bottom_samples


def plot_allmonth_latlon_pred_actual_15min(
    plot_df,
    selected_samples,
    title,
    selection_horizons=[5, 10, 15],
    draw_error_lines=False
):
    selected_ids = selected_samples["sample_index"].tolist()

    data = plot_df[
        plot_df["sample_index"].isin(selected_ids)
        & plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    plt.figure(figsize=(11, 9))

    colors = plt.cm.tab10(np.linspace(0, 1, max(len(selected_ids), 1)))
    plot_count = 0

    for i, sample_index in enumerate(selected_ids):
        group = data[data["sample_index"] == sample_index].sort_values("forecast_minutes")

        if len(group) == 0:
            continue

        color = colors[i]
        plot_count += 1

        mmsi = int(group.iloc[0]["mmsi"])

        # 시작 위치
        plt.scatter(
            group.iloc[0]["last_lon"],
            group.iloc[0]["last_lat"],
            color=color,
            marker="o",
            s=70,
            edgecolor="black",
            linewidth=0.8
        )

        # 실제 움직임
        plt.plot(
            group["true_lon"],
            group["true_lat"],
            color=color,
            linestyle="-",
            marker="x",
            linewidth=1.5,
            label=f"Actual {i}: {mmsi}"
        )

        # 예측 움직임
        plt.plot(
            group["pred_lon"],
            group["pred_lat"],
            color=color,
            linestyle="--",
            marker="*",
            linewidth=1.5,
            label=f"Pred {i}: {mmsi}"
        )

        # forecast label
        for _, row in group.iterrows():
            plt.text(
                row["pred_lon"],
                row["pred_lat"],
                f"{int(row['forecast_minutes'])}min",
                fontsize=7,
                color=color
            )

        # 예측-실제 연결선
        if draw_error_lines:
            for _, row in group.iterrows():
                plt.plot(
                    [row["true_lon"], row["pred_lon"]],
                    [row["true_lat"], row["pred_lat"]],
                    color=color,
                    alpha=0.35,
                    linewidth=0.9
                )

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.grid(True)
    plt.legend(fontsize=8, ncol=2)

    ax = plt.gca()
    ax.xaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.ticklabel_format(style="plain", axis="both")

    plt.show()

    print("plotted samples:", plot_count)


allmonth_plot_df_15, allmonth_score_df_15, allmonth_top5_15_df, allmonth_bottom5_15_df = (
    select_allmonth_top_bottom_samples_15min(
        allmonth_trajectory_results_df,
        allmonth_trajectory_paths,
        selection_horizons=ALLMONTH_SELECTION_HORIZONS_15,
        top_n=ALLMONTH_TOP_N,
        bottom_n=ALLMONTH_BOTTOM_N
    )
)

print("15분까지 실제 데이터가 있는 sample 수:", len(allmonth_score_df_15))

print("Top 5 samples by 5/10/15min mean error")
display(allmonth_top5_15_df)

print("Bottom 5 samples by 5/10/15min mean error")
display(allmonth_bottom5_15_df)

# 상위 5개: 실제 vs 예측 궤적
plot_allmonth_latlon_pred_actual_15min(
    allmonth_plot_df_15,
    allmonth_top5_15_df,
    title="All Months Top 5 Samples: Predicted vs Actual Trajectories (up to 15min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_15,
    draw_error_lines=False
)

# 상위 5개: 예측-실제 연결선 포함
plot_allmonth_latlon_pred_actual_15min(
    allmonth_plot_df_15,
    allmonth_top5_15_df,
    title="All Months Top 5 Samples: Prediction Error Lines (up to 15min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_15,
    draw_error_lines=True
)

# 하위 5개: 실제 vs 예측 궤적
plot_allmonth_latlon_pred_actual_15min(
    allmonth_plot_df_15,
    allmonth_bottom5_15_df,
    title="All Months Bottom 5 Samples: Predicted vs Actual Trajectories (up to 15min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_15,
    draw_error_lines=False
)

# 하위 5개: 예측-실제 연결선 포함
plot_allmonth_latlon_pred_actual_15min(
    allmonth_plot_df_15,
    allmonth_bottom5_15_df,
    title="All Months Bottom 5 Samples: Prediction Error Lines (up to 15min)",
    selection_horizons=ALLMONTH_SELECTION_HORIZONS_15,
    draw_error_lines=True
)
# Out:
# 15분까지 실제 데이터가 있는 sample 수: 365
# Top 5 samples by 5/10/15min mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 241           242  211886810 2024-05-21 12:50:00     16.898723
# 509           512  636020440 2024-07-14 23:55:00     31.188286
# 523           526  636020978 2024-07-18 00:00:00     37.981880
# 618           621  370206000 2024-08-04 13:40:00     41.781944
# 736           739  367578740 2024-08-28 00:00:00     42.897290
#
#      median_error_m  max_error_m  count
# 241       20.462021    23.373058      3
# 509       28.803265    36.782271      3
# 523       37.996531    50.297703      3
# 618       51.624955    56.207798      3
# 736       28.763220    74.497288      3
# Bottom 5 samples by 5/10/15min mean error
#      sample_index       mmsi           base_time  mean_error_m  \
# 248           249  255806034 2024-05-22 16:15:00   1590.629681
# 591           594  563324000 2024-07-30 19:20:00   1474.224033
# 745           748  441743000 2024-08-28 18:00:00   1262.838174
# 506           509  311655000 2024-07-14 00:40:00   1096.062213
# 281           282  209716000 2024-05-31 06:45:00    921.581991
#
#      median_error_m  max_error_m  count
# 248      337.245203  4309.603952      3
# 591     1446.963213  2348.475166      3
# 745     1215.726795  2150.922168      3
# 506     1118.913961  1964.963033      3
# 281      871.925974  1686.226034      3
# plotted samples: 5
# plotted samples: 5
# plotted samples: 5
# plotted samples: 5

# %%
# 8월 test_raw 기준 선박 수 확인

print("8월 전체 row 수:", len(test_raw))
print("8월 고유 선박 수:", test_raw["MMSI"].nunique())

display(
    test_raw["MMSI"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "MMSI", "MMSI": "row_count"})
    .head(20)
)
# Out:
# 8월 전체 row 수: 16790
# 8월 고유 선박 수: 521
#     row_count  count
# 0   311703000    199
# 1   441246000    199
# 2   477947700    180
# 3   370206000    158
# 4   440502300    140
# 5   441743000    135
# 6   538009631    125
# 7   352001660    122
# 8   212352000    116
# 9   636018380    114
# 10  636015779    113
# 11  352153000    107
# 12  636020440    107
# 13  440273000    101
# 14  441387000    101
# 15  538009457     99
# 16  413218000     98
# 17  413383270     96
# 18  440505000     96
# 19  371002000     95

# %%
# 19-C. 8월 test_raw 전체 선박 / 전체 가능한 시점에 대한 Multi-horizon 예측
# 계산량이 많아도 test set 전체를 최대한 공정하게 평가하기 위한 코드
# 기존 trajectory_results_df, trajectory_paths와 섞이지 않도록 fulltest_ 접두사를 사용한다.

FULLTEST_MIN_TARGET_HORIZON = MAX_FORECAST_MINUTES
FULLTEST_MAX_HISTORY_GAP_MINUTES = MAX_HISTORY_GAP_MINUTES

fulltest_trajectory_records = []
fulltest_trajectory_paths = []

model.eval()

fulltest_total_candidates = 0
fulltest_used_candidates = 0

for mmsi_idx, (mmsi, raw_group) in enumerate(test_raw.groupby("MMSI"), start=1):
    raw_group = raw_group.sort_values("timestamp").reset_index(drop=True)
    norm_group = test_norm[test_norm["MMSI"] == mmsi].sort_values("timestamp").reset_index(drop=True)

    if len(raw_group) < SEQ_LEN + 1 or len(norm_group) < SEQ_LEN + 1:
        continue

    raw_data = raw_group[feature_cols].values.astype(np.float32)
    norm_data = norm_group[feature_cols].values.astype(np.float32)
    timestamps = raw_group["timestamp"].values.astype("datetime64[ns]")

    for start_idx in range(0, len(raw_group) - SEQ_LEN):
        fulltest_total_candidates += 1

        hist_timestamps = timestamps[start_idx:start_idx + SEQ_LEN]
        hist_diffs = np.diff(hist_timestamps).astype("timedelta64[m]")

        if len(hist_diffs) > 0:
            valid_history = np.all(
                (hist_diffs > np.timedelta64(0, "m")) &
                (hist_diffs <= np.timedelta64(FULLTEST_MAX_HISTORY_GAP_MINUTES, "m"))
            )
        else:
            valid_history = False

        if not valid_history:
            continue

        base_time = pd.Timestamp(timestamps[start_idx + SEQ_LEN - 1])

        # 최소한 최대 horizon까지 실제 비교 가능한 데이터가 있을 가능성이 있는지 확인
        max_target_time = base_time + pd.Timedelta(minutes=FULLTEST_MIN_TARGET_HORIZON)
        if raw_group["timestamp"].max() < max_target_time - pd.Timedelta(minutes=TOLERANCE_MINUTES):
            continue

        raw_seq = raw_data[start_idx:start_idx + SEQ_LEN]
        norm_seq = norm_data[start_idx:start_idx + SEQ_LEN]

        start_lat = raw_seq[-1][0]
        start_lon = raw_seq[-1][1]
        start_sog = raw_seq[-1][2]

        fulltest_pred_path = recursive_forecast_path(
            model,
            raw_seq,
            norm_seq,
            forecast_minutes=MAX_FORECAST_MINUTES
        )

        fulltest_actual_path = get_actual_path_for_horizons(
            test_raw,
            mmsi,
            base_time,
            FORECAST_MINUTES_LIST
        )

        if len(fulltest_actual_path) == 0:
            continue

        fulltest_pred_horizon = fulltest_pred_path[
            fulltest_pred_path["forecast_minutes"].isin(FORECAST_MINUTES_LIST)
        ].copy()

        fulltest_merged = fulltest_pred_horizon.merge(
            fulltest_actual_path,
            on="forecast_minutes",
            suffixes=("_pred", "_actual")
        )

        if len(fulltest_merged) == 0:
            continue

        fulltest_used_candidates += 1

        for _, row in fulltest_merged.iterrows():
            fulltest_error_km = haversine_km(
                row["lat_actual"],
                row["lon_actual"],
                row["lat_pred"],
                row["lon_pred"]
            )

            fulltest_trajectory_records.append({
                "prediction_scope": "Full test month all vessels",
                "base_time": base_time,
                "MMSI": mmsi,
                "start_sog": start_sog,
                "forecast_minutes": row["forecast_minutes"],
                "pred_lat": row["lat_pred"],
                "pred_lon": row["lon_pred"],
                "actual_lat": row["lat_actual"],
                "actual_lon": row["lon_actual"],
                "error_km": fulltest_error_km,
                "error_nm": fulltest_error_km / 1.852
            })

        fulltest_trajectory_paths.append({
            "prediction_scope": "Full test month all vessels",
            "base_time": base_time,
            "MMSI": mmsi,
            "start_lat": start_lat,
            "start_lon": start_lon,
            "start_sog": start_sog,
            "raw_seq": raw_seq,
            "pred_path": fulltest_pred_horizon.reset_index(drop=True),
            "actual_path": fulltest_actual_path.reset_index(drop=True)
        })

    if mmsi_idx % 20 == 0:
        print(
            f"processed vessels: {mmsi_idx}, "
            f"total candidates: {fulltest_total_candidates}, "
            f"used candidates: {fulltest_used_candidates}"
        )

fulltest_trajectory_results_df = pd.DataFrame(fulltest_trajectory_records)

print("fulltest total candidates:", fulltest_total_candidates)
print("fulltest used candidates:", fulltest_used_candidates)
print("fulltest trajectory result rows:", len(fulltest_trajectory_results_df))
print("fulltest trajectory paths:", len(fulltest_trajectory_paths))

if len(fulltest_trajectory_results_df) > 0:
    display(fulltest_trajectory_results_df.head())
else:
    print("평가 가능한 fulltest trajectory 결과가 없습니다.")
# Out:
# processed vessels: 20, total candidates: 536, used candidates: 139
# processed vessels: 40, total candidates: 947, used candidates: 249
# processed vessels: 60, total candidates: 1307, used candidates: 337
# processed vessels: 80, total candidates: 1656, used candidates: 421
# processed vessels: 100, total candidates: 1962, used candidates: 482
# processed vessels: 120, total candidates: 2367, used candidates: 573
# processed vessels: 140, total candidates: 2589, used candidates: 598
# processed vessels: 160, total candidates: 3226, used candidates: 743
# processed vessels: 180, total candidates: 3631, used candidates: 832
# processed vessels: 200, total candidates: 4171, used candidates: 950
# processed vessels: 220, total candidates: 4576, used candidates: 1025
# processed vessels: 240, total candidates: 4910, used candidates: 1109
# processed vessels: 260, total candidates: 5226, used candidates: 1129
# processed vessels: 280, total candidates: 5995, used candidates: 1220
# processed vessels: 300, total candidates: 6615, used candidates: 1310
# processed vessels: 320, total candidates: 7231, used candidates: 1380
# processed vessels: 340, total candidates: 7583, used candidates: 1471
# processed vessels: 360, total candidates: 8066, used candidates: 1572
# processed vessels: 380, total candidates: 8587, used candidates: 1669
# processed vessels: 400, total candidates: 9144, used candidates: 1766
# processed vessels: 420, total candidates: 9586, used candidates: 1863
# processed vessels: 440, total candidates: 9998, used candidates: 1958
# processed vessels: 460, total candidates: 10415, used candidates: 2059
# processed vessels: 480, total candidates: 10814, used candidates: 2154
# processed vessels: 500, total candidates: 11325, used candidates: 2294
# processed vessels: 520, total candidates: 11563, used candidates: 2335
# fulltest total candidates: 11618
# fulltest used candidates: 2335
# fulltest trajectory result rows: 5450
# fulltest trajectory paths: 2335
#               prediction_scope           base_time       MMSI  start_sog  \
# 0  Full test month all vessels 2024-08-12 04:30:00  209470000   6.960000
# 1  Full test month all vessels 2024-08-12 04:30:00  209470000   6.960000
# 2  Full test month all vessels 2024-08-12 04:30:00  209470000   6.960000
# 3  Full test month all vessels 2024-08-12 04:35:00  209470000   5.353571
# 4  Full test month all vessels 2024-08-12 04:35:00  209470000   5.353571
#
#    forecast_minutes   pred_lat    pred_lon  actual_lat  actual_lon  error_km  \
# 0                 5  35.070545  128.800461   35.071291  128.800248  0.085164
# 1                10  35.072945  128.808624   35.073956  128.807493  0.152442
# 2                15  35.074802  128.815933   35.075726  128.811544  0.412443
# 3                 5  35.073524  128.807541   35.073956  128.807493  0.048134
# 4                10  35.075195  128.813828   35.075726  128.811544  0.216043
#
#    error_nm
# 0  0.045985
# 1  0.082312
# 2  0.222702
# 3  0.025990
# 4  0.116654

# %%
# fulltest 결과 기준: 상위 5개 / 하위 5개 예측 그래프
# 기준: 5/10/15분 평균 오차

import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import pandas as pd
import numpy as np


FULLTEST_SELECTION_HORIZONS = [5, 10, 15]
FULLTEST_TOP_N = 5
FULLTEST_BOTTOM_N = 5


def build_fulltest_plot_dataframe(fulltest_trajectory_results_df, fulltest_trajectory_paths):
    result_df = fulltest_trajectory_results_df.copy()

    result_df = result_df.rename(columns={
        "MMSI": "mmsi",
        "actual_lat": "true_lat",
        "actual_lon": "true_lon"
    })

    start_rows = []

    for sample_index, item in enumerate(fulltest_trajectory_paths):
        start_rows.append({
            "sample_index": sample_index,
            "mmsi": item["MMSI"],
            "base_time": item["base_time"],
            "last_lat": item["start_lat"],
            "last_lon": item["start_lon"],
            "start_sog": item.get("start_sog", np.nan)
        })

    start_df = pd.DataFrame(start_rows)

    result_df = result_df.merge(
        start_df,
        on=["mmsi", "base_time"],
        how="inner"
    )

    result_df["error_m"] = result_df["error_km"] * 1000

    result_df = result_df[
        [
            "sample_index",
            "mmsi",
            "base_time",
            "start_sog",
            "forecast_minutes",
            "last_lat",
            "last_lon",
            "true_lat",
            "true_lon",
            "pred_lat",
            "pred_lon",
            "error_m"
        ]
    ].dropna()

    return result_df


def select_fulltest_top_bottom_samples(
    fulltest_trajectory_results_df,
    fulltest_trajectory_paths,
    selection_horizons=[5, 10, 15],
    top_n=5,
    bottom_n=5
):
    plot_df = build_fulltest_plot_dataframe(
        fulltest_trajectory_results_df,
        fulltest_trajectory_paths
    )

    horizon_df = plot_df[
        plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    sample_score_df = (
        horizon_df
        .groupby("sample_index")
        .agg(
            mmsi=("mmsi", "first"),
            base_time=("base_time", "first"),
            start_sog=("start_sog", "first"),
            mean_error_m=("error_m", "mean"),
            median_error_m=("error_m", "median"),
            max_error_m=("error_m", "max"),
            count=("error_m", "count")
        )
        .reset_index()
    )

    # 선택 horizon이 모두 있는 샘플만 사용
    sample_score_df = sample_score_df[
        sample_score_df["count"] >= len(selection_horizons)
    ].copy()

    top_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=True)
        .head(top_n)
    )

    bottom_samples = (
        sample_score_df
        .sort_values("mean_error_m", ascending=False)
        .head(bottom_n)
    )

    return plot_df, sample_score_df, top_samples, bottom_samples


def plot_fulltest_latlon_pred_actual(
    plot_df,
    selected_samples,
    title,
    selection_horizons=[5, 10, 15],
    draw_error_lines=False
):
    selected_ids = selected_samples["sample_index"].tolist()

    data = plot_df[
        plot_df["sample_index"].isin(selected_ids)
        & plot_df["forecast_minutes"].isin(selection_horizons)
    ].copy()

    plt.figure(figsize=(11, 9))

    colors = plt.cm.tab10(np.linspace(0, 1, max(len(selected_ids), 1)))
    plot_count = 0

    for i, sample_index in enumerate(selected_ids):
        group = data[data["sample_index"] == sample_index].sort_values("forecast_minutes")

        if len(group) == 0:
            continue

        color = colors[i]
        plot_count += 1

        mmsi = int(group.iloc[0]["mmsi"])
        start_sog = float(group.iloc[0]["start_sog"])

        # 시작 위치
        plt.scatter(
            group.iloc[0]["last_lon"],
            group.iloc[0]["last_lat"],
            color=color,
            marker="o",
            s=70,
            edgecolor="black",
            linewidth=0.8
        )

        # 실제 움직임
        plt.plot(
            group["true_lon"],
            group["true_lat"],
            color=color,
            linestyle="-",
            marker="x",
            linewidth=1.5,
            label=f"Actual {i}: {mmsi} ({start_sog:.1f}kt)"
        )

        # 예측 움직임
        plt.plot(
            group["pred_lon"],
            group["pred_lat"],
            color=color,
            linestyle="--",
            marker="*",
            linewidth=1.5,
            label=f"Pred {i}: {mmsi}"
        )

        # forecast label
        for _, row in group.iterrows():
            plt.text(
                row["pred_lon"],
                row["pred_lat"],
                f"{int(row['forecast_minutes'])}min",
                fontsize=7,
                color=color
            )

        # 예측-실제 연결선
        if draw_error_lines:
            for _, row in group.iterrows():
                plt.plot(
                    [row["true_lon"], row["pred_lon"]],
                    [row["true_lat"], row["pred_lat"]],
                    color=color,
                    alpha=0.35,
                    linewidth=0.9
                )

    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.grid(True)
    plt.legend(fontsize=8, ncol=2)

    ax = plt.gca()
    ax.xaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.yaxis.set_major_formatter(ScalarFormatter(useOffset=False))
    ax.ticklabel_format(style="plain", axis="both")

    plt.show()

    print("plotted samples:", plot_count)


fulltest_plot_df, fulltest_score_df, fulltest_top5_df, fulltest_bottom5_df = (
    select_fulltest_top_bottom_samples(
        fulltest_trajectory_results_df,
        fulltest_trajectory_paths,
        selection_horizons=FULLTEST_SELECTION_HORIZONS,
        top_n=FULLTEST_TOP_N,
        bottom_n=FULLTEST_BOTTOM_N
    )
)

print("Fulltest candidate samples:", len(fulltest_score_df))

print("Fulltest Top 5 samples by mean error")
display(fulltest_top5_df)

print("Fulltest Bottom 5 samples by mean error")
display(fulltest_bottom5_df)

# 상위 5개: 실제 vs 예측 궤적
plot_fulltest_latlon_pred_actual(
    fulltest_plot_df,
    fulltest_top5_df,
    title="Full Test Top 5 Samples: Predicted vs Actual Trajectories",
    selection_horizons=FULLTEST_SELECTION_HORIZONS,
    draw_error_lines=False
)

# 상위 5개: 예측-실제 연결선 포함
plot_fulltest_latlon_pred_actual(
    fulltest_plot_df,
    fulltest_top5_df,
    title="Full Test Top 5 Samples: Prediction Error Lines",
    selection_horizons=FULLTEST_SELECTION_HORIZONS,
    draw_error_lines=True
)

# 하위 5개: 실제 vs 예측 궤적
plot_fulltest_latlon_pred_actual(
    fulltest_plot_df,
    fulltest_bottom5_df,
    title="Full Test Bottom 5 Samples: Predicted vs Actual Trajectories",
    selection_horizons=FULLTEST_SELECTION_HORIZONS,
    draw_error_lines=False
)

# 하위 5개: 예측-실제 연결선 포함
plot_fulltest_latlon_pred_actual(
    fulltest_plot_df,
    fulltest_bottom5_df,
    title="Full Test Bottom 5 Samples: Prediction Error Lines",
    selection_horizons=FULLTEST_SELECTION_HORIZONS,
    draw_error_lines=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 219
#     215     print("plotted samples:", plot_count)
#     216
#     217
#     218 fulltest_plot_df, fulltest_score_df, fulltest_top5_df, fulltest_bottom5_df = (
# --> 219     select_fulltest_top_bottom_samples(
#     220         fulltest_trajectory_results_df,
#     221         fulltest_trajectory_paths,
#     222         selection_horizons=FULLTEST_SELECTION_HORIZONS,
#
# Cell In[52], line 73, in select_fulltest_top_bottom_samples(fulltest_trajectory_results_df, fulltest_trajectory_paths, selection_horizons, top_n, bottom_n)
#      69     selection_horizons=[5, 10, 15],
#      70     top_n=5,
#      71     bottom_n=5
#      72 ):
# ---> 73     plot_df = build_fulltest_plot_dataframe(
#      74         fulltest_trajectory_results_df,
#      75         fulltest_trajectory_paths
#      76     )
#
# Cell In[52], line 46, in build_fulltest_plot_dataframe(fulltest_trajectory_results_df, fulltest_trajectory_paths)
#      42     )
#      43
#      44     result_df["error_m"] = result_df["error_km"] * 1000
#      45
# ---> 46     result_df = result_df[
#      47         [
#      48             "sample_index",
#      49             "mmsi",
#
# File ~\anaconda3\envs\torch_env\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\torch_env\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\envs\torch_env\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['start_sog'] not in index"

# %%
# 원본 moving_df 기준 AIS 수신 간격 분포 확인

interval_df = []

for mmsi, group in moving_df.groupby("MMSI"):
    group = group.sort_values("timestamp")
    dt_sec = group["timestamp"].diff().dt.total_seconds().dropna()

    if len(dt_sec) == 0:
        continue

    interval_df.append(pd.DataFrame({
        "MMSI": mmsi,
        "dt_sec": dt_sec
    }))

interval_df = pd.concat(interval_df, ignore_index=True)

display(interval_df["dt_sec"].describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9]))

print("30초 이하 비율:", (interval_df["dt_sec"] <= 30).mean())
print("60초 이하 비율:", (interval_df["dt_sec"] <= 60).mean())
print("120초 이하 비율:", (interval_df["dt_sec"] <= 120).mean())
print("300초 이하 비율:", (interval_df["dt_sec"] <= 300).mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       1 # 원본 moving_df 기준 AIS 수신 간격 분포 확인
#       2
#       3 interval_df = []
#       4
# ----> 5 for mmsi, group in moving_df.groupby("MMSI"):
#       6     group = group.sort_values("timestamp")
#       7     dt_sec = group["timestamp"].diff().dt.total_seconds().dropna()
#       8
#
# NameError: name 'moving_df' is not defined
